# %%
import json
import pprint
import uuid
import xmltodict

RESULT_TABLE_NAMES = ['prequal_results', 'xml_details', 'products', 'credit_profiles', 'headers', 'risk_models', 'consumer_identities', 'addr_infos', 'employ_infos', 'trade_lines', 'inquiries', 'info_msgs', 'enhanced_pm_data', 'tradeline_amounts']
with open("./data/prequalresult.json", 'r') as f:
    json_file = json.load(f)
json_file
# Out:
# [{'model': 'common.prequalresult',
#   'pk': 1,
#   'fields': {'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant'}}]

# %% [markdown]
# Building PrequalResult table objects

# %%
# initialize result object lists
RESULT_OBJ_DICT = dict((key, []) for key in RESULT_TABLE_NAMES)
ATTR_CODE_DICT = {
    'risk_models': ['ModelIndicator', 'Evaluation'],
    'addr_infos': ['Origination', 'DwellingType', 'HomeOwnership', '']
}

prequal_results = json_file
for prequal_result in prequal_results:
    prequal_result.update(prequal_result.pop('fields'))
    xml_detail_id = "xd_{}".format(uuid.uuid4())
    prequal_result['xml_detail_id'] = xml_detail_id
    RESULT_OBJ_DICT['prequal_results'].append(prequal_result)
    
    # initializing XML_Detail object
    xml_dict = xmltodict.parse(result['xml_data'], dict_constructor=dict)['NetConnectResponse']
    xml_dict['id'] = xml_detail_id
    RESULT_OBJ_DICT['xml_details'].append(xml_dict)
    product_id = "pd_{}".format(uuid.uuid4())
    xml_dict['product_id'] = product_id
    
    # initializing Product object
    product_obj = xml_dict.pop('Products')
    product_obj['id'] = product_id
    RESULT_OBJ_DICT['products'].append(product_obj)
    credit_profile_id = "cp_{}".format(uuid.uuid4())
    product_obj['credit_profile_id'] = credit_profile_id
    
    # initializing CreditProfile object
    credit_profile_obj = product_obj.pop('CreditProfile')
    credit_profile_obj['id'] = credit_profile_id
    RESULT_OBJ_DICT['credit_profiles'].append(credit_profile_obj)
    
    
    ## handling RiskModels in CreditProfile
    for risk_model in credit_profile_obj.pop('RiskModel'):
        risk_model['id'] = "rm_{}".format(uuid.uuid4())
        risk_model['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['risk_models'].append(risk_model)
    
    # initializing Header object in CreditProfile
    header_id = "hd_{}".format(uuid.uuid4())
    credit_profile_obj['header_id'] = header_id
    header_obj = credit_profile_obj.pop('Header')
    header_obj['id'] = header_id
    RESULT_OBJ_DICT['headers'].append(header_obj)
    
    ## handling ConsumerIdentities in CreditProfile
    for consumer_identity in credit_profile_obj.pop('ConsumerIdentity'):
        consumer_identity['id'] = "ci_{}".format(uuid.uuid4())
        consumer_identity['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['consumer_identities'].append(consumer_identity)
    
    ## handling AddressInformations in CreditProfile
    for addr_info in credit_profile_obj.pop('AddressInformation'):
        addr_info['id'] = "ai_{}".format(uuid.uuid4())
        addr_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['addr_infos'].append(addr_info)
       
    ## handling EmploymentInformations in CreditProfile
    for employ_info in credit_profile_obj.pop('EmploymentInformation'):
        employ_info['id'] = "ei_{}".format(uuid.uuid4())
        employ_info['CreditProfile_id'] = credit_profile_id
        if 'Origination' in employ_info:
                code = employ_info['Origination']['@code']
            else:
                code = ''
        employ_info['Origination_code'] = code
        employ_info.pop('Origination', None)
        RESULT_OBJ_DICT['employ_infos'].append(employ_info)
        
    ## handling TradeLines in CreditProfile
    code_attrs = ['SpecialComment', 'Evaluation', 'AccountType', 'TermsDuration', 'Status', 'OpenOrClosed', 'RevolvingOrInstallment', 'MonthlyPaymentType', 'KOB']
    for trade_line in credit_profile_obj.pop('TradeLine'):
        trade_line['id'] = "tl_{}".format(uuid.uuid4())
        trade_line['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['trade_lines'].append(trade_line)
        for attr in code_attrs:
            if attr in trade_line:
                code = trade_line[attr]['@code']
            else:
                code = ''
            trade_line["{}_code".format(attr)] = code
            trade_line.pop(attr, None)
        
        # initializing EnhancedPaymentData object in TradeLine
        enhanced_pm_data_id = "ep_{}".format(uuid.uuid4())
        trade_line['enhanced_pm_data_id'] = enhanced_pm_data_id
        enhanced_pm_data_obj = trade_line.pop('EnhancedPaymentData')
        enhanced_pm_data_obj['id'] = enhanced_pm_data_id
        RESULT_OBJ_DICT['enhanced_pm_data'].append(enhanced_pm_data_obj)
        
        ## handling Amount object in TradeLine
        for amt_obj in trade_line.pop('Amount'):
            amt_obj['id'] = "am_{}".format(uuid.uuid4())
            amt_obj['TradeLine_id'] = trade_line['id']
            RESULT_OBJ_DICT['tradeline_amounts'].append(amt_obj)
    
    # initializing Inquiry object in CreditProfile
    inquiry_id = "iq_{}".format(uuid.uuid4())
    credit_profile_obj['inquiry_id'] = inquiry_id
    inquiry_obj = credit_profile_obj.pop('Inquiry')
    inquiry_obj['id'] = inquiry_id
    RESULT_OBJ_DICT['inquiries'].append(inquiry_obj)
    
    ## handling InformationalMessages in CreditProfile
    for info_msg in credit_profile_obj.pop('InformationalMessage'):
        info_msg['id'] = "im_{}".format(uuid.uuid4())
        info_msg['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['info_msgs'].append(info_msg)
    
    
RESULT_OBJ_DICT
# Out:
# {'prequal_results': [{'model': 'common.prequalresult',
#    'pk': 1,
#    'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant',
#    'xml_detail_id': 'xd_b71c92de-04c0-434c-84b5-b99e06595ac9'}],
#  'xml_details': [{'@xmlns': 'http://www.experian.com/NetConnectResponse',
#    'CompletionCode': '0000',
#    'ReferenceId': 'testing 123',
#    'TransactionId': '41588980',
#    'id': 'xd_b71c92de-04c0-434c-84b5-b99e06595ac9',
#    'product_id': 'pd_47de6504-5b8f-4858-aa1b-3ebcc28309cc'}],
#  'products': [{'@xmlns': 'http://www.experian.com/ARFResponse',
#    'id': 'pd_47de6504-5b8f-4858-aa1b-3ebcc28309cc',
#    'credit_profile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0'}],
#  'credit_profiles': [{'id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'header_id': 'hd_88e537f2-8be4-4c52-9723-d53ceb872d10',
#    'inquiry_id': 'iq_571d9f4e-cffe-4bdb-9b1b-cc691b1d1d89'}],
#  'headers': [{'ReportDate': '10032017',
#    'ReportTime': '140607',
#    'Preamble': 'TWA1',
#    'ARFVersion': '07',
#    'id': 'hd_88e537f2-8be4-4c52-9723-d53ceb872d10'}],
#  'risk_models': [{'Score': '0808',
#    'ScoreFactorCodeOne': '10',
#    'ScoreFactorCodeTwo': '09',
#    'ScoreFactorCodeThree': '05',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_aa3141ff-428a-450e-9f48-0e1d68aef368',
#    'ModelIndicator_code': 'F ',
#    'Evaluation_code': 'P',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0'},
#   {'Score': '0807',
#    'ScoreFactorCodeOne': '30',
#    'ScoreFactorCodeTwo': '05',
#    'ScoreFactorCodeThree': '11',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_02e7a359-2754-4d47-91a1-5f3898612db1',
#    'ModelIndicator_code': 'AA',
#    'Evaluation_code': 'P',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0'}],
#  'consumer_identities': [{'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_cf8d300a-20cf-4665-ba50-d07c7a0edc10',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0'},
#   {'Name': {'Type': {'@code': 'N'},
#     'Surname': 'SCALICI',
#     'First': 'AS',
#     'Middle': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_f9a41dbc-54e9-4873-806c-ae9ec3fd3494',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0'},
#   {'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM', 'Gen': 'JR'},
#    'YOB': None,
#    'id': 'ci_a39c34e6-61b3-478b-908a-02d267b05955',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0'},
#   {'Name': {'Type': {'@code': 'A'},
#     'Surname': 'ANTHONY',
#     'First': 'WILLIAM',
#     'Middle': 'R'},
#    'YOB': None,
#    'id': 'ci_0215b213-9493-486b-b251-facdd96d1ba6',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0'}],
#  'addr_infos': [{'FirstReportedDate': '10272003',
#    'LastUpdatedDate': '12202015',
#    'TimesReported': '00',
#    'LastReportingSubcode': '7370142',
#    'StreetPrefix': '7324',
#    'StreetName': '84TH STREET',
#    'StreetSuffix': 'CT SW',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984986380',
#    'CensusGeoCode': None,
#    'id': 'ai_e127fad4-38a0-41b2-8dc1-89af0fb01ab9',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'Origination_code': '2',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '01012011',
#    'LastUpdatedDate': '01012011',
#    'TimesReported': '00',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3260 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_5bb141a5-ec02-430c-9fb6-73ac03f647a7',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '05282006',
#    'LastUpdatedDate': '11022010',
#    'TimesReported': '12',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3216 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_7eb10c6c-3ff7-4348-99ee-2075b091d624',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '}],
#  'employ_infos': [{'FirstReportedDate': '04082011',
#    'LastUpdatedDate': '04082011',
#    'Name': 'GM RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_4f9b451c-efbb-44c6-917e-79b2b089acf0',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'Origination_code': '2'},
#   {'FirstReportedDate': '12282009',
#    'LastUpdatedDate': '06112010',
#    'Name': 'RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_302bb25d-6f62-445a-8924-0ea36e48e184',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'Origination_code': '2'}],
#  'trade_lines': [{'OpenDate': '06011981',
#    'StatusDate': '05012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '05192017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '15',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01032016',
#    'Subcode': '1401790',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_a8048731-3f84-4b95-be3c-1385527d59da',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '28',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC',
#    'enhanced_pm_data_id': 'ep_20257bda-e2e3-49eb-a081-9815ac02ff6e'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03182012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1213727',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_44fc9b3c-35fd-4c17-a381-2a8e7d98d1b9',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '31',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_af2cf695-7db8-4533-8573-ca039fdac173'},
#   {'OpenDate': '06102006',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '07232017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '96',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0---------CCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '07212015',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_2b8e3773-0ac8-47e2-a0ed-e37739b1d666',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_465227ff-3595-40c9-9cd5-5685151a7052'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '04282012',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '03',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01122010',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_33775e75-f79f-4d47-9d27-c88b04748b98',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_cba6aa6c-ce9a-448f-9db3-4f16530b3110'},
#   {'OpenDate': '03012002',
#    'StatusDate': '04012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '0'},
#    'BalanceDate': '04012009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '86',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00--------0-----------00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12102006',
#    'Subcode': '1439507',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_2561c200-7542-4822-92ac-a99b73cddc01',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'NZ',
#    'enhanced_pm_data_id': 'ep_98892b72-1a43-406d-8762-ffb0ae9cc86e'},
#   {'OpenDate': '03012007',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03282009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '26',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0----------0',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_f304394d-eb98-40b2-b992-75d238a62548',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_9f2b4cab-ee1e-49d9-8f47-af04be81f50e'},
#   {'OpenDate': '04072017',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08032017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '04',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00C',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_d96e5e5f-f708-4801-92f1-9cb088c39a53',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_e0dc6cce-0514-47bc-87f5-75f8253c125b'},
#   {'OpenDate': '09012016',
#    'StatusDate': '06012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '06282017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '6037453215420',
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '06262017',
#    'Subcode': '1945962',
#    'SubscriberDisplayName': 'VERIZON NEW ENGLAND IN',
#    'id': 'tl_c78051b4-685d-4bd1-9ef9-b6e611ad501e',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '31',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'UT',
#    'enhanced_pm_data_id': 'ep_712cd930-4373-4c6d-935c-5feb80cfbb6f'},
#   {'OpenDate': '08122015',
#    'StatusDate': '05012016',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '05282016',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '15621485',
#    'MonthsHistory': '10',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_da1b2a7a-744b-4b48-bdba-711dfa1c1826',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': 'UNK',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB',
#    'enhanced_pm_data_id': 'ep_8475efbe-a0ae-4bf2-8f9c-11ede57df8ba'},
#   {'OpenDate': '02182007',
#    'StatusDate': '11012015',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '11282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000CCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_ba0eec46-4eee-45bd-86df-191ab4290008',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB',
#    'enhanced_pm_data_id': 'ep_75f0f771-6ce4-4183-af1b-ac58b46ccf28'},
#   {'OpenDate': '05011984',
#    'StatusDate': '10012015',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '10082015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_d92a2a02-ee3d-49a5-8d9e-49d052f7d6db',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_6655c501-9154-4d0d-aecb-73aa0ec9c6f1'},
#   {'OpenDate': '12142012',
#    'StatusDate': '08012015',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '08282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '13750088',
#    'MonthsHistory': '33',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_a6086b89-7083-4987-b789-cd21f7a48fa8',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': '180',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB',
#    'enhanced_pm_data_id': 'ep_9f9ef110-3a29-42ee-b937-1db4f60b1160'},
#   {'OpenDate': '10202007',
#    'StatusDate': '11012012',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '11102012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '68',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_f142a78a-1abf-44f5-927f-6782702b857d',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_b7271a8a-6dfc-480a-9d11-886585594caa'},
#   {'OpenDate': '10202007',
#    'StatusDate': '10012011',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '10282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1220390',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_9ec579c5-3f89-4f38-a80c-fe1e5f0e2871',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_4e6c0f08-853d-49f7-a044-4166daf0612e'},
#   {'OpenDate': '01012007',
#    'StatusDate': '07012011',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '07282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000CCCCCC',
#    'Subcode': '1290016',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_dd117a42-7e80-477a-856e-954afbab0d95',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_d2bcabb0-7fee-48fe-9ce6-5b318eb0f841'},
#   {'OpenDate': '01092008',
#    'StatusDate': '06012011',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '3'},
#    'BalanceDate': '06082011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '32',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000CCCCCCCCCC',
#    'Subcode': '1290138',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_67f2ccc7-0cd8-4a36-8acf-b7d2bb00d57a',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_e545f9d7-0397-40d5-b818-3526372cb16c'},
#   {'OpenDate': '01082006',
#    'StatusDate': '02012011',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '02282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '62',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B0000000000000000--------',
#    'Subcode': '6230125',
#    'SubscriberDisplayName': 'BAC/FLEET-BKCARD',
#    'id': 'tl_974517ed-22f4-4ceb-adc6-ff9c3abc138d',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_70e033c2-b9eb-4694-b7de-c7419726a390'},
#   {'OpenDate': '09242005',
#    'StatusDate': '11012010',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '3'},
#    'BalanceDate': '11282010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '60',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1260958',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_12dbd3e2-c74b-411d-91bd-e8c7731efdbe',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_d2395fa4-8288-41a9-9837-84b39196fcce'},
#   {'OpenDate': '09102007',
#    'StatusDate': '03012010',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03072010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '30',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000000CCCCCCC',
#    'Subcode': '3245600',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_95f9c1c2-7d1c-4898-975b-c5ade5980046',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_17203bb9-b0a0-4ee6-a7a3-357ecbe1cdb8'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_48990eb3-f09b-4362-b3a8-4c7a71230e09',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_f971c147-399a-4ce1-9a53-215a94896ecb'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_32171b92-b0d2-4088-b6e5-efefa72ba293',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_b1b89013-29e5-4b5a-ac10-63267184b862'},
#   {'OpenDate': '04222005',
#    'StatusDate': '06012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '06282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '1201520',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_f9e22d6f-56e6-48bf-adda-6430502bc2db',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_5d9bcaec-95ef-40ae-88d3-691071e89da0'},
#   {'OpenDate': '01072008',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03012009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '14',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCC',
#    'Subcode': '1202270',
#    'SubscriberDisplayName': 'WF/WB',
#    'id': 'tl_160d3d3a-5482-48ff-a7a1-fdd0d722c394',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB',
#    'enhanced_pm_data_id': 'ep_3752af47-3d8b-4a57-8fb6-945ec43ddee8'},
#   {'OpenDate': '02282004',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '02282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '61',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC00000000CCCCC',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_87dae5a5-575a-4461-a8af-9e225ae482c7',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_73da4a43-5b4c-462f-a217-1ec44f5172f7'},
#   {'OpenDate': '02151994',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '02222009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B---------------C--------',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_9f2d0202-ff3f-4e1b-a7f3-0c5fe1d58cfe',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_8eda1167-ee2c-49a5-8c69-5fc6e4d6d09d'},
#   {'OpenDate': '09072013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '08232017',
#    'BalanceAmount': '00000025',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C0CCCCCCCCC000CCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000010',
#    'LastPaymentDate': '06082017',
#    'Subcode': '3178962',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_6ed01ce1-022f-4f21-8b69-90ad27b75855',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'ZR',
#    'enhanced_pm_data_id': 'ep_81e49e87-92a7-4f07-ba5d-d1dca3b974cc'},
#   {'OpenDate': '09011979',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08202017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '75',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000CCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '05092017',
#    'Subcode': '1335510',
#    'SubscriberDisplayName': 'SYNCB/EXXON MOBIL',
#    'id': 'tl_c1d971d5-3430-4e69-8dd7-cb92b480630c',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC',
#    'enhanced_pm_data_id': 'ep_a148fd66-95e3-4921-be25-3695dcf198a6'},
#   {'OpenDate': '06182013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08162017',
#    'BalanceAmount': '00000160',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '51',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0C',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07272017',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_147172a1-743c-4698-ab52-6b902ddbf412',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'DV',
#    'enhanced_pm_data_id': 'ep_6ee93938-29d8-41a9-af02-503b38094c75'},
#   {'OpenDate': '04272007',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '3'},
#    'BalanceDate': '08152017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000000000CCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12282015',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_72a9c28a-cd57-4c77-aef8-11e1346e5197',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'DV',
#    'enhanced_pm_data_id': 'ep_caaf2e8a-5208-400d-a639-3ac27f03a98b'},
#   {'OpenDate': '09012010',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08142017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '84',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000C000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '08282016',
#    'Subcode': '1349040',
#    'SubscriberDisplayName': 'FILENES',
#    'id': 'tl_afd8c9c3-8e43-473e-a12c-ab646ddff091',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'ZR',
#    'enhanced_pm_data_id': 'ep_267f679b-ef09-433c-b397-dfceb2b9a2fe'},
#   {'OpenDate': '04011998',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08092017',
#    'BalanceAmount': '00001354',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '97',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07242017',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_b9fdaeaa-d68f-4618-ac96-151bc59c7d36',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_eb4640a1-2c81-499e-9e63-15add37c5be0'},
#   {'OpenDate': '06011983',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000052',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_4bd4839b-fdf8-446f-bc2d-bf6e6ec3b8ac',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_10d45db8-4acd-4f2b-a172-fac8fa6ad51a'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000599',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_c1a6f325-9920-4f2b-b401-4b1321f3ab11',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_5cf3ac69-5f81-4309-baf9-733f685ebf19'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00001960',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_6e2788df-e422-4c06-a85e-5f0e8cb54153',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC',
#    'enhanced_pm_data_id': 'ep_b42a69fe-1860-4c94-bee5-cc4e666cb1a4'},
#   {'OpenDate': '08182016',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '0000000000CC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '09192016',
#    'Subcode': '2613430',
#    'SubscriberDisplayName': 'SYNCB/BROOK BROS',
#    'id': 'tl_b60b0b12-4145-41a4-89b7-b7519e9ad105',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'CG',
#    'enhanced_pm_data_id': 'ep_aad0e97b-1dac-4fda-9716-71dec3f2f9c8'},
#   {'OpenDate': '08122015',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '07282017',
#    'BalanceAmount': '00004607',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '24',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0',
#    'MonthlyPaymentAmount': 'UNKNOWN',
#    'LastPaymentDate': '07102017',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_fb2b9138-d1f9-49e1-a6ee-7cfa5f8c96ca',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BB',
#    'enhanced_pm_data_id': 'ep_dccabaaf-cdb2-4bdf-a43a-3efc2ce1c1c8'}],
#  'inquiries': [{'Date': '08182016',
#    'Amount': 'UNKNOWN',
#    'Type': {'@code': '31'},
#    'Terms': {'@code': 'UNK'},
#    'Subcode': '1640007',
#    'KOB': {'@code': 'FF'},
#    'SubscriberDisplayName': 'SYNCB/BROOKS BROS',
#    'id': 'iq_571d9f4e-cffe-4bdb-9b1b-cc691b1d1d89'}],
#  'info_msgs': [{'MessageNumber': '92',
#    'MessageText': '0092 REQUESTED PRODUCT OPTION NOT ALLOWED',
#    'id': 'im_23bc39aa-9162-4a69-bc39-a573e2eff865',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0'},
#   {'MessageNumber': '84',
#    'MessageText': '0084 SSN MATCHES',
#    'id': 'im_d206b377-b931-4058-996a-71a3070271c0',
#    'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0'}],
#  'enhanced_pm_data': [{'InitialPaymentLevelDate': '05012017',
#    'AccountCondition': {'@code': '05'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '51'},
#    'id': 'ep_20257bda-e2e3-49eb-a081-9815ac02ff6e'},
#   {'InitialPaymentLevelDate': '03012012',
#    'AccountCondition': {'@code': '05'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '40'},
#    'id': 'ep_af2cf695-7db8-4533-8573-ca039fdac173'},
#   {'InitialPaymentLevelDate': '07012017',
#    'AccountCondition': {'@code': 'A3'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_465227ff-3595-40c9-9cd5-5685151a7052'},
#   {'InitialPaymentLevelDate': '03012012',
#    'AccountCondition': {'@code': 'A3'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '18'},
#    'id': 'ep_cba6aa6c-ce9a-448f-9db3-4f16530b3110'},
#   {'InitialPaymentLevelDate': '04012009',
#    'AccountCondition': {'@code': 'A3'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_98892b72-1a43-406d-8762-ffb0ae9cc86e'},
#   {'InitialPaymentLevelDate': '03012009',
#    'AccountCondition': {'@code': 'A3'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_9f2b4cab-ee1e-49d9-8f47-af04be81f50e'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_e0dc6cce-0514-47bc-87f5-75f8253c125b'},
#   {'InitialPaymentLevelDate': '06012017',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '92'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_712cd930-4373-4c6d-935c-5feb80cfbb6f'},
#   {'InitialPaymentLevelDate': '05012016',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '6D'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_8475efbe-a0ae-4bf2-8f9c-11ede57df8ba'},
#   {'InitialPaymentLevelDate': '11012015',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '89'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_75f0f771-6ce4-4183-af1b-ac58b46ccf28'},
#   {'InitialPaymentLevelDate': '10012015',
#    'AccountCondition': {'@code': 'A2'},
# ...
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_b1b89013-29e5-4b5a-ac10-63267184b862'},
#   {'InitialPaymentLevelDate': '06012009',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '18'},
#    'id': 'ep_5d9bcaec-95ef-40ae-88d3-691071e89da0'},
#   {'InitialPaymentLevelDate': '03012009',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_3752af47-3d8b-4a57-8fb6-945ec43ddee8'},
#   {'InitialPaymentLevelDate': '02012009',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_73da4a43-5b4c-462f-a217-1ec44f5172f7'},
#   {'InitialPaymentLevelDate': '02012009',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_8eda1167-ee2c-49a5-8c69-5fc6e4d6d09d'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_81e49e87-92a7-4f07-ba5d-d1dca3b974cc'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_a148fd66-95e3-4921-be25-3695dcf198a6'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_6ee93938-29d8-41a9-af02-503b38094c75'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_caaf2e8a-5208-400d-a639-3ac27f03a98b'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_267f679b-ef09-433c-b397-dfceb2b9a2fe'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_eb4640a1-2c81-499e-9e63-15add37c5be0'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_10d45db8-4acd-4f2b-a172-fac8fa6ad51a'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_5cf3ac69-5f81-4309-baf9-733f685ebf19'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_b42a69fe-1860-4c94-bee5-cc4e666cb1a4'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_aad0e97b-1dac-4fda-9716-71dec3f2f9c8'},
#   {'InitialPaymentLevelDate': '07012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '89'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_dccabaaf-cdb2-4bdf-a43a-3efc2ce1c1c8'}],
#  'tradeline_amounts': [{'Qualifier': {'@code': 'L'},
#    'Value': '00000350',
#    'id': 'am_7a879cb9-a2ec-426e-8457-560e3979e15b',
#    'TradeLine_id': 'tl_a8048731-3f84-4b95-be3c-1385527d59da'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000056',
#    'id': 'am_accaaec7-1f49-4316-b3f5-43638b7fdf8c',
#    'TradeLine_id': 'tl_a8048731-3f84-4b95-be3c-1385527d59da'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00011500',
#    'id': 'am_8c454bba-2ddd-4563-8ed0-767d0f665480',
#    'TradeLine_id': 'tl_44fc9b3c-35fd-4c17-a381-2a8e7d98d1b9'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00011440',
#    'id': 'am_65b25b5c-d5ec-4390-9233-eb3d04c789ae',
#    'TradeLine_id': 'tl_44fc9b3c-35fd-4c17-a381-2a8e7d98d1b9'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00012900',
#    'id': 'am_72a80688-93ed-44f4-b065-b1f939504760',
#    'TradeLine_id': 'tl_2b8e3773-0ac8-47e2-a0ed-e37739b1d666'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00008979',
#    'id': 'am_ff4e124f-e38d-435c-8644-6770b9922cea',
#    'TradeLine_id': 'tl_2b8e3773-0ac8-47e2-a0ed-e37739b1d666'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_c8ce9ceb-b799-4ece-8ec7-ad49f4fdec96',
#    'TradeLine_id': 'tl_33775e75-f79f-4d47-9d27-c88b04748b98'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_49560c5c-9353-4a91-a99a-992f03fa00ef',
#    'TradeLine_id': 'tl_33775e75-f79f-4d47-9d27-c88b04748b98'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_00b4c9ac-7e89-4876-af41-81d697574791',
#    'TradeLine_id': 'tl_2561c200-7542-4822-92ac-a99b73cddc01'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_7c799873-5e4f-4eda-b4ac-865873005e01',
#    'TradeLine_id': 'tl_2561c200-7542-4822-92ac-a99b73cddc01'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_ea252db8-9112-408b-b56d-c37c2d7aa0ce',
#    'TradeLine_id': 'tl_f304394d-eb98-40b2-b992-75d238a62548'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_263d5f83-a2ad-4390-829c-bb418f76d04a',
#    'TradeLine_id': 'tl_f304394d-eb98-40b2-b992-75d238a62548'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00010000',
#    'id': 'am_8da54404-4927-4e1c-89fa-772899f68677',
#    'TradeLine_id': 'tl_d96e5e5f-f708-4801-92f1-9cb088c39a53'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_b622a6a8-34e1-469e-a834-9fd3b5d8a7e5',
#    'TradeLine_id': 'tl_d96e5e5f-f708-4801-92f1-9cb088c39a53'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_1c65e26c-cdb4-4e7a-80a9-8f35ce3d6389',
#    'TradeLine_id': 'tl_c78051b4-685d-4bd1-9ef9-b6e611ad501e'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_d5903318-7e4d-4e57-9446-a135fe16ebd0',
#    'TradeLine_id': 'tl_c78051b4-685d-4bd1-9ef9-b6e611ad501e'},
#   {'Qualifier': {'@code': 'O'},
#    'Value': '00040000',
#    'id': 'am_d0abe263-9189-4ad0-8601-ecea7cf27bae',
#    'TradeLine_id': 'tl_da1b2a7a-744b-4b48-bdba-711dfa1c1826'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_699b9d30-b287-4de4-a07f-3431db7e22a0',
#    'TradeLine_id': 'tl_da1b2a7a-744b-4b48-bdba-711dfa1c1826'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00080000',
#    'id': 'am_126360aa-8338-4c95-a031-7ad607c80a3d',
#    'TradeLine_id': 'tl_ba0eec46-4eee-45bd-86df-191ab4290008'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00159087',
#    'id': 'am_dbd0cb11-5e94-49d8-bf3e-9baea85101d1',
#    'TradeLine_id': 'tl_ba0eec46-4eee-45bd-86df-191ab4290008'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000223',
#    'id': 'am_a195cce0-e795-4be2-b6b8-6a61b73106ad',
#    'TradeLine_id': 'tl_d92a2a02-ee3d-49a5-8d9e-49d052f7d6db'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_13906332-4290-4b26-bd2b-6b9117680e9c',
#    'TradeLine_id': 'tl_d92a2a02-ee3d-49a5-8d9e-49d052f7d6db'},
#   {'Qualifier': {'@code': 'O'},
#    'Value': '00150000',
#    'id': 'am_897a1345-86b7-48eb-bb42-ae5260865f76',
#    'TradeLine_id': 'tl_a6086b89-7083-4987-b789-cd21f7a48fa8'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_886bb4df-e8f9-41ae-b012-ddf2fc41f8f2',
#    'TradeLine_id': 'tl_a6086b89-7083-4987-b789-cd21f7a48fa8'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00007000',
#    'id': 'am_1a08cc3f-1085-4184-a92f-df1d70f2a209',
#    'TradeLine_id': 'tl_f142a78a-1abf-44f5-927f-6782702b857d'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000082',
#    'id': 'am_66887832-8ad7-415d-989a-3e19b8dc80c8',
#    'TradeLine_id': 'tl_f142a78a-1abf-44f5-927f-6782702b857d'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00007000',
#    'id': 'am_acbb374d-87cf-4549-b9af-5404a7568827',
#    'TradeLine_id': 'tl_9ec579c5-3f89-4f38-a80c-fe1e5f0e2871'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00007000',
#    'id': 'am_194513dc-a28b-4bca-aa7c-3e6c82eb840e',
#    'TradeLine_id': 'tl_9ec579c5-3f89-4f38-a80c-fe1e5f0e2871'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00010000',
#    'id': 'am_8a77939b-d74e-4ad1-8f7c-5496e18fc94c',
#    'TradeLine_id': 'tl_dd117a42-7e80-477a-856e-954afbab0d95'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00009434',
#    'id': 'am_c4b3a93a-405a-4c16-87a5-82fc1b4c80b9',
#    'TradeLine_id': 'tl_dd117a42-7e80-477a-856e-954afbab0d95'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00010000',
#    'id': 'am_f1446cac-cddd-4892-b317-2442543e2e28',
#    'TradeLine_id': 'tl_67f2ccc7-0cd8-4a36-8acf-b7d2bb00d57a'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00008982',
#    'id': 'am_8223725b-4156-40dd-bb35-223b2678a665',
#    'TradeLine_id': 'tl_67f2ccc7-0cd8-4a36-8acf-b7d2bb00d57a'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00000700',
#    'id': 'am_692aa990-f408-4847-9439-fdc8741f598c',
#    'TradeLine_id': 'tl_974517ed-22f4-4ceb-adc6-ff9c3abc138d'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000283',
#    'id': 'am_1393f0d8-8c88-4e42-99f0-fe39b156562c',
#    'TradeLine_id': 'tl_974517ed-22f4-4ceb-adc6-ff9c3abc138d'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_c92adfc0-784c-4b39-bdbc-6616f55ec8e2',
#    'TradeLine_id': 'tl_12dbd3e2-c74b-411d-91bd-e8c7731efdbe'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_69b8dec3-8298-4f80-8518-1261f1d53689',
#    'TradeLine_id': 'tl_12dbd3e2-c74b-411d-91bd-e8c7731efdbe'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00004072',
#    'id': 'am_5aaee276-9abe-4252-9dec-25bf54dbbbca',
#    'TradeLine_id': 'tl_95f9c1c2-7d1c-4898-975b-c5ade5980046'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_eb5b8583-44cb-4f78-b2e5-16788c7a363b',
#    'TradeLine_id': 'tl_95f9c1c2-7d1c-4898-975b-c5ade5980046'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00007000',
#    'id': 'am_8be87219-5f17-4f93-9b9f-1cbba7b9efac',
#    'TradeLine_id': 'tl_48990eb3-f09b-4362-b3a8-4c7a71230e09'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_fc7fb9dd-eac9-42ad-9129-6ccdd50e5bbb',
#    'TradeLine_id': 'tl_48990eb3-f09b-4362-b3a8-4c7a71230e09'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00007000',
#    'id': 'am_fdc701e6-f1fb-481d-8ea4-0549a3ee6dbd',
#    'TradeLine_id': 'tl_32171b92-b0d2-4088-b6e5-efefa72ba293'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00003813',
#    'id': 'am_c8bae4ce-9057-4417-ab4d-5a5b22176d21',
#    'TradeLine_id': 'tl_32171b92-b0d2-4088-b6e5-efefa72ba293'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00010000',
#    'id': 'am_1672149b-66a1-4595-ac98-d5dca95f7cdc',
#    'TradeLine_id': 'tl_f9e22d6f-56e6-48bf-adda-6430502bc2db'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00008679',
#    'id': 'am_f7c4feff-780e-418f-b972-499c0dcbb053',
#    'TradeLine_id': 'tl_f9e22d6f-56e6-48bf-adda-6430502bc2db'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00000500',
#    'id': 'am_40f5465d-b909-4e3d-81d8-604c621359ba',
#    'TradeLine_id': 'tl_160d3d3a-5482-48ff-a7a1-fdd0d722c394'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_b82c023d-73db-4339-be57-29bd496c703c',
#    'TradeLine_id': 'tl_160d3d3a-5482-48ff-a7a1-fdd0d722c394'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00012000',
#    'id': 'am_487e9ce7-aece-4bec-9c1b-9af20eeb39aa',
#    'TradeLine_id': 'tl_87dae5a5-575a-4461-a8af-9e225ae482c7'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00010020',
#    'id': 'am_afc718c4-ae35-4f03-b361-35dc467bdb69',
#    'TradeLine_id': 'tl_87dae5a5-575a-4461-a8af-9e225ae482c7'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00005000',
#    'id': 'am_d5c90402-4267-48f6-a9aa-a00cb96a20a9',
#    'TradeLine_id': 'tl_9f2d0202-ff3f-4e1b-a7f3-0c5fe1d58cfe'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_a88a6841-a276-440f-b719-fb2811041556',
#    'TradeLine_id': 'tl_9f2d0202-ff3f-4e1b-a7f3-0c5fe1d58cfe'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00006900',
#    'id': 'am_9eb265ef-23ab-46a1-b1a1-67de5be0841b',
#    'TradeLine_id': 'tl_6ed01ce1-022f-4f21-8b69-90ad27b75855'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00003032',
#    'id': 'am_cedffbbd-b570-4cfc-a28f-77af8557f471',
#    'TradeLine_id': 'tl_6ed01ce1-022f-4f21-8b69-90ad27b75855'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00001000',
#    'id': 'am_5ae1e464-4706-4553-8bbe-d21c5d1922a9',
#    'TradeLine_id': 'tl_c1d971d5-3430-4e69-8dd7-cb92b480630c'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000285',
#    'id': 'am_b85cc835-48a4-4c08-a123-f6b5e6bfea28',
#    'TradeLine_id': 'tl_c1d971d5-3430-4e69-8dd7-cb92b480630c'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00001500',
#    'id': 'am_73b5440b-c798-4c89-8e2a-dfbb6add0c82',
#    'TradeLine_id': 'tl_147172a1-743c-4698-ab52-6b902ddbf412'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000546',
#    'id': 'am_7b477696-628c-4b06-9911-3e69969349b2',
#    'TradeLine_id': 'tl_147172a1-743c-4698-ab52-6b902ddbf412'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00003600',
#    'id': 'am_6b0143c6-912f-4819-9ebd-c81b42cf10ec',
#    'TradeLine_id': 'tl_72a9c28a-cd57-4c77-aef8-11e1346e5197'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00001184',
#    'id': 'am_83550483-47d8-4eb7-b72a-5c682e86457d',
#    'TradeLine_id': 'tl_72a9c28a-cd57-4c77-aef8-11e1346e5197'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000723',
#    'id': 'am_0b671a81-2791-4589-ba24-237f60f70e82',
#    'TradeLine_id': 'tl_afd8c9c3-8e43-473e-a12c-ab646ddff091'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_8de3e871-f938-4477-841a-d8efd822de7c',
#    'TradeLine_id': 'tl_afd8c9c3-8e43-473e-a12c-ab646ddff091'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00019000',
#    'id': 'am_e21306fe-3b63-472b-8605-65f40cf3fd3d',
#    'TradeLine_id': 'tl_b9fdaeaa-d68f-4618-ac96-151bc59c7d36'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00010513',
#    'id': 'am_25d18aee-387f-4440-96b8-1b034ded4b19',
#    'TradeLine_id': 'tl_b9fdaeaa-d68f-4618-ac96-151bc59c7d36'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00012200',
#    'id': 'am_67837078-1d78-4d7a-bb37-30573ce32040',
#    'TradeLine_id': 'tl_4bd4839b-fdf8-446f-bc2d-bf6e6ec3b8ac'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000629',
#    'id': 'am_69479c2b-1906-481a-b259-20b7813c65be',
#    'TradeLine_id': 'tl_4bd4839b-fdf8-446f-bc2d-bf6e6ec3b8ac'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00001047',
#    'id': 'am_dafddc77-668b-4e40-afc0-90b78a495a9d',
#    'TradeLine_id': 'tl_c1a6f325-9920-4f2b-b401-4b1321f3ab11'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_95ea347b-92a6-4292-9e4d-e9e047dd4c1c',
#    'TradeLine_id': 'tl_c1a6f325-9920-4f2b-b401-4b1321f3ab11'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00007361',
#    'id': 'am_98d3b701-8d6e-44f5-a3ba-ff1539e2e2ad',
#    'TradeLine_id': 'tl_6e2788df-e422-4c06-a85e-5f0e8cb54153'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_9f2ad5b4-8c6f-429b-b275-b59414e4f28f',
#    'TradeLine_id': 'tl_6e2788df-e422-4c06-a85e-5f0e8cb54153'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00001500',
#    'id': 'am_08742584-7691-4343-a02c-111be90eac82',
#    'TradeLine_id': 'tl_b60b0b12-4145-41a4-89b7-b7519e9ad105'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000089',
#    'id': 'am_6ef98529-30e1-4eff-b33a-372d6c169ff9',
#    'TradeLine_id': 'tl_b60b0b12-4145-41a4-89b7-b7519e9ad105'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00150000',
#    'id': 'am_ca957c46-8a9a-415b-9ef1-7d80bfd49b3d',
#    'TradeLine_id': 'tl_fb2b9138-d1f9-49e1-a6ee-7cfa5f8c96ca'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00022118',
#    'id': 'am_3b6ed616-bd96-4863-ae62-e501037e6aa1',
#    'TradeLine_id': 'tl_fb2b9138-d1f9-49e1-a6ee-7cfa5f8c96ca'}]}

# %% [markdown]
# Parse XML data string and build XML_Detail table objects

# %%
RESULT_OBJ_DICT['trade_lines']
# Out:
# [{'OpenDate': '06011981',
#   'StatusDate': '05012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '05192017',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '15',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B00000000000000',
#   'MonthlyPaymentAmount': None,
#   'LastPaymentDate': '01032016',
#   'Subcode': '1401790',
#   'SubscriberDisplayName': 'CBNA',
#   'id': 'tl_a8048731-3f84-4b95-be3c-1385527d59da',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '28',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '05',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'OC',
#   'enhanced_pm_data_id': 'ep_20257bda-e2e3-49eb-a081-9815ac02ff6e'},
#  {'OpenDate': '08282007',
#   'StatusDate': '03012012',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '03182012',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '56',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B000000000000000000000000',
#   'Subcode': '1213727',
#   'SubscriberDisplayName': 'BK OF AMER',
#   'id': 'tl_44fc9b3c-35fd-4c17-a381-2a8e7d98d1b9',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '31',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '05',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_af2cf695-7db8-4533-8573-ca039fdac173'},
#  {'OpenDate': '06102006',
#   'StatusDate': '07012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '2'},
#   'BalanceDate': '07232017',
#   'BalanceAmount': '00000000',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '96',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B-0---------0---------CCC',
#   'MonthlyPaymentAmount': None,
#   'LastPaymentDate': '07212015',
#   'Subcode': '1230206',
#   'SubscriberDisplayName': 'BK OF AMER',
#   'id': 'tl_2b8e3773-0ac8-47e2-a0ed-e37739b1d666',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_465227ff-3595-40c9-9cd5-5685151a7052'},
#  {'OpenDate': '08282007',
#   'StatusDate': '03012012',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '04282012',
#   'BalanceAmount': '00000000',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '03',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B00',
#   'MonthlyPaymentAmount': None,
#   'LastPaymentDate': '01122010',
#   'Subcode': '1216268',
#   'SubscriberDisplayName': 'CITI',
#   'id': 'tl_33775e75-f79f-4d47-9d27-c88b04748b98',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '18',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_cba6aa6c-ce9a-448f-9db3-4f16530b3110'},
#  {'OpenDate': '03012002',
#   'StatusDate': '04012009',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '0'},
#   'BalanceDate': '04012009',
#   'BalanceAmount': '00000000',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '86',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B00--------0-----------00',
#   'MonthlyPaymentAmount': None,
#   'LastPaymentDate': '12102006',
#   'Subcode': '1439507',
#   'SubscriberDisplayName': 'CITI',
#   'id': 'tl_2561c200-7542-4822-92ac-a99b73cddc01',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'NZ',
#   'enhanced_pm_data_id': 'ep_98892b72-1a43-406d-8762-ffb0ae9cc86e'},
#  {'OpenDate': '03012007',
#   'StatusDate': '03012009',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '03282009',
#   'BalanceAmount': '00000000',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '26',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B-0---------0----------0',
#   'Subcode': '1216268',
#   'SubscriberDisplayName': 'CITI',
#   'id': 'tl_f304394d-eb98-40b2-b992-75d238a62548',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_9f2b4cab-ee1e-49d9-8f47-af04be81f50e'},
#  {'OpenDate': '04072017',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '08032017',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '04',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B00C',
#   'Subcode': '3278165',
#   'SubscriberDisplayName': 'CITI',
#   'id': 'tl_d96e5e5f-f708-4801-92f1-9cb088c39a53',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_e0dc6cce-0514-47bc-87f5-75f8253c125b'},
#  {'OpenDate': '09012016',
#   'StatusDate': '06012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '06282017',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'AccountNumber': '6037453215420',
#   'MonthsHistory': '01',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B',
#   'MonthlyPaymentAmount': None,
#   'LastPaymentDate': '06262017',
#   'Subcode': '1945962',
#   'SubscriberDisplayName': 'VERIZON NEW ENGLAND IN',
#   'id': 'tl_c78051b4-685d-4bd1-9ef9-b6e611ad501e',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '31',
#   'TermsDuration_code': '001',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'I',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'UT',
#   'enhanced_pm_data_id': 'ep_712cd930-4373-4c6d-935c-5feb80cfbb6f'},
#  {'OpenDate': '08122015',
#   'StatusDate': '05012016',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '05282016',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'AccountNumber': '15621485',
#   'MonthsHistory': '10',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'BCCCCCCCCC',
#   'Subcode': '2165670',
#   'SubscriberDisplayName': 'CITIZENS BANK',
#   'id': 'tl_da1b2a7a-744b-4b48-bdba-711dfa1c1826',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '31',
#   'TermsDuration_code': 'UNK',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'I',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BB',
#   'enhanced_pm_data_id': 'ep_8475efbe-a0ae-4bf2-8f9c-11ede57df8ba'},
#  {'OpenDate': '02182007',
#   'StatusDate': '11012015',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '2'},
#   'BalanceDate': '11282015',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '99',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B000CCCCCCCCCCCCCCCCCCCCC',
#   'Subcode': '2165670',
#   'SubscriberDisplayName': 'CITIZENS BANK',
#   'id': 'tl_ba0eec46-4eee-45bd-86df-191ab4290008',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '47',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BB',
#   'enhanced_pm_data_id': 'ep_75f0f771-6ce4-4183-af1b-ac58b46ccf28'},
#  {'OpenDate': '05011984',
#   'StatusDate': '10012015',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '10082015',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '01',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B',
#   'Subcode': '1229200',
#   'SubscriberDisplayName': 'AMEX',
#   'id': 'tl_d92a2a02-ee3d-49a5-8d9e-49d052f7d6db',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': '001',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_6655c501-9154-4d0d-aecb-73aa0ec9c6f1'},
#  {'OpenDate': '12142012',
#   'StatusDate': '08012015',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '2'},
#   'BalanceDate': '08282015',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'AccountNumber': '13750088',
#   'MonthsHistory': '33',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#   'Subcode': '2165670',
#   'SubscriberDisplayName': 'CITIZENS BANK',
#   'id': 'tl_a6086b89-7083-4987-b789-cd21f7a48fa8',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '31',
#   'TermsDuration_code': '180',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'I',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BB',
#   'enhanced_pm_data_id': 'ep_9f9ef110-3a29-42ee-b937-1db4f60b1160'},
#  {'OpenDate': '10202007',
#   'StatusDate': '11012012',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '11102012',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '68',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B000000000000000000000000',
#   'Subcode': '3278165',
#   'SubscriberDisplayName': 'CITI',
#   'id': 'tl_f142a78a-1abf-44f5-927f-6782702b857d',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '18',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_b7271a8a-6dfc-480a-9d11-886585594caa'},
#  {'OpenDate': '10202007',
#   'StatusDate': '10012011',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '10282011',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '49',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B000000000000000000000000',
#   'Subcode': '1220390',
#   'SubscriberDisplayName': 'BANK CREDIT CARD',
#   'id': 'tl_9ec579c5-3f89-4f38-a80c-fe1e5f0e2871',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_4e6c0f08-853d-49f7-a044-4166daf0612e'},
#  {'OpenDate': '01012007',
#   'StatusDate': '07012011',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '07282011',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '56',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B000000000000000000CCCCCC',
#   'Subcode': '1290016',
#   'SubscriberDisplayName': 'BANK CREDIT CARD',
#   'id': 'tl_dd117a42-7e80-477a-856e-954afbab0d95',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_d2bcabb0-7fee-48fe-9ce6-5b318eb0f841'},
#  {'OpenDate': '01092008',
#   'StatusDate': '06012011',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '3'},
#   'BalanceDate': '06082011',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '32',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B00000000000000CCCCCCCCCC',
#   'Subcode': '1290138',
#   'SubscriberDisplayName': 'BANK CREDIT CARD',
#   'id': 'tl_67f2ccc7-0cd8-4a36-8acf-b7d2bb00d57a',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_e545f9d7-0397-40d5-b818-3526372cb16c'},
#  {'OpenDate': '01082006',
#   'StatusDate': '02012011',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '2'},
#   'BalanceDate': '02282011',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '62',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B0000000000000000--------',
#   'Subcode': '6230125',
#   'SubscriberDisplayName': 'BAC/FLEET-BKCARD',
#   'id': 'tl_974517ed-22f4-4ceb-adc6-ff9c3abc138d',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '18',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_70e033c2-b9eb-4694-b7de-c7419726a390'},
#  {'OpenDate': '09242005',
#   'StatusDate': '11012010',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '3'},
#   'BalanceDate': '11282010',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '60',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B000000000000000000000000',
#   'Subcode': '1260958',
#   'SubscriberDisplayName': 'BANK CREDIT CARD',
#   'id': 'tl_12dbd3e2-c74b-411d-91bd-e8c7731efdbe',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_d2395fa4-8288-41a9-9837-84b39196fcce'},
#  {'OpenDate': '09102007',
#   'StatusDate': '03012010',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '03072010',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '30',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B00000000000000000CCCCCCC',
#   'Subcode': '3245600',
#   'SubscriberDisplayName': 'BANK CREDIT CARD',
#   'id': 'tl_95f9c1c2-7d1c-4898-975b-c5ade5980046',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_17203bb9-b0a0-4ee6-a7a3-357ecbe1cdb8'},
#  {'OpenDate': '09262007',
#   'StatusDate': '12012009',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '2'},
#   'BalanceDate': '12282009',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '12',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'BCCCCCCCCCCC',
#   'Subcode': '3278165',
#   'SubscriberDisplayName': 'CITI',
#   'id': 'tl_48990eb3-f09b-4362-b3a8-4c7a71230e09',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_f971c147-399a-4ce1-9a53-215a94896ecb'},
#  {'OpenDate': '09262007',
#   'StatusDate': '12012009',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '2'},
#   'BalanceDate': '12282009',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '25',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#   'Subcode': '3278165',
#   'SubscriberDisplayName': 'CITI',
#   'id': 'tl_32171b92-b0d2-4088-b6e5-efefa72ba293',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_b1b89013-29e5-4b5a-ac10-63267184b862'},
#  {'OpenDate': '04222005',
#   'StatusDate': '06012009',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '06282009',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '25',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#   'Subcode': '1201520',
#   'SubscriberDisplayName': 'BANK CREDIT CARD',
#   'id': 'tl_f9e22d6f-56e6-48bf-adda-6430502bc2db',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '18',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_5d9bcaec-95ef-40ae-88d3-691071e89da0'},
#  {'OpenDate': '01072008',
#   'StatusDate': '03012009',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '03012009',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '14',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'BCCCCCCCCCCCCC',
#   'Subcode': '1202270',
#   'SubscriberDisplayName': 'WF/WB',
#   'id': 'tl_160d3d3a-5482-48ff-a7a1-fdd0d722c394',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BB',
#   'enhanced_pm_data_id': 'ep_3752af47-3d8b-4a57-8fb6-945ec43ddee8'},
#  {'OpenDate': '02282004',
#   'StatusDate': '02012009',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '02282009',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '61',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'BCCCCCCCCCCC00000000CCCCC',
#   'Subcode': '1270583',
#   'SubscriberDisplayName': 'CHASE NA',
#   'id': 'tl_87dae5a5-575a-4461-a8af-9e225ae482c7',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '19',
#   'Evaluation_code': 'N',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_73da4a43-5b4c-462f-a217-1ec44f5172f7'},
#  {'OpenDate': '02151994',
#   'StatusDate': '02012009',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '2'},
#   'BalanceDate': '02222009',
#   'BalanceAmount': None,
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '99',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'B---------------C--------',
#   'Subcode': '1270583',
#   'SubscriberDisplayName': 'CHASE NA',
#   'id': 'tl_9f2d0202-ff3f-4e1b-a7f3-0c5fe1d58cfe',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '12',
#   'OpenOrClosed_code': 'C',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_8eda1167-ee2c-49a5-8c69-5fc6e4d6d09d'},
#  {'OpenDate': '09072013',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '2'},
#   'BalanceDate': '08232017',
#   'BalanceAmount': '00000025',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '49',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'C0CCCCCCCCC000CCCCCCCCCCC',
#   'MonthlyPaymentAmount': '00000010',
#   'LastPaymentDate': '06082017',
#   'Subcode': '3178962',
#   'SubscriberDisplayName': 'CBNA',
#   'id': 'tl_6ed01ce1-022f-4f21-8b69-90ad27b75855',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '07',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': 'S',
#   'KOB_code': 'ZR',
#   'enhanced_pm_data_id': 'ep_81e49e87-92a7-4f07-ba5d-d1dca3b974cc'},
#  {'OpenDate': '09011979',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '08202017',
#   'BalanceAmount': '00000000',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '75',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': '000CCCCCCCCCCCCCCCCCCCCCC',
#   'MonthlyPaymentAmount': None,
#   'LastPaymentDate': '05092017',
#   'Subcode': '1335510',
#   'SubscriberDisplayName': 'SYNCB/EXXON MOBIL',
#   'id': 'tl_c1d971d5-3430-4e69-8dd7-cb92b480630c',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '07',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'OC',
#   'enhanced_pm_data_id': 'ep_a148fd66-95e3-4921-be25-3695dcf198a6'},
#  {'OpenDate': '06182013',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '08162017',
#   'BalanceAmount': '00000160',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '51',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0C',
#   'MonthlyPaymentAmount': '00000015',
#   'LastPaymentDate': '07272017',
#   'Subcode': '3308810',
#   'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#   'id': 'tl_147172a1-743c-4698-ab52-6b902ddbf412',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '07',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': 'S',
#   'KOB_code': 'DV',
#   'enhanced_pm_data_id': 'ep_6ee93938-29d8-41a9-af02-503b38094c75'},
#  {'OpenDate': '04272007',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '3'},
#   'BalanceDate': '08152017',
#   'BalanceAmount': '00000000',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '99',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': '000000000000000000CCCCCCC',
#   'MonthlyPaymentAmount': None,
#   'LastPaymentDate': '12282015',
#   'Subcode': '3308810',
#   'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#   'id': 'tl_72a9c28a-cd57-4c77-aef8-11e1346e5197',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '07',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'DV',
#   'enhanced_pm_data_id': 'ep_caaf2e8a-5208-400d-a639-3ac27f03a98b'},
#  {'OpenDate': '09012010',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '08142017',
#   'BalanceAmount': '00000000',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '84',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': '000000000000C000000000000',
#   'MonthlyPaymentAmount': None,
#   'LastPaymentDate': '08282016',
#   'Subcode': '1349040',
#   'SubscriberDisplayName': 'FILENES',
#   'id': 'tl_afd8c9c3-8e43-473e-a12c-ab646ddff091',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '07',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'ZR',
#   'enhanced_pm_data_id': 'ep_267f679b-ef09-433c-b397-dfceb2b9a2fe'},
#  {'OpenDate': '04011998',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '08092017',
#   'BalanceAmount': '00001354',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '97',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCCCC',
#   'MonthlyPaymentAmount': '00000015',
#   'LastPaymentDate': '07242017',
#   'Subcode': '1230206',
#   'SubscriberDisplayName': 'BK OF AMER',
#   'id': 'tl_b9fdaeaa-d68f-4618-ac96-151bc59c7d36',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': 'S',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_eb4640a1-2c81-499e-9e63-15add37c5be0'},
#  {'OpenDate': '06011983',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '08072017',
#   'BalanceAmount': '00000052',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '01',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'C',
#   'Subcode': '1229200',
#   'SubscriberDisplayName': 'AMEX',
#   'id': 'tl_4bd4839b-fdf8-446f-bc2d-bf6e6ec3b8ac',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_10d45db8-4acd-4f2b-a172-fac8fa6ad51a'},
#  {'OpenDate': '05011984',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '08072017',
#   'BalanceAmount': '00000599',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '01',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'C',
#   'Subcode': '1229200',
#   'SubscriberDisplayName': 'AMEX',
#   'id': 'tl_c1a6f325-9920-4f2b-b401-4b1321f3ab11',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '18',
#   'TermsDuration_code': '001',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_5cf3ac69-5f81-4309-baf9-733f685ebf19'},
#  {'OpenDate': '05011984',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '08072017',
#   'BalanceAmount': '00001960',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '01',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'C',
#   'Subcode': '1229200',
#   'SubscriberDisplayName': 'AMEX',
#   'id': 'tl_6e2788df-e422-4c06-a85e-5f0e8cb54153',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '18',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': '',
#   'KOB_code': 'BC',
#   'enhanced_pm_data_id': 'ep_b42a69fe-1860-4c94-bee5-cc4e666cb1a4'},
#  {'OpenDate': '08182016',
#   'StatusDate': '08012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '08072017',
#   'BalanceAmount': '00000000',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '12',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': '0000000000CC',
#   'MonthlyPaymentAmount': None,
#   'LastPaymentDate': '09192016',
#   'Subcode': '2613430',
#   'SubscriberDisplayName': 'SYNCB/BROOK BROS',
#   'id': 'tl_b60b0b12-4145-41a4-89b7-b7519e9ad105',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '07',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'CG',
#   'enhanced_pm_data_id': 'ep_aad0e97b-1dac-4fda-9716-71dec3f2f9c8'},
#  {'OpenDate': '08122015',
#   'StatusDate': '07012017',
#   'MaxDelinquencyDate': None,
#   'ECOA': {'@code': '1'},
#   'BalanceDate': '07282017',
#   'BalanceAmount': '00004607',
#   'AmountPastDue': None,
#   'ConsumerComment': None,
#   'MonthsHistory': '24',
#   'DelinquenciesOver30Days': '00',
#   'DelinquenciesOver60Days': '00',
#   'DelinquenciesOver90Days': '00',
#   'DerogCounter': '00',
#   'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0',
#   'MonthlyPaymentAmount': 'UNKNOWN',
#   'LastPaymentDate': '07102017',
#   'Subcode': '2165670',
#   'SubscriberDisplayName': 'CITIZENS BANK',
#   'id': 'tl_fb2b9138-d1f9-49e1-a6ee-7cfa5f8c96ca',
#   'CreditProfile_id': 'cp_2ed1f349-8511-407c-bf4d-65e4a9d6f2e0',
#   'SpecialComment_code': '  ',
#   'Evaluation_code': 'P',
#   'AccountType_code': '47',
#   'TermsDuration_code': 'REV',
#   'Status_code': '11',
#   'OpenOrClosed_code': 'O',
#   'RevolvingOrInstallment_code': 'R',
#   'MonthlyPaymentType_code': ' ',
#   'KOB_code': 'BB',
#   'enhanced_pm_data_id': 'ep_dccabaaf-cdb2-4bdf-a43a-3efc2ce1c1c8'}]
