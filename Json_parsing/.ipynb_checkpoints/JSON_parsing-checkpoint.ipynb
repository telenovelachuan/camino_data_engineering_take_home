# %%
import json
import pprint
import uuid
import xmltodict
import datetime
from dateutil import parser
import pandas as pd

pd.set_option('display.max_rows', 10)
RESULT_TABLE_NAMES = ['prequal_results', 'xml_details', 'products', 'credit_profiles', 'headers', 'risk_models', 'consumer_identities', 'addr_infos', 'employ_infos', 'trade_lines', 'inquiries', 'info_msgs', 'enhanced_pm_data', 'tradeline_amounts']
with open("./data/prequalresult.json", 'r') as f:
    json_file = json.load(f)

# %% [markdown]
# Parse XML data string and build the internal objects into the designed tables

# %%
# initialize result object lists
RESULT_OBJ_DICT = dict((key, []) for key in RESULT_TABLE_NAMES)
ATTR_CODE_DICT = {
    'risk_models': ['ModelIndicator', 'Evaluation'],
    'addr_infos': ['Origination', 'DwellingType', 'HomeOwnership'],
    'employ_infos': ['Origination'],
    'trade_lines': ['SpecialComment', 'Evaluation', 'AccountType', 'TermsDuration', 'Status', 'ECOA', 'OpenOrClosed', 'RevolvingOrInstallment', 'MonthlyPaymentType', 'KOB'],
    'tradeline_amounts': ['Qualifier'],
    'enhanced_pm_data': ['AccountCondition', 'PaymentStatus', 'AccountType', 'SpecialComment'],
    'inquiries': ['Type', 'Terms', 'KOB'],
}
DATE_ATTR_DICT = {
    'prequal_results': {'long': ['created_at', 'bkdate']},
    'headers': {'short': ['ReportDate']},
    'addr_infos': {'short': ['FirstReportedDate', 'LastUpdatedDate']},
    'employ_infos': {'short': ['FirstReportedDate', 'LastUpdatedDate']},
    'trade_lines': {'short': ['OpenDate', 'StatusDate', 'MaxDelinquencyDate', 'BalanceDate', 'LastPaymentDate']},
    'enhanced_pm_data': {'short': ['InitialPaymentLevelDate']},
    'inquiries': {'short': ['Date']}
}

# parse string into date
def parse_to_date(input_str, mode='short'):
    if mode == 'short':
        year, month, day = int(input_str[-4:]), int(input_str[:2]), int(input_str[2:4])
        return datetime.datetime(year, month, day)
    else:
        return parser.parse(input_str)

prequal_results = json_file
for prequal_result in prequal_results:
    prequal_result.update(prequal_result.pop('fields'))
    prequal_result['created_at'] = parser.parse(prequal_result['created_at'])
    xml_detail_id = "xd_{}".format(uuid.uuid4())
    prequal_result['xml_detail_id'] = xml_detail_id
    RESULT_OBJ_DICT['prequal_results'].append(prequal_result)
    
    # initializing XML_Detail object
    xml_dict = xmltodict.parse(result['xml_data'], dict_constructor=dict)['NetConnectResponse']
    xml_dict['id'] = xml_detail_id
    RESULT_OBJ_DICT['xml_details'].append(xml_dict)
    product_id = "pd_{}".format(uuid.uuid4())
    xml_dict['product_id'] = product_id
    
    # initializing Product object
    product_obj = xml_dict.pop('Products')
    product_obj['id'] = product_id
    RESULT_OBJ_DICT['products'].append(product_obj)
    credit_profile_id = "cp_{}".format(uuid.uuid4())
    product_obj['credit_profile_id'] = credit_profile_id
    
    # initializing CreditProfile object
    credit_profile_obj = product_obj.pop('CreditProfile')
    credit_profile_obj['id'] = credit_profile_id
    RESULT_OBJ_DICT['credit_profiles'].append(credit_profile_obj)
    
    
    ## handling RiskModels in CreditProfile
    for risk_model in credit_profile_obj.pop('RiskModel'):
        risk_model['id'] = "rm_{}".format(uuid.uuid4())
        risk_model['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['risk_models'].append(risk_model)
    
    # initializing Header object in CreditProfile
    header_id = "hd_{}".format(uuid.uuid4())
    credit_profile_obj['header_id'] = header_id
    header_obj = credit_profile_obj.pop('Header')
    header_obj['id'] = header_id
    RESULT_OBJ_DICT['headers'].append(header_obj)
    
    ## handling ConsumerIdentities in CreditProfile
    name_attrs = ['Surname', 'First', 'Middle', 'Gen']
    for consumer_identity in credit_profile_obj.pop('ConsumerIdentity'):
        consumer_identity['id'] = "ci_{}".format(uuid.uuid4())
        for name_attr in name_attrs:
            if name_attr in consumer_identity['Name']:
                attr_v = consumer_identity['Name'][name_attr]
            else:
                attr_v = ''
            consumer_identity[name_attr] = attr_v
        consumer_identity['YOB'] = consumer_identity['YOB']
        if 'Type' in consumer_identity['Name']:
            name_type_code = consumer_identity['Name']['Type']['@code']
        else:
            name_type_code = ''
        consumer_identity['NameType_code'] = name_type_code
        del consumer_identity['Name']
        consumer_identity['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['consumer_identities'].append(consumer_identity)
    
    ## handling AddressInformations in CreditProfile
    for addr_info in credit_profile_obj.pop('AddressInformation'):
        addr_info['id'] = "ai_{}".format(uuid.uuid4())
        addr_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['addr_infos'].append(addr_info)
       
    ## handling EmploymentInformations in CreditProfile
    for employ_info in credit_profile_obj.pop('EmploymentInformation'):
        employ_info['id'] = "ei_{}".format(uuid.uuid4())
        employ_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['employ_infos'].append(employ_info)
        
    ## handling TradeLines in CreditProfile
    code_attrs = ['SpecialComment', 'Evaluation', 'AccountType', 'TermsDuration', 'Status', 'OpenOrClosed', 'RevolvingOrInstallment', 'MonthlyPaymentType', 'KOB']
    for trade_line in credit_profile_obj.pop('TradeLine'):
        trade_line['id'] = "tl_{}".format(uuid.uuid4())
        trade_line['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['trade_lines'].append(trade_line)
        
        # initializing EnhancedPaymentData object in TradeLine
        enhanced_pm_data_id = "ep_{}".format(uuid.uuid4())
        trade_line['enhanced_pm_data_id'] = enhanced_pm_data_id
        enhanced_pm_data_obj = trade_line.pop('EnhancedPaymentData')
        enhanced_pm_data_obj['id'] = enhanced_pm_data_id
        RESULT_OBJ_DICT['enhanced_pm_data'].append(enhanced_pm_data_obj)
        
        ## handling Amount object in TradeLine
        for amt_obj in trade_line.pop('Amount'):
            amt_obj['id'] = "am_{}".format(uuid.uuid4())
            amt_obj['TradeLine_id'] = trade_line['id']
            RESULT_OBJ_DICT['tradeline_amounts'].append(amt_obj)
    
    # initializing Inquiry object in CreditProfile
    inquiry_id = "iq_{}".format(uuid.uuid4())
    credit_profile_obj['inquiry_id'] = inquiry_id
    inquiry_obj = credit_profile_obj.pop('Inquiry')
    inquiry_obj['id'] = inquiry_id
    RESULT_OBJ_DICT['inquiries'].append(inquiry_obj)
    
    ## handling InformationalMessages in CreditProfile
    for info_msg in credit_profile_obj.pop('InformationalMessage'):
        info_msg['id'] = "im_{}".format(uuid.uuid4())
        info_msg['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['info_msgs'].append(info_msg)
    
# converting sub-attrs into underscore attrs
for attr, code_attr_list in ATTR_CODE_DICT.items():
    attr_obj_list = RESULT_OBJ_DICT[attr]
    for attr_obj in attr_obj_list:
        for attr in code_attr_list:
            if attr in attr_obj:
                code = attr_obj[attr]['@code']
            else:
                code = ''
            attr_obj["{}_code".format(attr)] = code
            attr_obj.pop(attr, None)
    
RESULT_OBJ_DICT
# Out:
# {'prequal_results': [{'model': 'common.prequalresult',
#    'pk': 1,
#    'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': datetime.datetime(2016, 8, 4, 0, 29, 3, 67000, tzinfo=tzutc()),
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant',
#    'xml_detail_id': 'xd_1173c369-4b11-49fd-a258-ee505f5311f4'}],
#  'xml_details': [{'@xmlns': 'http://www.experian.com/NetConnectResponse',
#    'CompletionCode': '0000',
#    'ReferenceId': 'testing 123',
#    'TransactionId': '41588980',
#    'id': 'xd_1173c369-4b11-49fd-a258-ee505f5311f4',
#    'product_id': 'pd_4433ee32-3163-4bf6-b838-3a8f1d637f96'}],
#  'products': [{'@xmlns': 'http://www.experian.com/ARFResponse',
#    'id': 'pd_4433ee32-3163-4bf6-b838-3a8f1d637f96',
#    'credit_profile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534'}],
#  'credit_profiles': [{'id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'header_id': 'hd_b11e6c87-36f4-4454-b5af-0f0f41ce67fb',
#    'inquiry_id': 'iq_29027527-e955-4795-a4a2-ba7fff3b3b80'}],
#  'headers': [{'ReportDate': '10032017',
#    'ReportTime': '140607',
#    'Preamble': 'TWA1',
#    'ARFVersion': '07',
#    'id': 'hd_b11e6c87-36f4-4454-b5af-0f0f41ce67fb'}],
#  'risk_models': [{'Score': '0808',
#    'ScoreFactorCodeOne': '10',
#    'ScoreFactorCodeTwo': '09',
#    'ScoreFactorCodeThree': '05',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_86d7cf54-a8f1-41e2-b573-de22b987ae89',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'ModelIndicator_code': 'F ',
#    'Evaluation_code': 'P'},
#   {'Score': '0807',
#    'ScoreFactorCodeOne': '30',
#    'ScoreFactorCodeTwo': '05',
#    'ScoreFactorCodeThree': '11',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_53d48793-a368-436f-af3e-458e9f636c2e',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'ModelIndicator_code': 'AA',
#    'Evaluation_code': 'P'}],
#  'consumer_identities': [{'YOB': None,
#    'id': 'ci_659e4d28-3ca3-4cb3-97cd-a5405b8ac46a',
#    'Surname': 'SCALICI',
#    'First': 'WILLIAM',
#    'Middle': '',
#    'Gen': '',
#    'NameType_code': '',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534'},
#   {'YOB': None,
#    'id': 'ci_3e3eb020-5f07-46bb-9400-cb39ccbe89b0',
#    'Surname': 'SCALICI',
#    'First': 'AS',
#    'Middle': 'WILLIAM',
#    'Gen': '',
#    'NameType_code': 'N',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534'},
#   {'YOB': None,
#    'id': 'ci_2fa789c4-ce48-4e6a-a559-693162fc84f3',
#    'Surname': 'SCALICI',
#    'First': 'WILLIAM',
#    'Middle': '',
#    'Gen': 'JR',
#    'NameType_code': '',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534'},
#   {'YOB': None,
#    'id': 'ci_557ebb77-3ff9-456a-949b-e2faa31e39b3',
#    'Surname': 'ANTHONY',
#    'First': 'WILLIAM',
#    'Middle': 'R',
#    'Gen': '',
#    'NameType_code': 'A',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534'}],
#  'addr_infos': [{'FirstReportedDate': '10272003',
#    'LastUpdatedDate': '12202015',
#    'TimesReported': '00',
#    'LastReportingSubcode': '7370142',
#    'StreetPrefix': '7324',
#    'StreetName': '84TH STREET',
#    'StreetSuffix': 'CT SW',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984986380',
#    'CensusGeoCode': None,
#    'id': 'ai_24e59593-9779-4eae-8c58-c452c48240e1',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'Origination_code': '2',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '01012011',
#    'LastUpdatedDate': '01012011',
#    'TimesReported': '00',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3260 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_50a010f4-c29c-451f-aec2-8c9d1f7592e8',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '05282006',
#    'LastUpdatedDate': '11022010',
#    'TimesReported': '12',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3216 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_b66d6a29-5181-47f6-b741-de46c28def4a',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '}],
#  'employ_infos': [{'FirstReportedDate': '04082011',
#    'LastUpdatedDate': '04082011',
#    'Name': 'GM RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_501b289d-68ed-4275-947a-3373c53cccea',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'Origination_code': '2'},
#   {'FirstReportedDate': '12282009',
#    'LastUpdatedDate': '06112010',
#    'Name': 'RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_2dffc4e1-8ef3-4ca2-94d8-b7a652ebe1bb',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'Origination_code': '2'}],
#  'trade_lines': [{'OpenDate': '06011981',
#    'StatusDate': '05012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '05192017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '15',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01032016',
#    'Subcode': '1401790',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_c59bfc92-2d17-423c-b01e-d072c38136aa',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_1ed0e6e6-d77a-48b2-87ed-f45867320347',
#    'SpecialComment_code': '28',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03182012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1213727',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_bb6c59d2-90fe-4a9d-8b2c-5a054ef2bc2e',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_82edee0b-4836-4b64-a58b-96fadb3990cd',
#    'SpecialComment_code': '31',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '06102006',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '07232017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '96',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0---------CCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '07212015',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_f326731d-303f-4ef5-a3f0-3c2d53cc2570',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_3c3d8540-fb3d-4267-b7a8-e0cd9e93daee',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '04282012',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '03',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01122010',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_c1b9e084-ab63-43ba-8dc2-02c2415cc20e',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_17cdbf37-ccd0-4503-94c6-d7217361cccb',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC'},
#   {'OpenDate': '03012002',
#    'StatusDate': '04012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '04012009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '86',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00--------0-----------00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12102006',
#    'Subcode': '1439507',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_cd648f49-3dab-4f87-9348-4cfcd605067e',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_3d191bcf-2cb1-463b-8b66-4f65290edc6c',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '0',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'NZ'},
#   {'OpenDate': '03012007',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03282009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '26',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0----------0',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_012bdde7-2519-4e1c-b3b4-a3a4c0c7440c',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_f4c35992-d689-4173-a5ce-62024b332ef4',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '04072017',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08032017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '04',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00C',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_482daa4b-eae6-4031-bcf7-177d6e5e8feb',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_ea33a43f-6f99-4cb2-aa9e-5aa16960cb7c',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09012016',
#    'StatusDate': '06012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '06282017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '6037453215420',
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '06262017',
#    'Subcode': '1945962',
#    'SubscriberDisplayName': 'VERIZON NEW ENGLAND IN',
#    'id': 'tl_5c0c6627-17b0-4c67-b46a-efd68903074f',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_c40ac8bb-9e31-4587-b2b6-f33d9256e5c1',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '31',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'UT'},
#   {'OpenDate': '08122015',
#    'StatusDate': '05012016',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '05282016',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '15621485',
#    'MonthsHistory': '10',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_d033235e-5fa4-4509-b673-29d10cccec52',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_0623cf9d-e975-479c-bc6b-306439cbd655',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': 'UNK',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '02182007',
#    'StatusDate': '11012015',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '11282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000CCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_232af7d7-b81d-4e4d-9661-503e06e5df26',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_ae0a35f5-f230-44cc-9b11-c82c3eee5b49',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '05011984',
#    'StatusDate': '10012015',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '10082015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_f126d305-3f43-43e5-8b68-23b4eb0afe64',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_745f20be-3b1f-4a9b-aee9-3e34ecc79664',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '12142012',
#    'StatusDate': '08012015',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '13750088',
#    'MonthsHistory': '33',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_5bc031bf-aef6-4f46-8835-67214bffc606',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_9b47ba3f-124b-431f-84a1-966307d56611',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': '180',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '10202007',
#    'StatusDate': '11012012',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '11102012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '68',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_5b2918d3-ccb6-4adb-a429-eff3d63ffce6',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_ad25a152-295d-4aa3-b2d8-062c481da6ad',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '10202007',
#    'StatusDate': '10012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '10282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1220390',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_dee654e5-66cd-453b-a78b-393765aa5c76',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_e2a44acc-5c92-47d0-be6b-0905b5b2641d',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01012007',
#    'StatusDate': '07012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '07282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000CCCCCC',
#    'Subcode': '1290016',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_c5219d3a-7bc3-4856-b106-b14ecb490865',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_34b1df3b-a3ca-466b-ac49-f9c1703c6d2c',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01092008',
#    'StatusDate': '06012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '06082011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '32',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000CCCCCCCCCC',
#    'Subcode': '1290138',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_967ef288-d037-475a-adf6-487331843c84',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_456d492c-cb4a-4d51-8872-f5645abc55b9',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '3',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01082006',
#    'StatusDate': '02012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '02282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '62',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B0000000000000000--------',
#    'Subcode': '6230125',
#    'SubscriberDisplayName': 'BAC/FLEET-BKCARD',
#    'id': 'tl_2c7fc2d3-b6fc-4c57-806e-7b8a47f03442',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_23c9b436-e370-45de-99dc-2e05b901a5d4',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09242005',
#    'StatusDate': '11012010',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '11282010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '60',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1260958',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_25bf5ea2-216d-4b00-b6b9-3d7ef0840725',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_8f634ddb-8c93-4c4e-a880-84fe231277db',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '3',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09102007',
#    'StatusDate': '03012010',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03072010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '30',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000000CCCCCCC',
#    'Subcode': '3245600',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_b68a94e7-6fbf-471c-909a-86f0e8aa06e2',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_3662c8b2-fb26-49e3-a7cd-f862ce431470',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_524f5bfb-9bb6-45cc-9c0b-e22160bed12e',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_9a1e0e4a-8574-422b-b93c-a6f8dfeec6f5',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_9e599b89-8fe9-47af-b0f0-8328223acbc6',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_894a651e-23a3-4ff7-accd-d08775cd14ef',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '04222005',
#    'StatusDate': '06012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '06282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '1201520',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_9db3b36b-f2ff-4c8a-a651-a75aa59fff33',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_cac8b770-92a8-40eb-91c1-1d5de87a6bae',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01072008',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03012009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '14',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCC',
#    'Subcode': '1202270',
#    'SubscriberDisplayName': 'WF/WB',
#    'id': 'tl_0c78c5e5-f7c8-4d1c-b009-cc5867e41009',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_6f5ef355-e26d-4966-9b56-79586d52c819',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '02282004',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '02282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '61',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC00000000CCCCC',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_07e04fac-d403-4ada-b3d3-a65c0c6e6310',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_75be4309-c14d-44b4-b79f-6c5b99330cbc',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '02151994',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '02222009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B---------------C--------',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_4a997077-a8e5-4d58-96e9-cd4d152abf61',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_aac2db09-d9d9-4bb5-8e3c-8545e62ffdd5',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09072013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08232017',
#    'BalanceAmount': '00000025',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C0CCCCCCCCC000CCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000010',
#    'LastPaymentDate': '06082017',
#    'Subcode': '3178962',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_b5da229a-a012-427c-bcf3-f42c70063ebb',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_b7fde874-39fd-4b18-8b22-33fcb74fd5ad',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'ZR'},
#   {'OpenDate': '09011979',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08202017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '75',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000CCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '05092017',
#    'Subcode': '1335510',
#    'SubscriberDisplayName': 'SYNCB/EXXON MOBIL',
#    'id': 'tl_5ea102ad-bdde-4791-ab6d-a0351049dc8e',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_48c05299-5075-4ecb-8221-6358ea69b5b6',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC'},
#   {'OpenDate': '06182013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08162017',
#    'BalanceAmount': '00000160',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '51',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0C',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07272017',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_06706504-a9b9-43ba-a6e9-61f52f6c9088',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_fd228350-11df-422a-8712-3bf6abde6096',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'DV'},
#   {'OpenDate': '04272007',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08152017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000000000CCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12282015',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_33b8b631-0d8f-4f23-9f05-96d416003e43',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_11c46258-1d03-4af4-90cc-d986b984bfd0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '3',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'DV'},
#   {'OpenDate': '09012010',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08142017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '84',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000C000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '08282016',
#    'Subcode': '1349040',
#    'SubscriberDisplayName': 'FILENES',
#    'id': 'tl_87adfb3e-0e8a-432c-b8bb-2f0eaf677486',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_e2b2e297-288f-473a-9454-41680a6bb007',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'ZR'},
#   {'OpenDate': '04011998',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08092017',
#    'BalanceAmount': '00001354',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '97',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07242017',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_be534cc3-1796-4297-8bf6-338de9ea74da',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_9c381785-1759-4d14-95f8-eb273d67c863',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'BC'},
#   {'OpenDate': '06011983',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000052',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_7617fb86-0514-4d4f-b8e2-e6a9760b154c',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_ac27790b-a752-496c-b6dc-458b4a8172ef',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000599',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_18479f02-9183-4665-a330-4878b350d94a',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_7d4289f4-a434-42f3-a3e8-acd1b1db4062',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00001960',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_96ee80e6-414d-48db-a58b-8efad0b0afd8',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_05497fd1-461c-4347-abb0-363a907c6429',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '08182016',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '0000000000CC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '09192016',
#    'Subcode': '2613430',
#    'SubscriberDisplayName': 'SYNCB/BROOK BROS',
#    'id': 'tl_1cae8438-caae-459c-b2d7-487a30ce5b09',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_5311c3db-fb9f-448d-a0b1-0fbad5fd29a8',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'CG'},
#   {'OpenDate': '08122015',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '07282017',
#    'BalanceAmount': '00004607',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '24',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0',
#    'MonthlyPaymentAmount': 'UNKNOWN',
#    'LastPaymentDate': '07102017',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_ae14fdb2-9a2d-455b-993a-480f910750c0',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534',
#    'enhanced_pm_data_id': 'ep_68266956-8e92-4bf8-904a-531e1e0eb69b',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BB'}],
#  'inquiries': [{'Date': '08182016',
#    'Amount': 'UNKNOWN',
#    'Subcode': '1640007',
#    'SubscriberDisplayName': 'SYNCB/BROOKS BROS',
#    'id': 'iq_29027527-e955-4795-a4a2-ba7fff3b3b80',
#    'Type_code': '31',
#    'Terms_code': 'UNK',
#    'KOB_code': 'FF'}],
#  'info_msgs': [{'MessageNumber': '92',
#    'MessageText': '0092 REQUESTED PRODUCT OPTION NOT ALLOWED',
#    'id': 'im_41eff5b9-ad3e-4f1c-911e-4d22c8908aba',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534'},
#   {'MessageNumber': '84',
#    'MessageText': '0084 SSN MATCHES',
#    'id': 'im_606033f4-abde-4c2d-9fe0-417dfefdac12',
#    'CreditProfile_id': 'cp_c9c74068-54f0-4156-8aea-03b0034e7534'}],
#  'enhanced_pm_data': [{'InitialPaymentLevelDate': '05012017',
#    'id': 'ep_1ed0e6e6-d77a-48b2-87ed-f45867320347',
#    'AccountCondition_code': '05',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '51'},
#   {'InitialPaymentLevelDate': '03012012',
#    'id': 'ep_82edee0b-4836-4b64-a58b-96fadb3990cd',
#    'AccountCondition_code': '05',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '40'},
#   {'InitialPaymentLevelDate': '07012017',
#    'id': 'ep_3c3d8540-fb3d-4267-b7a8-e0cd9e93daee',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012012',
#    'id': 'ep_17cdbf37-ccd0-4503-94c6-d7217361cccb',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '18'},
#   {'InitialPaymentLevelDate': '04012009',
#    'id': 'ep_3d191bcf-2cb1-463b-8b66-4f65290edc6c',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012009',
#    'id': 'ep_f4c35992-d689-4173-a5ce-62024b332ef4',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_ea33a43f-6f99-4cb2-aa9e-5aa16960cb7c',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '06012017',
#    'id': 'ep_c40ac8bb-9e31-4587-b2b6-f33d9256e5c1',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '92',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '05012016',
#    'id': 'ep_0623cf9d-e975-479c-bc6b-306439cbd655',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '6D',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '11012015',
#    'id': 'ep_ae0a35f5-f230-44cc-9b11-c82c3eee5b49',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '89',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '10012015',
#    'id': 'ep_745f20be-3b1f-4a9b-aee9-3e34ecc79664',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '08012015',
#    'id': 'ep_9b47ba3f-124b-431f-84a1-966307d56611',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '6D',
#    'SpecialComment_code': '  '},
# ...
#    'id': 'ep_8f634ddb-8c93-4c4e-a880-84fe231277db',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012010',
#    'id': 'ep_3662c8b2-fb26-49e3-a7cd-f862ce431470',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '12012009',
#    'id': 'ep_9a1e0e4a-8574-422b-b93c-a6f8dfeec6f5',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '12012009',
#    'id': 'ep_894a651e-23a3-4ff7-accd-d08775cd14ef',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '06012009',
#    'id': 'ep_cac8b770-92a8-40eb-91c1-1d5de87a6bae',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '18'},
#   {'InitialPaymentLevelDate': '03012009',
#    'id': 'ep_6f5ef355-e26d-4966-9b56-79586d52c819',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '02012009',
#    'id': 'ep_75be4309-c14d-44b4-b79f-6c5b99330cbc',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '02012009',
#    'id': 'ep_aac2db09-d9d9-4bb5-8e3c-8545e62ffdd5',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_b7fde874-39fd-4b18-8b22-33fcb74fd5ad',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_48c05299-5075-4ecb-8221-6358ea69b5b6',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_fd228350-11df-422a-8712-3bf6abde6096',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_11c46258-1d03-4af4-90cc-d986b984bfd0',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_e2b2e297-288f-473a-9454-41680a6bb007',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_9c381785-1759-4d14-95f8-eb273d67c863',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_ac27790b-a752-496c-b6dc-458b4a8172ef',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_7d4289f4-a434-42f3-a3e8-acd1b1db4062',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_05497fd1-461c-4347-abb0-363a907c6429',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_5311c3db-fb9f-448d-a0b1-0fbad5fd29a8',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '07012017',
#    'id': 'ep_68266956-8e92-4bf8-904a-531e1e0eb69b',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '89',
#    'SpecialComment_code': '  '}],
#  'tradeline_amounts': [{'Value': '00000350',
#    'id': 'am_4d217420-12b3-4975-ba42-1f5f3c87a601',
#    'TradeLine_id': 'tl_c59bfc92-2d17-423c-b01e-d072c38136aa',
#    'Qualifier_code': 'L'},
#   {'Value': '00000056',
#    'id': 'am_01182d2a-4c4e-4ffd-9538-d8ac0d6ed034',
#    'TradeLine_id': 'tl_c59bfc92-2d17-423c-b01e-d072c38136aa',
#    'Qualifier_code': 'H'},
#   {'Value': '00011500',
#    'id': 'am_6a1bc251-d9bc-4a5e-b86c-78c866a44507',
#    'TradeLine_id': 'tl_bb6c59d2-90fe-4a9d-8b2c-5a054ef2bc2e',
#    'Qualifier_code': 'L'},
#   {'Value': '00011440',
#    'id': 'am_52620af2-f86b-439c-93bd-ac1ba096111c',
#    'TradeLine_id': 'tl_bb6c59d2-90fe-4a9d-8b2c-5a054ef2bc2e',
#    'Qualifier_code': 'H'},
#   {'Value': '00012900',
#    'id': 'am_51934027-e0ea-403c-956b-c70ea392c767',
#    'TradeLine_id': 'tl_f326731d-303f-4ef5-a3f0-3c2d53cc2570',
#    'Qualifier_code': 'L'},
#   {'Value': '00008979',
#    'id': 'am_93b159c9-9b24-49da-9658-375fbfb15b22',
#    'TradeLine_id': 'tl_f326731d-303f-4ef5-a3f0-3c2d53cc2570',
#    'Qualifier_code': 'H'},
#   {'Value': 'UNKNOWN',
#    'id': 'am_7b00a5d8-211f-422e-a8ba-7a210c23fc73',
#    'TradeLine_id': 'tl_c1b9e084-ab63-43ba-8dc2-02c2415cc20e',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_4187cf7f-b856-4c75-b298-7f3220438cd5',
#    'TradeLine_id': 'tl_c1b9e084-ab63-43ba-8dc2-02c2415cc20e',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_535cda2c-b039-4258-abf6-cb4588721a5f',
#    'TradeLine_id': 'tl_cd648f49-3dab-4f87-9348-4cfcd605067e',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_5835616c-563f-4980-a10a-b02b22ed0d80',
#    'TradeLine_id': 'tl_cd648f49-3dab-4f87-9348-4cfcd605067e',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_f71c852e-bfef-4e70-90df-b58bffa7af90',
#    'TradeLine_id': 'tl_012bdde7-2519-4e1c-b3b4-a3a4c0c7440c',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_d5366aed-8322-44c8-b3ab-3dba36c590e7',
#    'TradeLine_id': 'tl_012bdde7-2519-4e1c-b3b4-a3a4c0c7440c',
#    'Qualifier_code': ' '},
#   {'Value': '00010000',
#    'id': 'am_ecfa0864-bda5-4332-aa3b-89628143567b',
#    'TradeLine_id': 'tl_482daa4b-eae6-4031-bcf7-177d6e5e8feb',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_02d3c489-2726-4f5b-9745-a09561a2cff2',
#    'TradeLine_id': 'tl_482daa4b-eae6-4031-bcf7-177d6e5e8feb',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_aee56471-9aaa-4c36-a3a8-6f430317e4d8',
#    'TradeLine_id': 'tl_5c0c6627-17b0-4c67-b46a-efd68903074f',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_af6a8dd6-e52c-471d-818e-e5de02faee19',
#    'TradeLine_id': 'tl_5c0c6627-17b0-4c67-b46a-efd68903074f',
#    'Qualifier_code': ' '},
#   {'Value': '00040000',
#    'id': 'am_0390dbdb-0b16-4813-9866-019956528444',
#    'TradeLine_id': 'tl_d033235e-5fa4-4509-b673-29d10cccec52',
#    'Qualifier_code': 'O'},
#   {'Value': None,
#    'id': 'am_116fb1a5-2ae2-4715-8de6-7877d1cb6d18',
#    'TradeLine_id': 'tl_d033235e-5fa4-4509-b673-29d10cccec52',
#    'Qualifier_code': ' '},
#   {'Value': '00080000',
#    'id': 'am_6e47ff9b-daf1-453a-a3bb-9835e5addb3f',
#    'TradeLine_id': 'tl_232af7d7-b81d-4e4d-9661-503e06e5df26',
#    'Qualifier_code': 'L'},
#   {'Value': '00159087',
#    'id': 'am_05f76770-252c-4b70-a498-566922c94397',
#    'TradeLine_id': 'tl_232af7d7-b81d-4e4d-9661-503e06e5df26',
#    'Qualifier_code': 'H'},
#   {'Value': '00000223',
#    'id': 'am_37d41ca2-2c8f-4820-87e3-5da3bbc016f4',
#    'TradeLine_id': 'tl_f126d305-3f43-43e5-8b68-23b4eb0afe64',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_283b2e31-c5fd-4d96-9c19-c6b061998379',
#    'TradeLine_id': 'tl_f126d305-3f43-43e5-8b68-23b4eb0afe64',
#    'Qualifier_code': ' '},
#   {'Value': '00150000',
#    'id': 'am_a875aa37-cdbe-4efe-ac7c-cbde830fbdcf',
#    'TradeLine_id': 'tl_5bc031bf-aef6-4f46-8835-67214bffc606',
#    'Qualifier_code': 'O'},
#   {'Value': None,
#    'id': 'am_482d326e-0b4e-446b-a4e9-76bb0832d158',
#    'TradeLine_id': 'tl_5bc031bf-aef6-4f46-8835-67214bffc606',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_b82149e9-d19c-43c3-ab7f-4f68044f51c7',
#    'TradeLine_id': 'tl_5b2918d3-ccb6-4adb-a429-eff3d63ffce6',
#    'Qualifier_code': 'L'},
#   {'Value': '00000082',
#    'id': 'am_975330ba-c38b-4b93-9ad5-a3149c639ad7',
#    'TradeLine_id': 'tl_5b2918d3-ccb6-4adb-a429-eff3d63ffce6',
#    'Qualifier_code': 'H'},
#   {'Value': '00007000',
#    'id': 'am_0bf1a804-797b-44d8-b295-cd393df92bf7',
#    'TradeLine_id': 'tl_dee654e5-66cd-453b-a78b-393765aa5c76',
#    'Qualifier_code': 'L'},
#   {'Value': '00007000',
#    'id': 'am_94a48005-dd8f-4255-9c14-4497250fc2c0',
#    'TradeLine_id': 'tl_dee654e5-66cd-453b-a78b-393765aa5c76',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_97c2ac9d-6bf1-4950-b307-654b773eb202',
#    'TradeLine_id': 'tl_c5219d3a-7bc3-4856-b106-b14ecb490865',
#    'Qualifier_code': 'L'},
#   {'Value': '00009434',
#    'id': 'am_502e3368-8087-449a-bc8a-414c4b928dba',
#    'TradeLine_id': 'tl_c5219d3a-7bc3-4856-b106-b14ecb490865',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_16582321-1c8f-49e0-9df1-5bf98e10bcdf',
#    'TradeLine_id': 'tl_967ef288-d037-475a-adf6-487331843c84',
#    'Qualifier_code': 'L'},
#   {'Value': '00008982',
#    'id': 'am_247e738f-861c-4180-bbc0-a9fe02752a8d',
#    'TradeLine_id': 'tl_967ef288-d037-475a-adf6-487331843c84',
#    'Qualifier_code': 'H'},
#   {'Value': '00000700',
#    'id': 'am_87e54f33-075b-4443-b5b1-e242ea48e97c',
#    'TradeLine_id': 'tl_2c7fc2d3-b6fc-4c57-806e-7b8a47f03442',
#    'Qualifier_code': 'L'},
#   {'Value': '00000283',
#    'id': 'am_9f7a22b5-2bff-498d-8977-5fee1c6f6366',
#    'TradeLine_id': 'tl_2c7fc2d3-b6fc-4c57-806e-7b8a47f03442',
#    'Qualifier_code': 'H'},
#   {'Value': 'UNKNOWN',
#    'id': 'am_e87c24c0-73cd-42da-b7a4-852c4b646be6',
#    'TradeLine_id': 'tl_25bf5ea2-216d-4b00-b6b9-3d7ef0840725',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_f7d5def8-ee11-4875-b9d2-19519fbdd72f',
#    'TradeLine_id': 'tl_25bf5ea2-216d-4b00-b6b9-3d7ef0840725',
#    'Qualifier_code': ' '},
#   {'Value': '00004072',
#    'id': 'am_f0af35b3-588d-4295-a33a-de8d040c5771',
#    'TradeLine_id': 'tl_b68a94e7-6fbf-471c-909a-86f0e8aa06e2',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_f2474395-4aa4-4c99-af5b-4af448beaad4',
#    'TradeLine_id': 'tl_b68a94e7-6fbf-471c-909a-86f0e8aa06e2',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_081719fa-4501-497c-ac38-6f9c03f9e5c3',
#    'TradeLine_id': 'tl_524f5bfb-9bb6-45cc-9c0b-e22160bed12e',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_9f82e82d-56ca-4c42-8058-180812626d22',
#    'TradeLine_id': 'tl_524f5bfb-9bb6-45cc-9c0b-e22160bed12e',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_b52e337c-7997-43d4-81de-d0071c06a325',
#    'TradeLine_id': 'tl_9e599b89-8fe9-47af-b0f0-8328223acbc6',
#    'Qualifier_code': 'L'},
#   {'Value': '00003813',
#    'id': 'am_544b935e-f99e-4385-b719-140705e5b319',
#    'TradeLine_id': 'tl_9e599b89-8fe9-47af-b0f0-8328223acbc6',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_a0a1a471-822d-4811-b82a-fd21b09b5b91',
#    'TradeLine_id': 'tl_9db3b36b-f2ff-4c8a-a651-a75aa59fff33',
#    'Qualifier_code': 'L'},
#   {'Value': '00008679',
#    'id': 'am_8cb84335-a2ba-43a1-ae87-916b91c47393',
#    'TradeLine_id': 'tl_9db3b36b-f2ff-4c8a-a651-a75aa59fff33',
#    'Qualifier_code': 'H'},
#   {'Value': '00000500',
#    'id': 'am_af243d18-d310-4f8d-9fe5-1a7226de3b4f',
#    'TradeLine_id': 'tl_0c78c5e5-f7c8-4d1c-b009-cc5867e41009',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_061e295e-9bfe-423b-9099-4b90036648d3',
#    'TradeLine_id': 'tl_0c78c5e5-f7c8-4d1c-b009-cc5867e41009',
#    'Qualifier_code': ' '},
#   {'Value': '00012000',
#    'id': 'am_68f659cd-cce7-4d1a-a017-063f77cb8456',
#    'TradeLine_id': 'tl_07e04fac-d403-4ada-b3d3-a65c0c6e6310',
#    'Qualifier_code': 'L'},
#   {'Value': '00010020',
#    'id': 'am_04578caa-0395-40c7-9502-1e53dd28a209',
#    'TradeLine_id': 'tl_07e04fac-d403-4ada-b3d3-a65c0c6e6310',
#    'Qualifier_code': 'H'},
#   {'Value': '00005000',
#    'id': 'am_d03cc3cb-1e65-4a9d-b17d-030ea5589648',
#    'TradeLine_id': 'tl_4a997077-a8e5-4d58-96e9-cd4d152abf61',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_6d15e82c-ebce-4552-a118-d3a9edc1c0d2',
#    'TradeLine_id': 'tl_4a997077-a8e5-4d58-96e9-cd4d152abf61',
#    'Qualifier_code': ' '},
#   {'Value': '00006900',
#    'id': 'am_967c755c-18fa-41dc-add2-9d6b15d68dd8',
#    'TradeLine_id': 'tl_b5da229a-a012-427c-bcf3-f42c70063ebb',
#    'Qualifier_code': 'L'},
#   {'Value': '00003032',
#    'id': 'am_8a9ef019-927e-4655-ba8f-08dfb84c48b4',
#    'TradeLine_id': 'tl_b5da229a-a012-427c-bcf3-f42c70063ebb',
#    'Qualifier_code': 'H'},
#   {'Value': '00001000',
#    'id': 'am_a6a38197-5e79-4255-b2cc-c198349d9174',
#    'TradeLine_id': 'tl_5ea102ad-bdde-4791-ab6d-a0351049dc8e',
#    'Qualifier_code': 'L'},
#   {'Value': '00000285',
#    'id': 'am_bc051fa6-ad43-4530-9b06-51ff6edff31d',
#    'TradeLine_id': 'tl_5ea102ad-bdde-4791-ab6d-a0351049dc8e',
#    'Qualifier_code': 'H'},
#   {'Value': '00001500',
#    'id': 'am_d07ca3c5-dace-41d7-928e-1bd31a938547',
#    'TradeLine_id': 'tl_06706504-a9b9-43ba-a6e9-61f52f6c9088',
#    'Qualifier_code': 'L'},
#   {'Value': '00000546',
#    'id': 'am_1494ad88-26f5-4636-b2d2-631941f33667',
#    'TradeLine_id': 'tl_06706504-a9b9-43ba-a6e9-61f52f6c9088',
#    'Qualifier_code': 'H'},
#   {'Value': '00003600',
#    'id': 'am_dc2a3e13-0296-4a52-8299-1133e2c487a7',
#    'TradeLine_id': 'tl_33b8b631-0d8f-4f23-9f05-96d416003e43',
#    'Qualifier_code': 'L'},
#   {'Value': '00001184',
#    'id': 'am_f2574785-8a82-470b-b13a-787ffa8dd996',
#    'TradeLine_id': 'tl_33b8b631-0d8f-4f23-9f05-96d416003e43',
#    'Qualifier_code': 'H'},
#   {'Value': '00000723',
#    'id': 'am_7cd7579d-fd53-41e1-919e-966288dbea92',
#    'TradeLine_id': 'tl_87adfb3e-0e8a-432c-b8bb-2f0eaf677486',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_2a0901ca-a74e-4844-957e-2a389287e2dc',
#    'TradeLine_id': 'tl_87adfb3e-0e8a-432c-b8bb-2f0eaf677486',
#    'Qualifier_code': ' '},
#   {'Value': '00019000',
#    'id': 'am_54d49bd3-dbf7-48e4-961b-d518319ac7c1',
#    'TradeLine_id': 'tl_be534cc3-1796-4297-8bf6-338de9ea74da',
#    'Qualifier_code': 'L'},
#   {'Value': '00010513',
#    'id': 'am_3237757d-3317-4401-8fdf-d32bac8b0f95',
#    'TradeLine_id': 'tl_be534cc3-1796-4297-8bf6-338de9ea74da',
#    'Qualifier_code': 'H'},
#   {'Value': '00012200',
#    'id': 'am_2a3b8b23-098c-45f3-810e-0362408490ee',
#    'TradeLine_id': 'tl_7617fb86-0514-4d4f-b8e2-e6a9760b154c',
#    'Qualifier_code': 'L'},
#   {'Value': '00000629',
#    'id': 'am_4f99dbd2-cfe6-402e-afab-9189424634d9',
#    'TradeLine_id': 'tl_7617fb86-0514-4d4f-b8e2-e6a9760b154c',
#    'Qualifier_code': 'H'},
#   {'Value': '00001047',
#    'id': 'am_bc71a0d6-3cf1-457a-bff8-a657b4f5547d',
#    'TradeLine_id': 'tl_18479f02-9183-4665-a330-4878b350d94a',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_96e3485c-fa73-4719-9afc-1bf64356ff4e',
#    'TradeLine_id': 'tl_18479f02-9183-4665-a330-4878b350d94a',
#    'Qualifier_code': ' '},
#   {'Value': '00007361',
#    'id': 'am_62f05b41-efc9-40b4-a59e-9572c74d55ad',
#    'TradeLine_id': 'tl_96ee80e6-414d-48db-a58b-8efad0b0afd8',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_67148348-bbec-492c-92e1-8e0928a142ba',
#    'TradeLine_id': 'tl_96ee80e6-414d-48db-a58b-8efad0b0afd8',
#    'Qualifier_code': ' '},
#   {'Value': '00001500',
#    'id': 'am_a5cec369-eec1-4431-b9b1-44864d7d42b3',
#    'TradeLine_id': 'tl_1cae8438-caae-459c-b2d7-487a30ce5b09',
#    'Qualifier_code': 'L'},
#   {'Value': '00000089',
#    'id': 'am_420307a7-c07b-4675-b37a-04b1b4d3eb35',
#    'TradeLine_id': 'tl_1cae8438-caae-459c-b2d7-487a30ce5b09',
#    'Qualifier_code': 'H'},
#   {'Value': '00150000',
#    'id': 'am_21d236ff-0518-404e-94d4-7aa3a835e4f3',
#    'TradeLine_id': 'tl_ae14fdb2-9a2d-455b-993a-480f910750c0',
#    'Qualifier_code': 'L'},
#   {'Value': '00022118',
#    'id': 'am_451514b6-d3aa-4109-bed6-5528da21da4b',
#    'TradeLine_id': 'tl_ae14fdb2-9a2d-455b-993a-480f910750c0',
#    'Qualifier_code': 'H'}]}

# %% [markdown]
# Take a preview of table PrequalResult

# %%
pd.DataFrame(RESULT_OBJ_DICT['prequal_results'])
# Out:
#                   model  pk  loanapp_id  result error_reason detail_results  \
# 0  common.prequalresult   1         194    True   no reasons           None
#
#   fico_v2    report_type username                       created_at  ...  \
# 0     695  CreditProfile      cho 2016-08-04 00:29:03.067000+00:00  ...
#
#   business_credit_card_total_limits business_credit_card_total_balances  \
# 0                              None                                None
#
#   business_total_mortgage_monthly_payments  \
# 0                                     None
#
#   business_total_monthly_debt_payments bkdate fico_v3  \
# 0                                 None   None    None
#
#   total_mortgage_monthly_payments       version       role  \
# 0                            None  CF Microloan  applicant
#
#                              xml_detail_id
# 0  xd_1173c369-4b11-49fd-a258-ee505f5311f4
#
# [1 rows x 24 columns]

# %% [markdown]
# Take a preview of table Product

# %%
pd.DataFrame(RESULT_OBJ_DICT['products'])
# Out:
#                                 @xmlns  \
# 0  http://www.experian.com/ARFResponse
#
#                                         id  \
# 0  pd_82762c24-7362-4c6d-a95c-01da3be29db0
#
#                          credit_profile_id
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea

# %% [markdown]
# Take a preview of table CreditProfile

# %%
pd.DataFrame(RESULT_OBJ_DICT['credit_profiles'])
# Out:
#                                         id  \
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea
#
#                                  header_id  \
# 0  hd_530c0a97-f26c-4d67-b153-3b11af4b1cea
#
#                                 inquiry_id
# 0  iq_e15be34d-446d-4998-b652-b8e98fcedd46

# %% [markdown]
# Take a preview of table Header

# %%
pd.DataFrame(RESULT_OBJ_DICT['headers'])
# Out:
#   ReportDate ReportTime Preamble ARFVersion  \
# 0   10032017     140607     TWA1         07
#
#                                         id
# 0  hd_530c0a97-f26c-4d67-b153-3b11af4b1cea

# %% [markdown]
# Take a preview of table RiskModel

# %%
pd.DataFrame(RESULT_OBJ_DICT['risk_models'])
# Out:
#   Score ScoreFactorCodeOne ScoreFactorCodeTwo ScoreFactorCodeThree  \
# 0  0808                 10                 09                   05
# 1  0807                 30                 05                   11
#
#   ScoreFactorCodeFour                                       id  \
# 0                None  rm_3f81f6bf-6b10-47f4-b21c-06bd3242fec8
# 1                None  rm_17da3e39-4320-4f1e-a642-7f3da2160e71
#
#                           CreditProfile_id ModelIndicator_code Evaluation_code
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                  F                P
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                  AA               P

# %% [markdown]
# Take a preview of table ConsumerIdentity

# %%
pd.DataFrame(RESULT_OBJ_DICT['consumer_identities'])
# Out:
#     YOB                                       id  Surname    First   Middle  \
# 0  None  ci_96c6683f-47f4-43bc-958b-339dd5755b2a  SCALICI  WILLIAM
# 1  None  ci_16874b77-f28a-49d2-85f6-0fead5f8fb97  SCALICI       AS  WILLIAM
# 2  None  ci_6336a8b5-f7f0-4f00-ad2e-6f7c82415042  SCALICI  WILLIAM
# 3  None  ci_7d44be99-91b4-4516-bc60-c65b6ba34fb0  ANTHONY  WILLIAM        R
#
#   Gen NameType_code                         CreditProfile_id
# 0                    cp_77c81901-e783-4adb-a5b5-f9b3a54cc976
# 1                 N  cp_77c81901-e783-4adb-a5b5-f9b3a54cc976
# 2  JR                cp_77c81901-e783-4adb-a5b5-f9b3a54cc976
# 3                 A  cp_77c81901-e783-4adb-a5b5-f9b3a54cc976

# %% [markdown]
# Take a preview of table AddressInfo

# %%
pd.DataFrame(RESULT_OBJ_DICT['addr_infos'])
# Out:
#   FirstReportedDate LastUpdatedDate TimesReported LastReportingSubcode  \
# 0          10272003        12202015            00              7370142
# 1          01012011        01012011            00                 None
# 2          05282006        11022010            12                 None
#
#   StreetPrefix   StreetName StreetSuffix    City State        Zip  \
# 0         7324  84TH STREET        CT SW  TACOMA    WA  984986380
# 1       3260 S       TACOMA          WAY  TACOMA    WA  984094725
# 2       3216 S       TACOMA          WAY  TACOMA    WA  984094725
#
#   CensusGeoCode                                       id  \
# 0          None  ai_8a249318-d504-4814-b0d2-28e656b033e2
# 1          None  ai_180a3b79-fc80-4969-91ea-4568b16cd4b5
# 2          None  ai_794d9a61-3eae-405d-b469-1dc26e2a8954
#
#                           CreditProfile_id Origination_code DwellingType_code  \
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                2                 S
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                1                 S
# 2  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                1                 S
#
#   HomeOwnership_code
# 0
# 1
# 2

# %% [markdown]
# Take a preview of table EmploymentInfo

# %%
pd.DataFrame(RESULT_OBJ_DICT['employ_infos'])
# Out:
#   FirstReportedDate LastUpdatedDate        Name AddressFirstLine  \
# 0          04082011        04082011  GM RETIRED             None
# 1          12282009        06112010     RETIRED             None
#
#   AddressSecondLine AddressExtraLine   Zip  \
# 0              None             None  None
# 1              None             None  None
#
#                                         id  \
# 0  ei_da29547c-22e3-455b-a51f-79af941f6917
# 1  ei_7fe91e47-c26a-4527-96e1-90ec73229d55
#
#                           CreditProfile_id Origination_code
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                2
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                2

# %% [markdown]
# Take a preview of table TradeLine

# %%
pd.DataFrame(RESULT_OBJ_DICT['trade_lines'])
# Out:
#     OpenDate StatusDate MaxDelinquencyDate BalanceDate BalanceAmount  \
# 0   06011981   05012017               None    05192017          None
# 1   08282007   03012012               None    03182012          None
# 2   06102006   07012017               None    07232017      00000000
# 3   08282007   03012012               None    04282012      00000000
# 4   03012002   04012009               None    04012009      00000000
# ..       ...        ...                ...         ...           ...
# 31  06011983   08012017               None    08072017      00000052
# 32  05011984   08012017               None    08072017      00000599
# 33  05011984   08012017               None    08072017      00001960
# 34  08182016   08012017               None    08072017      00000000
# 35  08122015   07012017               None    07282017      00004607
#
#    AmountPastDue ConsumerComment MonthsHistory DelinquenciesOver30Days  \
# 0           None            None            15                      00
# 1           None            None            56                      00
# 2           None            None            96                      00
# 3           None            None            03                      00
# 4           None            None            86                      00
# ..           ...             ...           ...                     ...
# 31          None            None            01                      00
# 32          None            None            01                      00
# 33          None            None            01                      00
# 34          None            None            12                      00
# 35          None            None            24                      00
#
#    DelinquenciesOver60Days  ... Evaluation_code AccountType_code  \
# 0                       00  ...               N               18
# 1                       00  ...               N               18
# 2                       00  ...               N               18
# 3                       00  ...               N               18
# 4                       00  ...               N               18
# ..                     ...  ...             ...              ...
# 31                      00  ...               P               18
# 32                      00  ...               P               18
# 33                      00  ...               P               18
# 34                      00  ...               P               07
# 35                      00  ...               P               47
#
#    TermsDuration_code Status_code ECOA_code OpenOrClosed_code  \
# 0                 REV          05         1                 C
# 1                 REV          05         1                 C
# 2                 REV          11         2                 C
# 3                 REV          11         1                 C
# 4                 REV          11         0                 C
# ..                ...         ...       ...               ...
# 31                REV          11         1                 O
# 32                001          11         1                 O
# 33                REV          11         1                 O
# 34                REV          11         1                 O
# 35                REV          11         1                 O
#
#    RevolvingOrInstallment_code MonthlyPaymentType_code KOB_code AccountNumber
# 0                            R                               OC           NaN
# 1                            R                               BC           NaN
# 2                            R                               BC           NaN
# 3                            R                               BC           NaN
# 4                            R                               NZ           NaN
# ..                         ...                     ...      ...           ...
# 31                           R                               BC           NaN
# 32                           R                               BC           NaN
# 33                           R                               BC           NaN
# 34                           R                               CG           NaN
# 35                           R                               BB           NaN
#
# [36 rows x 31 columns]

# %% [markdown]
# Take a preview of table Inquiry

# %%
pd.DataFrame(RESULT_OBJ_DICT['inquiries'])
# Out:
#        Date   Amount  Subcode SubscriberDisplayName  \
# 0  08182016  UNKNOWN  1640007     SYNCB/BROOKS BROS
#
#                                         id Type_code Terms_code KOB_code
# 0  iq_3fc54910-a551-4314-85d9-51c8d0d5cfec        31        UNK       FF

# %% [markdown]
# Take a preview of table InformationMessage

# %%
pd.DataFrame(RESULT_OBJ_DICT['info_msgs'])
# Out:
#   MessageNumber                                MessageText  \
# 0            92  0092 REQUESTED PRODUCT OPTION NOT ALLOWED
# 1            84                           0084 SSN MATCHES
#
#                                         id  \
# 0  im_28268464-7836-441b-a0d0-18f3205ef32c
# 1  im_ebdda4fd-48a0-41fc-93db-5e2749d0ba4f
#
#                           CreditProfile_id
# 0  cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6
# 1  cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6

# %%
Take a preview of table EnhancedPaymentData

# %%
pd.DataFrame(RESULT_OBJ_DICT['enhanced_pm_data'])
# Out:
#    InitialPaymentLevelDate                                       id  \
# 0                 05012017  ep_3c421ba6-2346-428c-8d27-68fe80c0d68c
# 1                 03012012  ep_568ec0f9-f267-4dc6-9a1a-a900a502f03b
# 2                 07012017  ep_047b1fda-32da-4a2f-9132-2b319fafbd66
# 3                 03012012  ep_1d2705f9-1a92-478d-b1d2-6a116354c0c6
# 4                 04012009  ep_67ca52d4-0e3f-4043-acb4-4e35c00b3135
# ..                     ...                                      ...
# 31                08012017  ep_0cd98c68-209d-46ed-813c-b46e6b79dc19
# 32                08012017  ep_5f1be051-aa86-49ed-ad57-a2fad69d656b
# 33                08012017  ep_65e68832-a111-4c24-9f1b-3f1cb61cbcbd
# 34                08012017  ep_6dfac92c-1023-4fc9-9852-105664319d7e
# 35                07012017  ep_5a86bd16-57bd-4126-a87f-16167ee5fecb
#
#    AccountCondition_code PaymentStatus_code AccountType_code  \
# 0                     05                 11               18
# 1                     05                 11               18
# 2                     A3                 11               18
# 3                     A3                 11               18
# 4                     A3                 11               18
# ..                   ...                ...              ...
# 31                    A1                 11               18
# 32                    A1                 11               18
# 33                    A1                 11               18
# 34                    A1                 11               07
# 35                    A1                 11               89
#
#    SpecialComment_code
# 0                   51
# 1                   40
# 2                   19
# 3                   18
# 4                   19
# ..                 ...
# 31
# 32
# 33
# 34
# 35
#
# [36 rows x 6 columns]

# %%
Take a preview of table TradeLineAmount

# %%
pd.DataFrame(RESULT_OBJ_DICT['tradeline_amounts'])
# Out:
#        Value                                       id  \
# 0   00000350  am_83f02edd-f55c-4d77-8a87-c01c6959cb5e
# 1   00000056  am_030a13e9-c47b-4937-be78-7a1e1e42ca52
# 2   00011500  am_9d329a05-5a4e-4d62-baa4-5af4378c7fa0
# 3   00011440  am_0fbe17a5-35f7-4a6e-bcb2-6263eaf49f61
# 4   00012900  am_53376d62-5f42-420f-9099-eeb21c7f0daf
# ..       ...                                      ...
# 67      None  am_4dd6e759-bea2-4030-9f2e-a76e8f319923
# 68  00001500  am_bc49cd77-e919-4876-89cb-5a65d773dc0b
# 69  00000089  am_437b4598-c470-4bdf-8420-dad6b0ffd728
# 70  00150000  am_e201de52-84d8-4e0e-92aa-43fdb07e4de7
# 71  00022118  am_c7136f6f-dc66-4f90-8ae9-f0ffeaad640e
#
#                                TradeLine_id Qualifier_code
# 0   tl_1db28f6a-e1f2-4694-afc8-f1c1660cbfe6              L
# 1   tl_1db28f6a-e1f2-4694-afc8-f1c1660cbfe6              H
# 2   tl_38ed728c-204b-499a-bcd8-db7e2f5b20a6              L
# 3   tl_38ed728c-204b-499a-bcd8-db7e2f5b20a6              H
# 4   tl_c81a6fb7-b0cb-4573-afc6-c2f18f4d218a              L
# ..                                      ...            ...
# 67  tl_a6592400-9fcd-44c5-ab51-32715778e8f8
# 68  tl_add11747-c117-42de-bdec-130a6cc899ff              L
# 69  tl_add11747-c117-42de-bdec-130a6cc899ff              H
# 70  tl_60319ada-d9ff-43c0-89b9-04470f2fb38c              L
# 71  tl_60319ada-d9ff-43c0-89b9-04470f2fb38c              H
#
# [72 rows x 4 columns]
