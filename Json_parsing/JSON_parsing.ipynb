# %%
import json
import pprint
import uuid
import xmltodict
import pandas as pd

pd.set_option('display.max_rows', 10)
RESULT_TABLE_NAMES = ['prequal_results', 'xml_details', 'products', 'credit_profiles', 'headers', 'risk_models', 'consumer_identities', 'addr_infos', 'employ_infos', 'trade_lines', 'inquiries', 'info_msgs', 'enhanced_pm_data', 'tradeline_amounts']
with open("./data/prequalresult.json", 'r') as f:
    json_file = json.load(f)
json_file
# Out:
# [{'model': 'common.prequalresult',
#   'pk': 1,
#   'fields': {'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant'}}]

# %% [markdown]
# Parse XML data string and build the internal objects into the designed tables

# %%
# initialize result object lists
RESULT_OBJ_DICT = dict((key, []) for key in RESULT_TABLE_NAMES)
ATTR_CODE_DICT = {
    'risk_models': ['ModelIndicator', 'Evaluation'],
    'addr_infos': ['Origination', 'DwellingType', 'HomeOwnership'],
    'employ_infos': ['Origination'],
    'trade_lines': ['SpecialComment', 'Evaluation', 'AccountType', 'TermsDuration', 'Status', 'ECOA', 'OpenOrClosed', 'RevolvingOrInstallment', 'MonthlyPaymentType', 'KOB'],
    'tradeline_amounts': ['Qualifier'],
    'enhanced_pm_data': ['AccountCondition', 'PaymentStatus', 'AccountType', 'SpecialComment'],
    'inquiries': ['Type', 'Terms', 'KOB']
}

prequal_results = json_file
for prequal_result in prequal_results:
    prequal_result.update(prequal_result.pop('fields'))
    xml_detail_id = "xd_{}".format(uuid.uuid4())
    prequal_result['xml_detail_id'] = xml_detail_id
    RESULT_OBJ_DICT['prequal_results'].append(prequal_result)
    
    # initializing XML_Detail object
    xml_dict = xmltodict.parse(result['xml_data'], dict_constructor=dict)['NetConnectResponse']
    xml_dict['id'] = xml_detail_id
    RESULT_OBJ_DICT['xml_details'].append(xml_dict)
    product_id = "pd_{}".format(uuid.uuid4())
    xml_dict['product_id'] = product_id
    
    # initializing Product object
    product_obj = xml_dict.pop('Products')
    product_obj['id'] = product_id
    RESULT_OBJ_DICT['products'].append(product_obj)
    credit_profile_id = "cp_{}".format(uuid.uuid4())
    product_obj['credit_profile_id'] = credit_profile_id
    
    # initializing CreditProfile object
    credit_profile_obj = product_obj.pop('CreditProfile')
    credit_profile_obj['id'] = credit_profile_id
    RESULT_OBJ_DICT['credit_profiles'].append(credit_profile_obj)
    
    
    ## handling RiskModels in CreditProfile
    for risk_model in credit_profile_obj.pop('RiskModel'):
        risk_model['id'] = "rm_{}".format(uuid.uuid4())
        risk_model['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['risk_models'].append(risk_model)
    
    # initializing Header object in CreditProfile
    header_id = "hd_{}".format(uuid.uuid4())
    credit_profile_obj['header_id'] = header_id
    header_obj = credit_profile_obj.pop('Header')
    header_obj['id'] = header_id
    RESULT_OBJ_DICT['headers'].append(header_obj)
    
    ## handling ConsumerIdentities in CreditProfile
    for consumer_identity in credit_profile_obj.pop('ConsumerIdentity'):
        consumer_identity['id'] = "ci_{}".format(uuid.uuid4())
        consumer_identity['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['consumer_identities'].append(consumer_identity)
    
    ## handling AddressInformations in CreditProfile
    for addr_info in credit_profile_obj.pop('AddressInformation'):
        addr_info['id'] = "ai_{}".format(uuid.uuid4())
        addr_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['addr_infos'].append(addr_info)
       
    ## handling EmploymentInformations in CreditProfile
    for employ_info in credit_profile_obj.pop('EmploymentInformation'):
        employ_info['id'] = "ei_{}".format(uuid.uuid4())
        employ_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['employ_infos'].append(employ_info)
        
    ## handling TradeLines in CreditProfile
    code_attrs = ['SpecialComment', 'Evaluation', 'AccountType', 'TermsDuration', 'Status', 'OpenOrClosed', 'RevolvingOrInstallment', 'MonthlyPaymentType', 'KOB']
    for trade_line in credit_profile_obj.pop('TradeLine'):
        trade_line['id'] = "tl_{}".format(uuid.uuid4())
        trade_line['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['trade_lines'].append(trade_line)
        
        # initializing EnhancedPaymentData object in TradeLine
        enhanced_pm_data_id = "ep_{}".format(uuid.uuid4())
        trade_line['enhanced_pm_data_id'] = enhanced_pm_data_id
        enhanced_pm_data_obj = trade_line.pop('EnhancedPaymentData')
        enhanced_pm_data_obj['id'] = enhanced_pm_data_id
        RESULT_OBJ_DICT['enhanced_pm_data'].append(enhanced_pm_data_obj)
        
        ## handling Amount object in TradeLine
        for amt_obj in trade_line.pop('Amount'):
            amt_obj['id'] = "am_{}".format(uuid.uuid4())
            amt_obj['TradeLine_id'] = trade_line['id']
            RESULT_OBJ_DICT['tradeline_amounts'].append(amt_obj)
    
    # initializing Inquiry object in CreditProfile
    inquiry_id = "iq_{}".format(uuid.uuid4())
    credit_profile_obj['inquiry_id'] = inquiry_id
    inquiry_obj = credit_profile_obj.pop('Inquiry')
    inquiry_obj['id'] = inquiry_id
    RESULT_OBJ_DICT['inquiries'].append(inquiry_obj)
    
    ## handling InformationalMessages in CreditProfile
    for info_msg in credit_profile_obj.pop('InformationalMessage'):
        info_msg['id'] = "im_{}".format(uuid.uuid4())
        info_msg['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['info_msgs'].append(info_msg)
    
# converting sub-attrs into _code
for attr, code_attr_list in ATTR_CODE_DICT.items():
    attr_obj_list = RESULT_OBJ_DICT[attr]
    for attr_obj in attr_obj_list:
        for attr in code_attr_list:
            if attr in attr_obj:
                code = attr_obj[attr]['@code']
            else:
                code = ''
            attr_obj["{}_code".format(attr)] = code
            attr_obj.pop(attr, None)
    
RESULT_OBJ_DICT
# Out:
# {'prequal_results': [{'model': 'common.prequalresult',
#    'pk': 1,
#    'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant',
#    'xml_detail_id': 'xd_d7008850-f9e4-4fdc-a93c-ce11b8861057'}],
#  'xml_details': [{'@xmlns': 'http://www.experian.com/NetConnectResponse',
#    'CompletionCode': '0000',
#    'ReferenceId': 'testing 123',
#    'TransactionId': '41588980',
#    'id': 'xd_d7008850-f9e4-4fdc-a93c-ce11b8861057',
#    'product_id': 'pd_da68fcbd-0504-449a-965d-c6b7615ace43'}],
#  'products': [{'@xmlns': 'http://www.experian.com/ARFResponse',
#    'id': 'pd_da68fcbd-0504-449a-965d-c6b7615ace43',
#    'credit_profile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6'}],
#  'credit_profiles': [{'id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'header_id': 'hd_f70dbe2f-3d87-48ab-a6c8-8e9fa4ecd23f',
#    'inquiry_id': 'iq_3fc54910-a551-4314-85d9-51c8d0d5cfec'}],
#  'headers': [{'ReportDate': '10032017',
#    'ReportTime': '140607',
#    'Preamble': 'TWA1',
#    'ARFVersion': '07',
#    'id': 'hd_f70dbe2f-3d87-48ab-a6c8-8e9fa4ecd23f'}],
#  'risk_models': [{'Score': '0808',
#    'ScoreFactorCodeOne': '10',
#    'ScoreFactorCodeTwo': '09',
#    'ScoreFactorCodeThree': '05',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_07e06a83-ece5-453c-aa10-05e734fb9c58',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'ModelIndicator_code': 'F ',
#    'Evaluation_code': 'P'},
#   {'Score': '0807',
#    'ScoreFactorCodeOne': '30',
#    'ScoreFactorCodeTwo': '05',
#    'ScoreFactorCodeThree': '11',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_7cb7eb10-0a5c-4913-b033-6d99441a4d97',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'ModelIndicator_code': 'AA',
#    'Evaluation_code': 'P'}],
#  'consumer_identities': [{'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_3d9bd434-cc56-4a1d-9b4e-e2512e9a4783',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6'},
#   {'Name': {'Type': {'@code': 'N'},
#     'Surname': 'SCALICI',
#     'First': 'AS',
#     'Middle': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_67206456-478c-4cb9-a62e-5c4eb7e7a1f5',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6'},
#   {'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM', 'Gen': 'JR'},
#    'YOB': None,
#    'id': 'ci_9388a11f-3b3a-4a46-8214-262d1ed8c311',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6'},
#   {'Name': {'Type': {'@code': 'A'},
#     'Surname': 'ANTHONY',
#     'First': 'WILLIAM',
#     'Middle': 'R'},
#    'YOB': None,
#    'id': 'ci_05d763da-1d35-4690-9260-809d9c7f010d',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6'}],
#  'addr_infos': [{'FirstReportedDate': '10272003',
#    'LastUpdatedDate': '12202015',
#    'TimesReported': '00',
#    'LastReportingSubcode': '7370142',
#    'StreetPrefix': '7324',
#    'StreetName': '84TH STREET',
#    'StreetSuffix': 'CT SW',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984986380',
#    'CensusGeoCode': None,
#    'id': 'ai_55712e00-2b8e-420f-a4fa-11aec7012072',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'Origination_code': '2',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '01012011',
#    'LastUpdatedDate': '01012011',
#    'TimesReported': '00',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3260 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_bd436a2d-8d22-4870-8712-ad5f59bcb470',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '05282006',
#    'LastUpdatedDate': '11022010',
#    'TimesReported': '12',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3216 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_934cc146-f7b0-4959-ac9b-81e380bff3fb',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '}],
#  'employ_infos': [{'FirstReportedDate': '04082011',
#    'LastUpdatedDate': '04082011',
#    'Name': 'GM RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_54109e08-f6ee-4419-b2de-7f54d281b004',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'Origination_code': '2'},
#   {'FirstReportedDate': '12282009',
#    'LastUpdatedDate': '06112010',
#    'Name': 'RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_a27dd148-00a0-4a7f-b5b5-4868224a6b71',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'Origination_code': '2'}],
#  'trade_lines': [{'OpenDate': '06011981',
#    'StatusDate': '05012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '05192017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '15',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01032016',
#    'Subcode': '1401790',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_1db28f6a-e1f2-4694-afc8-f1c1660cbfe6',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_3c421ba6-2346-428c-8d27-68fe80c0d68c',
#    'SpecialComment_code': '28',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03182012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1213727',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_38ed728c-204b-499a-bcd8-db7e2f5b20a6',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_568ec0f9-f267-4dc6-9a1a-a900a502f03b',
#    'SpecialComment_code': '31',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '06102006',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '07232017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '96',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0---------CCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '07212015',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_c81a6fb7-b0cb-4573-afc6-c2f18f4d218a',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_047b1fda-32da-4a2f-9132-2b319fafbd66',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '04282012',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '03',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01122010',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_a3e221ac-77aa-470d-99f3-812fb4dbc840',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_1d2705f9-1a92-478d-b1d2-6a116354c0c6',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC'},
#   {'OpenDate': '03012002',
#    'StatusDate': '04012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '04012009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '86',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00--------0-----------00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12102006',
#    'Subcode': '1439507',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_62a5cef6-c27a-4207-a50c-d3b982f29463',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_67ca52d4-0e3f-4043-acb4-4e35c00b3135',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '0',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'NZ'},
#   {'OpenDate': '03012007',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03282009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '26',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0----------0',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_085a0de0-8010-482b-b26f-9b1c02b6b81b',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_6b08370e-bc60-4f08-92fd-7cc5398affa6',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '04072017',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08032017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '04',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00C',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_c235ba85-a002-4b90-adb7-d1ded85fff8a',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_a81f73de-b5bd-4fee-9357-85f2a731c6d0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09012016',
#    'StatusDate': '06012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '06282017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '6037453215420',
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '06262017',
#    'Subcode': '1945962',
#    'SubscriberDisplayName': 'VERIZON NEW ENGLAND IN',
#    'id': 'tl_c42692c2-243d-422b-abd8-3104182d8f8e',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_56509cff-f124-4e52-be70-f09c2db8b6bf',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '31',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'UT'},
#   {'OpenDate': '08122015',
#    'StatusDate': '05012016',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '05282016',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '15621485',
#    'MonthsHistory': '10',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_a5471727-686b-4a21-96b2-e47f0510f8e3',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_f7505619-0e92-4505-8d69-0b7ad055c6a9',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': 'UNK',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '02182007',
#    'StatusDate': '11012015',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '11282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000CCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_3250a832-a4bb-411a-9d26-d86a274dba1f',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_8f4b0a74-827f-47b4-abc1-0e60ec1b60da',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '05011984',
#    'StatusDate': '10012015',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '10082015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_a8128eff-4249-42b7-b53a-8dd4f02ec7dc',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_5b1d5088-d2d2-4fc9-97ce-56ac27adec99',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '12142012',
#    'StatusDate': '08012015',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '13750088',
#    'MonthsHistory': '33',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_b8f07ac8-c9de-45a2-85de-fc9d86c6f834',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_dca4afaf-86ee-4aca-ac6d-83aace987f5d',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': '180',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '10202007',
#    'StatusDate': '11012012',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '11102012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '68',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_b1508112-3499-4654-9d45-189116e5a85b',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_d5737709-c6b8-43e9-9e67-8b72afc759b9',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '10202007',
#    'StatusDate': '10012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '10282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1220390',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_d574cc82-edb8-4d61-95d6-bae8d09c81bd',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_22eb77e0-5cba-421e-a6ff-5e409f771848',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01012007',
#    'StatusDate': '07012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '07282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000CCCCCC',
#    'Subcode': '1290016',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_c1e93f4e-090a-40f1-b0aa-140412fc73ef',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_9173ca68-ecf7-40e1-be58-c6e90eb94615',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01092008',
#    'StatusDate': '06012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '06082011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '32',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000CCCCCCCCCC',
#    'Subcode': '1290138',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_faa6b915-26a9-4947-921c-66a49d3f85fa',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_67953c14-fb88-478b-aae0-fa2174370245',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '3',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01082006',
#    'StatusDate': '02012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '02282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '62',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B0000000000000000--------',
#    'Subcode': '6230125',
#    'SubscriberDisplayName': 'BAC/FLEET-BKCARD',
#    'id': 'tl_c40dd77e-d4b7-45bc-8650-2cd70811c0f8',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_7559cbe8-c3e6-4794-8b3e-7344719d7587',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09242005',
#    'StatusDate': '11012010',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '11282010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '60',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1260958',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_aeab1016-6772-48ae-a2dc-55c7f62019ed',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_32fbf53e-b6d5-4fe7-aadf-4c3fbdd36004',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '3',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09102007',
#    'StatusDate': '03012010',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03072010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '30',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000000CCCCCCC',
#    'Subcode': '3245600',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_8c4bd233-598a-47da-81c1-8e66e3678325',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_fddcc4a1-528e-41c4-b444-ec634b22562c',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_178cd1dd-5169-4359-9f22-95a8c6f8ede1',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_f2c4c65f-6bff-4ed4-bcc6-ead89d47e484',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_05f1074b-d451-4e85-844e-685e3a137e89',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_45f8a3cd-960e-4b86-b6cd-51a6abe96f54',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '04222005',
#    'StatusDate': '06012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '06282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '1201520',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_94fd1768-9b4a-45dc-a148-db5d3eabb107',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_4b689461-a9e6-4f45-9fd6-ad69e56ebd9d',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01072008',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03012009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '14',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCC',
#    'Subcode': '1202270',
#    'SubscriberDisplayName': 'WF/WB',
#    'id': 'tl_b43875f8-feb9-4bfa-b7d3-ef2f84f0d9bd',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_fdc2d765-83f4-4816-8220-e156ed2574a6',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '02282004',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '02282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '61',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC00000000CCCCC',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_0648d5b0-ad98-42aa-8633-52c25418e924',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_0e1f4737-9bb1-49e5-b7cd-3fa4cfbf411f',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '02151994',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '02222009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B---------------C--------',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_32389349-213d-4b12-95e1-6fcef8d7e112',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_280cab31-d601-4426-9bf8-8db1ee771ba8',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09072013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08232017',
#    'BalanceAmount': '00000025',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C0CCCCCCCCC000CCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000010',
#    'LastPaymentDate': '06082017',
#    'Subcode': '3178962',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_213f8cc9-fc63-477a-b8f3-ca2b24860f16',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_006d36c8-ac82-4d28-96e4-f670de4ac71c',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'ZR'},
#   {'OpenDate': '09011979',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08202017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '75',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000CCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '05092017',
#    'Subcode': '1335510',
#    'SubscriberDisplayName': 'SYNCB/EXXON MOBIL',
#    'id': 'tl_a4b07e08-c44c-4ec1-a83a-8e281c7a9fbd',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_4787d070-3c60-4dc8-bb70-b69debc2d73f',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC'},
#   {'OpenDate': '06182013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08162017',
#    'BalanceAmount': '00000160',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '51',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0C',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07272017',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_dd83ef63-3040-467a-9030-bacc163110d9',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_fbce6e10-13a5-4bf9-b872-3173d99f75f9',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'DV'},
#   {'OpenDate': '04272007',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08152017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000000000CCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12282015',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_554d5257-b1c4-4db8-a630-4f1e0c6fd25d',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_9ef25b04-8ef0-4cfb-ae43-b716f7d2daf0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '3',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'DV'},
#   {'OpenDate': '09012010',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08142017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '84',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000C000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '08282016',
#    'Subcode': '1349040',
#    'SubscriberDisplayName': 'FILENES',
#    'id': 'tl_de6a9ed7-cdf8-4c13-aee4-ad4dc023c1ab',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_9c89c002-27cb-4836-a583-d127c86f9219',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'ZR'},
#   {'OpenDate': '04011998',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08092017',
#    'BalanceAmount': '00001354',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '97',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07242017',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_2bf3e18e-fa0c-4d1e-bf84-f219d758a405',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_fc34bf51-cbbb-4322-8274-88b991f9e3ca',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'BC'},
#   {'OpenDate': '06011983',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000052',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_46599e98-efe1-437d-8bfc-1523a3250cf8',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_0cd98c68-209d-46ed-813c-b46e6b79dc19',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000599',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_335559fd-6665-4da5-b5a9-9566f188e3c7',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_5f1be051-aa86-49ed-ad57-a2fad69d656b',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00001960',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_a6592400-9fcd-44c5-ab51-32715778e8f8',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_65e68832-a111-4c24-9f1b-3f1cb61cbcbd',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '08182016',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '0000000000CC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '09192016',
#    'Subcode': '2613430',
#    'SubscriberDisplayName': 'SYNCB/BROOK BROS',
#    'id': 'tl_add11747-c117-42de-bdec-130a6cc899ff',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_6dfac92c-1023-4fc9-9852-105664319d7e',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'CG'},
#   {'OpenDate': '08122015',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '07282017',
#    'BalanceAmount': '00004607',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '24',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0',
#    'MonthlyPaymentAmount': 'UNKNOWN',
#    'LastPaymentDate': '07102017',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_60319ada-d9ff-43c0-89b9-04470f2fb38c',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6',
#    'enhanced_pm_data_id': 'ep_5a86bd16-57bd-4126-a87f-16167ee5fecb',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BB'}],
#  'inquiries': [{'Date': '08182016',
#    'Amount': 'UNKNOWN',
#    'Subcode': '1640007',
#    'SubscriberDisplayName': 'SYNCB/BROOKS BROS',
#    'id': 'iq_3fc54910-a551-4314-85d9-51c8d0d5cfec',
#    'Type_code': '31',
#    'Terms_code': 'UNK',
#    'KOB_code': 'FF'}],
#  'info_msgs': [{'MessageNumber': '92',
#    'MessageText': '0092 REQUESTED PRODUCT OPTION NOT ALLOWED',
#    'id': 'im_28268464-7836-441b-a0d0-18f3205ef32c',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6'},
#   {'MessageNumber': '84',
#    'MessageText': '0084 SSN MATCHES',
#    'id': 'im_ebdda4fd-48a0-41fc-93db-5e2749d0ba4f',
#    'CreditProfile_id': 'cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6'}],
#  'enhanced_pm_data': [{'InitialPaymentLevelDate': '05012017',
#    'id': 'ep_3c421ba6-2346-428c-8d27-68fe80c0d68c',
#    'AccountCondition_code': '05',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '51'},
#   {'InitialPaymentLevelDate': '03012012',
#    'id': 'ep_568ec0f9-f267-4dc6-9a1a-a900a502f03b',
#    'AccountCondition_code': '05',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '40'},
#   {'InitialPaymentLevelDate': '07012017',
#    'id': 'ep_047b1fda-32da-4a2f-9132-2b319fafbd66',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012012',
#    'id': 'ep_1d2705f9-1a92-478d-b1d2-6a116354c0c6',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '18'},
#   {'InitialPaymentLevelDate': '04012009',
#    'id': 'ep_67ca52d4-0e3f-4043-acb4-4e35c00b3135',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012009',
#    'id': 'ep_6b08370e-bc60-4f08-92fd-7cc5398affa6',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_a81f73de-b5bd-4fee-9357-85f2a731c6d0',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '06012017',
#    'id': 'ep_56509cff-f124-4e52-be70-f09c2db8b6bf',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '92',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '05012016',
#    'id': 'ep_f7505619-0e92-4505-8d69-0b7ad055c6a9',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '6D',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '11012015',
#    'id': 'ep_8f4b0a74-827f-47b4-abc1-0e60ec1b60da',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '89',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '10012015',
#    'id': 'ep_5b1d5088-d2d2-4fc9-97ce-56ac27adec99',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '08012015',
#    'id': 'ep_dca4afaf-86ee-4aca-ac6d-83aace987f5d',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '6D',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '11012012',
#    'id': 'ep_d5737709-c6b8-43e9-9e67-8b72afc759b9',
#    'AccountCondition_code': 'A2',
# ...
#    'id': 'ep_32fbf53e-b6d5-4fe7-aadf-4c3fbdd36004',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012010',
#    'id': 'ep_fddcc4a1-528e-41c4-b444-ec634b22562c',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '12012009',
#    'id': 'ep_f2c4c65f-6bff-4ed4-bcc6-ead89d47e484',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '12012009',
#    'id': 'ep_45f8a3cd-960e-4b86-b6cd-51a6abe96f54',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '06012009',
#    'id': 'ep_4b689461-a9e6-4f45-9fd6-ad69e56ebd9d',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '18'},
#   {'InitialPaymentLevelDate': '03012009',
#    'id': 'ep_fdc2d765-83f4-4816-8220-e156ed2574a6',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '02012009',
#    'id': 'ep_0e1f4737-9bb1-49e5-b7cd-3fa4cfbf411f',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '02012009',
#    'id': 'ep_280cab31-d601-4426-9bf8-8db1ee771ba8',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_006d36c8-ac82-4d28-96e4-f670de4ac71c',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_4787d070-3c60-4dc8-bb70-b69debc2d73f',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_fbce6e10-13a5-4bf9-b872-3173d99f75f9',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_9ef25b04-8ef0-4cfb-ae43-b716f7d2daf0',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_9c89c002-27cb-4836-a583-d127c86f9219',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_fc34bf51-cbbb-4322-8274-88b991f9e3ca',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_0cd98c68-209d-46ed-813c-b46e6b79dc19',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_5f1be051-aa86-49ed-ad57-a2fad69d656b',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_65e68832-a111-4c24-9f1b-3f1cb61cbcbd',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_6dfac92c-1023-4fc9-9852-105664319d7e',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '07012017',
#    'id': 'ep_5a86bd16-57bd-4126-a87f-16167ee5fecb',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '89',
#    'SpecialComment_code': '  '}],
#  'tradeline_amounts': [{'Value': '00000350',
#    'id': 'am_83f02edd-f55c-4d77-8a87-c01c6959cb5e',
#    'TradeLine_id': 'tl_1db28f6a-e1f2-4694-afc8-f1c1660cbfe6',
#    'Qualifier_code': 'L'},
#   {'Value': '00000056',
#    'id': 'am_030a13e9-c47b-4937-be78-7a1e1e42ca52',
#    'TradeLine_id': 'tl_1db28f6a-e1f2-4694-afc8-f1c1660cbfe6',
#    'Qualifier_code': 'H'},
#   {'Value': '00011500',
#    'id': 'am_9d329a05-5a4e-4d62-baa4-5af4378c7fa0',
#    'TradeLine_id': 'tl_38ed728c-204b-499a-bcd8-db7e2f5b20a6',
#    'Qualifier_code': 'L'},
#   {'Value': '00011440',
#    'id': 'am_0fbe17a5-35f7-4a6e-bcb2-6263eaf49f61',
#    'TradeLine_id': 'tl_38ed728c-204b-499a-bcd8-db7e2f5b20a6',
#    'Qualifier_code': 'H'},
#   {'Value': '00012900',
#    'id': 'am_53376d62-5f42-420f-9099-eeb21c7f0daf',
#    'TradeLine_id': 'tl_c81a6fb7-b0cb-4573-afc6-c2f18f4d218a',
#    'Qualifier_code': 'L'},
#   {'Value': '00008979',
#    'id': 'am_35c01ac7-b726-44e2-8a1f-e1be6237e88e',
#    'TradeLine_id': 'tl_c81a6fb7-b0cb-4573-afc6-c2f18f4d218a',
#    'Qualifier_code': 'H'},
#   {'Value': 'UNKNOWN',
#    'id': 'am_a719d7cc-f3cd-4fee-944b-666ab4f5124c',
#    'TradeLine_id': 'tl_a3e221ac-77aa-470d-99f3-812fb4dbc840',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_c4b5917e-96b7-4b94-a7e8-e9613ff05c76',
#    'TradeLine_id': 'tl_a3e221ac-77aa-470d-99f3-812fb4dbc840',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_19b51fda-2f33-42a1-9cd0-34ba12439bb6',
#    'TradeLine_id': 'tl_62a5cef6-c27a-4207-a50c-d3b982f29463',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_7b211eb8-ed6a-4411-9146-919ffd7bc493',
#    'TradeLine_id': 'tl_62a5cef6-c27a-4207-a50c-d3b982f29463',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_e6155a4d-a4f1-420c-9bf4-9e9544bed0a8',
#    'TradeLine_id': 'tl_085a0de0-8010-482b-b26f-9b1c02b6b81b',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_8e578f6e-66e7-4b46-a120-e6ed1ecea30c',
#    'TradeLine_id': 'tl_085a0de0-8010-482b-b26f-9b1c02b6b81b',
#    'Qualifier_code': ' '},
#   {'Value': '00010000',
#    'id': 'am_a21b93f3-549d-4b73-ad84-9b7c92af09ac',
#    'TradeLine_id': 'tl_c235ba85-a002-4b90-adb7-d1ded85fff8a',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_ef8c1ac7-58f0-4ac2-bd00-4c83d230405a',
#    'TradeLine_id': 'tl_c235ba85-a002-4b90-adb7-d1ded85fff8a',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_13e67a50-4ee2-4610-a9b4-68f2e0ad48d8',
#    'TradeLine_id': 'tl_c42692c2-243d-422b-abd8-3104182d8f8e',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_6d9667a4-6824-4454-a239-561769fab0bb',
#    'TradeLine_id': 'tl_c42692c2-243d-422b-abd8-3104182d8f8e',
#    'Qualifier_code': ' '},
#   {'Value': '00040000',
#    'id': 'am_042759f6-d5aa-4316-9542-9d7d2c313c18',
#    'TradeLine_id': 'tl_a5471727-686b-4a21-96b2-e47f0510f8e3',
#    'Qualifier_code': 'O'},
#   {'Value': None,
#    'id': 'am_5fcee2ca-92ce-4134-9073-c03b94110138',
#    'TradeLine_id': 'tl_a5471727-686b-4a21-96b2-e47f0510f8e3',
#    'Qualifier_code': ' '},
#   {'Value': '00080000',
#    'id': 'am_b9c12e57-31b8-4afd-a9a3-c714a4ffeb84',
#    'TradeLine_id': 'tl_3250a832-a4bb-411a-9d26-d86a274dba1f',
#    'Qualifier_code': 'L'},
#   {'Value': '00159087',
#    'id': 'am_cb5e3d97-7209-4290-813a-aacec19e7cb5',
#    'TradeLine_id': 'tl_3250a832-a4bb-411a-9d26-d86a274dba1f',
#    'Qualifier_code': 'H'},
#   {'Value': '00000223',
#    'id': 'am_e29e1f6c-7bba-47c2-8e9f-7e8a2ee18ebc',
#    'TradeLine_id': 'tl_a8128eff-4249-42b7-b53a-8dd4f02ec7dc',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_1a01d89d-556e-414e-b008-a5440e2b0030',
#    'TradeLine_id': 'tl_a8128eff-4249-42b7-b53a-8dd4f02ec7dc',
#    'Qualifier_code': ' '},
#   {'Value': '00150000',
#    'id': 'am_bfb9bd97-ba0e-4c99-9c78-239d6b7d0fde',
#    'TradeLine_id': 'tl_b8f07ac8-c9de-45a2-85de-fc9d86c6f834',
#    'Qualifier_code': 'O'},
#   {'Value': None,
#    'id': 'am_dbe14225-5a21-4089-b2d9-9f741169d925',
#    'TradeLine_id': 'tl_b8f07ac8-c9de-45a2-85de-fc9d86c6f834',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_de19024a-0285-48b6-9b1a-bfd4486fb0de',
#    'TradeLine_id': 'tl_b1508112-3499-4654-9d45-189116e5a85b',
#    'Qualifier_code': 'L'},
#   {'Value': '00000082',
#    'id': 'am_3e7736d5-3044-4f8b-8d24-a9030252c86d',
#    'TradeLine_id': 'tl_b1508112-3499-4654-9d45-189116e5a85b',
#    'Qualifier_code': 'H'},
#   {'Value': '00007000',
#    'id': 'am_d88a4a2d-b47e-4219-9b44-19a44999744d',
#    'TradeLine_id': 'tl_d574cc82-edb8-4d61-95d6-bae8d09c81bd',
#    'Qualifier_code': 'L'},
#   {'Value': '00007000',
#    'id': 'am_cc4f9698-ce84-4414-bf11-f0be896c7f29',
#    'TradeLine_id': 'tl_d574cc82-edb8-4d61-95d6-bae8d09c81bd',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_d165f070-04c8-4411-a898-ea2d2353bf8b',
#    'TradeLine_id': 'tl_c1e93f4e-090a-40f1-b0aa-140412fc73ef',
#    'Qualifier_code': 'L'},
#   {'Value': '00009434',
#    'id': 'am_7bbbaf18-a80d-443b-9fd5-9ab00e8da555',
#    'TradeLine_id': 'tl_c1e93f4e-090a-40f1-b0aa-140412fc73ef',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_3030947a-a734-4bbb-a061-83c5082f6272',
#    'TradeLine_id': 'tl_faa6b915-26a9-4947-921c-66a49d3f85fa',
#    'Qualifier_code': 'L'},
#   {'Value': '00008982',
#    'id': 'am_4c7de10a-5a1f-4055-ba61-d237ace78e4b',
#    'TradeLine_id': 'tl_faa6b915-26a9-4947-921c-66a49d3f85fa',
#    'Qualifier_code': 'H'},
#   {'Value': '00000700',
#    'id': 'am_d4f72096-cc2b-4fdd-ad33-265f9eed19e9',
#    'TradeLine_id': 'tl_c40dd77e-d4b7-45bc-8650-2cd70811c0f8',
#    'Qualifier_code': 'L'},
#   {'Value': '00000283',
#    'id': 'am_983bfe36-d3dd-4591-b571-8237a5c60ed1',
#    'TradeLine_id': 'tl_c40dd77e-d4b7-45bc-8650-2cd70811c0f8',
#    'Qualifier_code': 'H'},
#   {'Value': 'UNKNOWN',
#    'id': 'am_05678421-88f3-4fab-9be2-83881b152491',
#    'TradeLine_id': 'tl_aeab1016-6772-48ae-a2dc-55c7f62019ed',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_23d6b255-0fa9-4a90-8fbf-fa435bedd524',
#    'TradeLine_id': 'tl_aeab1016-6772-48ae-a2dc-55c7f62019ed',
#    'Qualifier_code': ' '},
#   {'Value': '00004072',
#    'id': 'am_36518467-49f7-49b0-b292-a063389d757f',
#    'TradeLine_id': 'tl_8c4bd233-598a-47da-81c1-8e66e3678325',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_b8b7b7f2-9067-4808-8b9a-eeab45fd8318',
#    'TradeLine_id': 'tl_8c4bd233-598a-47da-81c1-8e66e3678325',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_e16ef011-0ba8-4fc8-9fbf-5c936e64e31a',
#    'TradeLine_id': 'tl_178cd1dd-5169-4359-9f22-95a8c6f8ede1',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_9a9a9258-b4ec-40cc-9685-3587b9347cdb',
#    'TradeLine_id': 'tl_178cd1dd-5169-4359-9f22-95a8c6f8ede1',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_593ec130-6445-42da-ad96-0e91073729dc',
#    'TradeLine_id': 'tl_05f1074b-d451-4e85-844e-685e3a137e89',
#    'Qualifier_code': 'L'},
#   {'Value': '00003813',
#    'id': 'am_ec0a5626-39cb-40d4-b567-9d8e5ed9e095',
#    'TradeLine_id': 'tl_05f1074b-d451-4e85-844e-685e3a137e89',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_9e48e95b-8c71-44e6-ac63-ce946a258fe4',
#    'TradeLine_id': 'tl_94fd1768-9b4a-45dc-a148-db5d3eabb107',
#    'Qualifier_code': 'L'},
#   {'Value': '00008679',
#    'id': 'am_0714b71a-112e-400e-89d6-a84fdf762d0f',
#    'TradeLine_id': 'tl_94fd1768-9b4a-45dc-a148-db5d3eabb107',
#    'Qualifier_code': 'H'},
#   {'Value': '00000500',
#    'id': 'am_d2522e54-7328-4648-81eb-625a5c4cadee',
#    'TradeLine_id': 'tl_b43875f8-feb9-4bfa-b7d3-ef2f84f0d9bd',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_631733c3-810a-4513-b475-ea6d0eecb4f9',
#    'TradeLine_id': 'tl_b43875f8-feb9-4bfa-b7d3-ef2f84f0d9bd',
#    'Qualifier_code': ' '},
#   {'Value': '00012000',
#    'id': 'am_25c7a988-3746-43ec-bcfd-c92669431d63',
#    'TradeLine_id': 'tl_0648d5b0-ad98-42aa-8633-52c25418e924',
#    'Qualifier_code': 'L'},
#   {'Value': '00010020',
#    'id': 'am_55e609ca-c536-4c8c-9c10-4b4cd6e9906e',
#    'TradeLine_id': 'tl_0648d5b0-ad98-42aa-8633-52c25418e924',
#    'Qualifier_code': 'H'},
#   {'Value': '00005000',
#    'id': 'am_5df1164d-8d7e-4ead-b22e-d9e4d9dd70ef',
#    'TradeLine_id': 'tl_32389349-213d-4b12-95e1-6fcef8d7e112',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_4395fa28-bddc-4fc8-9d1a-9f4cf503f96a',
#    'TradeLine_id': 'tl_32389349-213d-4b12-95e1-6fcef8d7e112',
#    'Qualifier_code': ' '},
#   {'Value': '00006900',
#    'id': 'am_d1f1972d-a473-42a5-85b5-6fac697868ab',
#    'TradeLine_id': 'tl_213f8cc9-fc63-477a-b8f3-ca2b24860f16',
#    'Qualifier_code': 'L'},
#   {'Value': '00003032',
#    'id': 'am_b8c90e24-0add-454e-916e-f0185086a1db',
#    'TradeLine_id': 'tl_213f8cc9-fc63-477a-b8f3-ca2b24860f16',
#    'Qualifier_code': 'H'},
#   {'Value': '00001000',
#    'id': 'am_e1b029ac-17ae-46b9-8965-4e12d1ebfc91',
#    'TradeLine_id': 'tl_a4b07e08-c44c-4ec1-a83a-8e281c7a9fbd',
#    'Qualifier_code': 'L'},
#   {'Value': '00000285',
#    'id': 'am_26bbf43e-4cf7-4c0a-80a8-333e32f9d163',
#    'TradeLine_id': 'tl_a4b07e08-c44c-4ec1-a83a-8e281c7a9fbd',
#    'Qualifier_code': 'H'},
#   {'Value': '00001500',
#    'id': 'am_06fd4755-164c-4c87-814a-5ad1ea631a1b',
#    'TradeLine_id': 'tl_dd83ef63-3040-467a-9030-bacc163110d9',
#    'Qualifier_code': 'L'},
#   {'Value': '00000546',
#    'id': 'am_b707b279-0f27-4f40-920d-be00c3d1a62e',
#    'TradeLine_id': 'tl_dd83ef63-3040-467a-9030-bacc163110d9',
#    'Qualifier_code': 'H'},
#   {'Value': '00003600',
#    'id': 'am_e6baae5c-eae7-4a5b-b118-3a454d5010c2',
#    'TradeLine_id': 'tl_554d5257-b1c4-4db8-a630-4f1e0c6fd25d',
#    'Qualifier_code': 'L'},
#   {'Value': '00001184',
#    'id': 'am_b90bcedc-ae6d-47ee-8683-8ee414537b64',
#    'TradeLine_id': 'tl_554d5257-b1c4-4db8-a630-4f1e0c6fd25d',
#    'Qualifier_code': 'H'},
#   {'Value': '00000723',
#    'id': 'am_069b3596-8da2-4572-92e3-45baf19e510b',
#    'TradeLine_id': 'tl_de6a9ed7-cdf8-4c13-aee4-ad4dc023c1ab',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_8094abbe-5b10-414e-8245-1a187ecbc9c7',
#    'TradeLine_id': 'tl_de6a9ed7-cdf8-4c13-aee4-ad4dc023c1ab',
#    'Qualifier_code': ' '},
#   {'Value': '00019000',
#    'id': 'am_dc13ca75-5f3d-4db3-a8f8-cfd244e4c273',
#    'TradeLine_id': 'tl_2bf3e18e-fa0c-4d1e-bf84-f219d758a405',
#    'Qualifier_code': 'L'},
#   {'Value': '00010513',
#    'id': 'am_67774c4a-13d0-4199-bbd4-6ff118327118',
#    'TradeLine_id': 'tl_2bf3e18e-fa0c-4d1e-bf84-f219d758a405',
#    'Qualifier_code': 'H'},
#   {'Value': '00012200',
#    'id': 'am_6e8ade4b-fe29-4a35-8120-c7f1dd41b402',
#    'TradeLine_id': 'tl_46599e98-efe1-437d-8bfc-1523a3250cf8',
#    'Qualifier_code': 'L'},
#   {'Value': '00000629',
#    'id': 'am_7ec0c5ed-3154-4e1f-9ca5-d7f4625d7bd0',
#    'TradeLine_id': 'tl_46599e98-efe1-437d-8bfc-1523a3250cf8',
#    'Qualifier_code': 'H'},
#   {'Value': '00001047',
#    'id': 'am_c0fcf2c1-a151-4901-8892-1fbc70ec21e2',
#    'TradeLine_id': 'tl_335559fd-6665-4da5-b5a9-9566f188e3c7',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_fb818e7a-898f-441b-bc66-8b51e51d5f65',
#    'TradeLine_id': 'tl_335559fd-6665-4da5-b5a9-9566f188e3c7',
#    'Qualifier_code': ' '},
#   {'Value': '00007361',
#    'id': 'am_cc874660-a2d0-4389-8825-2e53378ccadf',
#    'TradeLine_id': 'tl_a6592400-9fcd-44c5-ab51-32715778e8f8',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_4dd6e759-bea2-4030-9f2e-a76e8f319923',
#    'TradeLine_id': 'tl_a6592400-9fcd-44c5-ab51-32715778e8f8',
#    'Qualifier_code': ' '},
#   {'Value': '00001500',
#    'id': 'am_bc49cd77-e919-4876-89cb-5a65d773dc0b',
#    'TradeLine_id': 'tl_add11747-c117-42de-bdec-130a6cc899ff',
#    'Qualifier_code': 'L'},
#   {'Value': '00000089',
#    'id': 'am_437b4598-c470-4bdf-8420-dad6b0ffd728',
#    'TradeLine_id': 'tl_add11747-c117-42de-bdec-130a6cc899ff',
#    'Qualifier_code': 'H'},
#   {'Value': '00150000',
#    'id': 'am_e201de52-84d8-4e0e-92aa-43fdb07e4de7',
#    'TradeLine_id': 'tl_60319ada-d9ff-43c0-89b9-04470f2fb38c',
#    'Qualifier_code': 'L'},
#   {'Value': '00022118',
#    'id': 'am_c7136f6f-dc66-4f90-8ae9-f0ffeaad640e',
#    'TradeLine_id': 'tl_60319ada-d9ff-43c0-89b9-04470f2fb38c',
#    'Qualifier_code': 'H'}]}

# %% [markdown]
# Take a preview of table PrequalResult

# %%
pd.DataFrame(RESULT_OBJ_DICT['prequal_results'])
# Out:
#                   model  pk  loanapp_id  result error_reason detail_results  \
# 0  common.prequalresult   1         194    True   no reasons           None
#
#   fico_v2    report_type username                created_at  ...  \
# 0     695  CreditProfile      cho  2016-08-04T00:29:03.067Z  ...
#
#   business_credit_card_total_limits business_credit_card_total_balances  \
# 0                              None                                None
#
#   business_total_mortgage_monthly_payments  \
# 0                                     None
#
#   business_total_monthly_debt_payments bkdate fico_v3  \
# 0                                 None   None    None
#
#   total_mortgage_monthly_payments       version       role  \
# 0                            None  CF Microloan  applicant
#
#                              xml_detail_id
# 0  xd_eb7c47ff-8048-441a-b153-522643657d03
#
# [1 rows x 24 columns]

# %% [markdown]
# Take a preview of table Product

# %%
pd.DataFrame(RESULT_OBJ_DICT['products'])
# Out:
#                                 @xmlns  \
# 0  http://www.experian.com/ARFResponse
#
#                                         id  \
# 0  pd_82762c24-7362-4c6d-a95c-01da3be29db0
#
#                          credit_profile_id
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea

# %% [markdown]
# Take a preview of table CreditProfile

# %%
pd.DataFrame(RESULT_OBJ_DICT['credit_profiles'])
# Out:
#                                         id  \
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea
#
#                                  header_id  \
# 0  hd_530c0a97-f26c-4d67-b153-3b11af4b1cea
#
#                                 inquiry_id
# 0  iq_e15be34d-446d-4998-b652-b8e98fcedd46

# %% [markdown]
# Take a preview of table Header

# %%
pd.DataFrame(RESULT_OBJ_DICT['headers'])
# Out:
#   ReportDate ReportTime Preamble ARFVersion  \
# 0   10032017     140607     TWA1         07
#
#                                         id
# 0  hd_530c0a97-f26c-4d67-b153-3b11af4b1cea

# %% [markdown]
# Take a preview of table RiskModel

# %%
pd.DataFrame(RESULT_OBJ_DICT['risk_models'])
# Out:
#   Score ScoreFactorCodeOne ScoreFactorCodeTwo ScoreFactorCodeThree  \
# 0  0808                 10                 09                   05
# 1  0807                 30                 05                   11
#
#   ScoreFactorCodeFour                                       id  \
# 0                None  rm_3f81f6bf-6b10-47f4-b21c-06bd3242fec8
# 1                None  rm_17da3e39-4320-4f1e-a642-7f3da2160e71
#
#                           CreditProfile_id ModelIndicator_code Evaluation_code
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                  F                P
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                  AA               P

# %% [markdown]
# Take a preview of table ConsumerIdentity

# %%
pd.DataFrame(RESULT_OBJ_DICT['consumer_identities'])
# Out:
#                                                 Name   YOB  \
# 0         {'Surname': 'SCALICI', 'First': 'WILLIAM'}  None
# 1  {'Type': {'@code': 'N'}, 'Surname': 'SCALICI',...  None
# 2  {'Surname': 'SCALICI', 'First': 'WILLIAM', 'Ge...  None
# 3  {'Type': {'@code': 'A'}, 'Surname': 'ANTHONY',...  None
#
#                                         id  \
# 0  ci_7a8676e3-94f3-49e5-9f67-a224ba45a787
# 1  ci_0e5ca0cd-0121-438d-a996-59c277725087
# 2  ci_260f4c36-42b7-4b0b-901c-1699835bc99c
# 3  ci_9f9a2e62-5a73-4726-b9d1-9a90181964ff
#
#                           CreditProfile_id
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea
# 2  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea
# 3  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea

# %% [markdown]
# Take a preview of table AddressInfo

# %%
pd.DataFrame(RESULT_OBJ_DICT['addr_infos'])
# Out:
#   FirstReportedDate LastUpdatedDate TimesReported LastReportingSubcode  \
# 0          10272003        12202015            00              7370142
# 1          01012011        01012011            00                 None
# 2          05282006        11022010            12                 None
#
#   StreetPrefix   StreetName StreetSuffix    City State        Zip  \
# 0         7324  84TH STREET        CT SW  TACOMA    WA  984986380
# 1       3260 S       TACOMA          WAY  TACOMA    WA  984094725
# 2       3216 S       TACOMA          WAY  TACOMA    WA  984094725
#
#   CensusGeoCode                                       id  \
# 0          None  ai_8a249318-d504-4814-b0d2-28e656b033e2
# 1          None  ai_180a3b79-fc80-4969-91ea-4568b16cd4b5
# 2          None  ai_794d9a61-3eae-405d-b469-1dc26e2a8954
#
#                           CreditProfile_id Origination_code DwellingType_code  \
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                2                 S
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                1                 S
# 2  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                1                 S
#
#   HomeOwnership_code
# 0
# 1
# 2

# %% [markdown]
# Take a preview of table EmploymentInfo

# %%
pd.DataFrame(RESULT_OBJ_DICT['employ_infos'])
# Out:
#   FirstReportedDate LastUpdatedDate        Name AddressFirstLine  \
# 0          04082011        04082011  GM RETIRED             None
# 1          12282009        06112010     RETIRED             None
#
#   AddressSecondLine AddressExtraLine   Zip  \
# 0              None             None  None
# 1              None             None  None
#
#                                         id  \
# 0  ei_da29547c-22e3-455b-a51f-79af941f6917
# 1  ei_7fe91e47-c26a-4527-96e1-90ec73229d55
#
#                           CreditProfile_id Origination_code
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                2
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                2

# %% [markdown]
# Take a preview of table TradeLine

# %%
pd.DataFrame(RESULT_OBJ_DICT['trade_lines'])
# Out:
#     OpenDate StatusDate MaxDelinquencyDate BalanceDate BalanceAmount  \
# 0   06011981   05012017               None    05192017          None
# 1   08282007   03012012               None    03182012          None
# 2   06102006   07012017               None    07232017      00000000
# 3   08282007   03012012               None    04282012      00000000
# 4   03012002   04012009               None    04012009      00000000
# ..       ...        ...                ...         ...           ...
# 31  06011983   08012017               None    08072017      00000052
# 32  05011984   08012017               None    08072017      00000599
# 33  05011984   08012017               None    08072017      00001960
# 34  08182016   08012017               None    08072017      00000000
# 35  08122015   07012017               None    07282017      00004607
#
#    AmountPastDue ConsumerComment MonthsHistory DelinquenciesOver30Days  \
# 0           None            None            15                      00
# 1           None            None            56                      00
# 2           None            None            96                      00
# 3           None            None            03                      00
# 4           None            None            86                      00
# ..           ...             ...           ...                     ...
# 31          None            None            01                      00
# 32          None            None            01                      00
# 33          None            None            01                      00
# 34          None            None            12                      00
# 35          None            None            24                      00
#
#    DelinquenciesOver60Days  ... Evaluation_code AccountType_code  \
# 0                       00  ...               N               18
# 1                       00  ...               N               18
# 2                       00  ...               N               18
# 3                       00  ...               N               18
# 4                       00  ...               N               18
# ..                     ...  ...             ...              ...
# 31                      00  ...               P               18
# 32                      00  ...               P               18
# 33                      00  ...               P               18
# 34                      00  ...               P               07
# 35                      00  ...               P               47
#
#    TermsDuration_code Status_code ECOA_code OpenOrClosed_code  \
# 0                 REV          05         1                 C
# 1                 REV          05         1                 C
# 2                 REV          11         2                 C
# 3                 REV          11         1                 C
# 4                 REV          11         0                 C
# ..                ...         ...       ...               ...
# 31                REV          11         1                 O
# 32                001          11         1                 O
# 33                REV          11         1                 O
# 34                REV          11         1                 O
# 35                REV          11         1                 O
#
#    RevolvingOrInstallment_code MonthlyPaymentType_code KOB_code AccountNumber
# 0                            R                               OC           NaN
# 1                            R                               BC           NaN
# 2                            R                               BC           NaN
# 3                            R                               BC           NaN
# 4                            R                               NZ           NaN
# ..                         ...                     ...      ...           ...
# 31                           R                               BC           NaN
# 32                           R                               BC           NaN
# 33                           R                               BC           NaN
# 34                           R                               CG           NaN
# 35                           R                               BB           NaN
#
# [36 rows x 31 columns]

# %% [markdown]
# Take a preview of table Inquiry

# %%
pd.DataFrame(RESULT_OBJ_DICT['inquiries'])
# Out:
#        Date   Amount  Subcode SubscriberDisplayName  \
# 0  08182016  UNKNOWN  1640007     SYNCB/BROOKS BROS
#
#                                         id Type_code Terms_code KOB_code
# 0  iq_3fc54910-a551-4314-85d9-51c8d0d5cfec        31        UNK       FF

# %% [markdown]
# Take a preview of table InformationMessage

# %%
pd.DataFrame(RESULT_OBJ_DICT['info_msgs'])
# Out:
#   MessageNumber                                MessageText  \
# 0            92  0092 REQUESTED PRODUCT OPTION NOT ALLOWED
# 1            84                           0084 SSN MATCHES
#
#                                         id  \
# 0  im_28268464-7836-441b-a0d0-18f3205ef32c
# 1  im_ebdda4fd-48a0-41fc-93db-5e2749d0ba4f
#
#                           CreditProfile_id
# 0  cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6
# 1  cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6

# %%
Take a preview of table EnhancedPaymentData

# %%
pd.DataFrame(RESULT_OBJ_DICT['enhanced_pm_data'])
# Out:
#    InitialPaymentLevelDate                                       id  \
# 0                 05012017  ep_3c421ba6-2346-428c-8d27-68fe80c0d68c
# 1                 03012012  ep_568ec0f9-f267-4dc6-9a1a-a900a502f03b
# 2                 07012017  ep_047b1fda-32da-4a2f-9132-2b319fafbd66
# 3                 03012012  ep_1d2705f9-1a92-478d-b1d2-6a116354c0c6
# 4                 04012009  ep_67ca52d4-0e3f-4043-acb4-4e35c00b3135
# ..                     ...                                      ...
# 31                08012017  ep_0cd98c68-209d-46ed-813c-b46e6b79dc19
# 32                08012017  ep_5f1be051-aa86-49ed-ad57-a2fad69d656b
# 33                08012017  ep_65e68832-a111-4c24-9f1b-3f1cb61cbcbd
# 34                08012017  ep_6dfac92c-1023-4fc9-9852-105664319d7e
# 35                07012017  ep_5a86bd16-57bd-4126-a87f-16167ee5fecb
#
#    AccountCondition_code PaymentStatus_code AccountType_code  \
# 0                     05                 11               18
# 1                     05                 11               18
# 2                     A3                 11               18
# 3                     A3                 11               18
# 4                     A3                 11               18
# ..                   ...                ...              ...
# 31                    A1                 11               18
# 32                    A1                 11               18
# 33                    A1                 11               18
# 34                    A1                 11               07
# 35                    A1                 11               89
#
#    SpecialComment_code
# 0                   51
# 1                   40
# 2                   19
# 3                   18
# 4                   19
# ..                 ...
# 31
# 32
# 33
# 34
# 35
#
# [36 rows x 6 columns]

# %%
Take a preview of table EnhancedPaymentData

# %%
pd.DataFrame(RESULT_OBJ_DICT['tradeline_amounts'])
