# %%
import json
import pprint
import uuid
import xmltodict

RESULT_TABLE_NAMES = ['prequal_results', 'xml_details', 'products', 'credit_profiles', 'headers', 'risk_models', 'consumer_identities', 'addr_infos', 'employ_infos', 'trade_lines', 'inquiries', 'info_msgs', 'enhanced_pm_data', 'tradeline_amounts']
with open("./data/prequalresult.json", 'r') as f:
    json_file = json.load(f)
json_file
# Out:
# [{'model': 'common.prequalresult',
#   'pk': 1,
#   'fields': {'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant'}}]

# %% [markdown]
# Building PrequalResult table objects

# %%
# initialize result object lists
RESULT_OBJ_DICT = dict((key, []) for key in RESULT_TABLE_NAMES)
ATTR_CODE_DICT = {
    'risk_models': ['ModelIndicator', 'Evaluation'],
    'addr_infos': ['Origination', 'DwellingType', 'HomeOwnership'],
    'employ_infos': ['Origination'],
    'trade_lines': ['SpecialComment', 'Evaluation', 'AccountType', 'TermsDuration', 'Status', 'OpenOrClosed', 'RevolvingOrInstallment', 'MonthlyPaymentType', 'KOB'],
    'tradeline_amounts': ['Qualifier'],
    'enhanced_pm_data': ['AccountCondition', 'PaymentStatus', 'AccountType', 'SpecialComment'],
    'inquiries': ['Type', 'Terms', 'KOB']
}

prequal_results = json_file
for prequal_result in prequal_results:
    prequal_result.update(prequal_result.pop('fields'))
    xml_detail_id = "xd_{}".format(uuid.uuid4())
    prequal_result['xml_detail_id'] = xml_detail_id
    RESULT_OBJ_DICT['prequal_results'].append(prequal_result)
    
    # initializing XML_Detail object
    xml_dict = xmltodict.parse(result['xml_data'], dict_constructor=dict)['NetConnectResponse']
    xml_dict['id'] = xml_detail_id
    RESULT_OBJ_DICT['xml_details'].append(xml_dict)
    product_id = "pd_{}".format(uuid.uuid4())
    xml_dict['product_id'] = product_id
    
    # initializing Product object
    product_obj = xml_dict.pop('Products')
    product_obj['id'] = product_id
    RESULT_OBJ_DICT['products'].append(product_obj)
    credit_profile_id = "cp_{}".format(uuid.uuid4())
    product_obj['credit_profile_id'] = credit_profile_id
    
    # initializing CreditProfile object
    credit_profile_obj = product_obj.pop('CreditProfile')
    credit_profile_obj['id'] = credit_profile_id
    RESULT_OBJ_DICT['credit_profiles'].append(credit_profile_obj)
    
    
    ## handling RiskModels in CreditProfile
    for risk_model in credit_profile_obj.pop('RiskModel'):
        risk_model['id'] = "rm_{}".format(uuid.uuid4())
        risk_model['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['risk_models'].append(risk_model)
    
    # initializing Header object in CreditProfile
    header_id = "hd_{}".format(uuid.uuid4())
    credit_profile_obj['header_id'] = header_id
    header_obj = credit_profile_obj.pop('Header')
    header_obj['id'] = header_id
    RESULT_OBJ_DICT['headers'].append(header_obj)
    
    ## handling ConsumerIdentities in CreditProfile
    for consumer_identity in credit_profile_obj.pop('ConsumerIdentity'):
        consumer_identity['id'] = "ci_{}".format(uuid.uuid4())
        consumer_identity['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['consumer_identities'].append(consumer_identity)
    
    ## handling AddressInformations in CreditProfile
    for addr_info in credit_profile_obj.pop('AddressInformation'):
        addr_info['id'] = "ai_{}".format(uuid.uuid4())
        addr_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['addr_infos'].append(addr_info)
       
    ## handling EmploymentInformations in CreditProfile
    for employ_info in credit_profile_obj.pop('EmploymentInformation'):
        employ_info['id'] = "ei_{}".format(uuid.uuid4())
        employ_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['employ_infos'].append(employ_info)
        
    ## handling TradeLines in CreditProfile
    code_attrs = ['SpecialComment', 'Evaluation', 'AccountType', 'TermsDuration', 'Status', 'OpenOrClosed', 'RevolvingOrInstallment', 'MonthlyPaymentType', 'KOB']
    for trade_line in credit_profile_obj.pop('TradeLine'):
        trade_line['id'] = "tl_{}".format(uuid.uuid4())
        trade_line['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['trade_lines'].append(trade_line)
        
        # initializing EnhancedPaymentData object in TradeLine
        enhanced_pm_data_id = "ep_{}".format(uuid.uuid4())
        trade_line['enhanced_pm_data_id'] = enhanced_pm_data_id
        enhanced_pm_data_obj = trade_line.pop('EnhancedPaymentData')
        enhanced_pm_data_obj['id'] = enhanced_pm_data_id
        RESULT_OBJ_DICT['enhanced_pm_data'].append(enhanced_pm_data_obj)
        
        ## handling Amount object in TradeLine
        for amt_obj in trade_line.pop('Amount'):
            amt_obj['id'] = "am_{}".format(uuid.uuid4())
            amt_obj['TradeLine_id'] = trade_line['id']
            RESULT_OBJ_DICT['tradeline_amounts'].append(amt_obj)
    
    # initializing Inquiry object in CreditProfile
    inquiry_id = "iq_{}".format(uuid.uuid4())
    credit_profile_obj['inquiry_id'] = inquiry_id
    inquiry_obj = credit_profile_obj.pop('Inquiry')
    inquiry_obj['id'] = inquiry_id
    RESULT_OBJ_DICT['inquiries'].append(inquiry_obj)
    
    ## handling InformationalMessages in CreditProfile
    for info_msg in credit_profile_obj.pop('InformationalMessage'):
        info_msg['id'] = "im_{}".format(uuid.uuid4())
        info_msg['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['info_msgs'].append(info_msg)
    
# converting sub-attrs into _code
for attr, code_attr_list in ATTR_CODE_DICT.items():
    attr_obj_list = RESULT_OBJ_DICT[attr]
    for attr_obj in attr_obj_list:
        for attr in code_attr_list:
            if attr in attr_obj:
                code = attr_obj[attr]['@code']
            else:
                code = ''
            attr_obj["{}_code".format(attr)] = code
            attr_obj.pop(attr, None)
    
RESULT_OBJ_DICT
# Out:
# {'prequal_results': [{'model': 'common.prequalresult',
#    'pk': 1,
#    'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant',
#    'xml_detail_id': 'xd_eb7c47ff-8048-441a-b153-522643657d03'}],
#  'xml_details': [{'@xmlns': 'http://www.experian.com/NetConnectResponse',
#    'CompletionCode': '0000',
#    'ReferenceId': 'testing 123',
#    'TransactionId': '41588980',
#    'id': 'xd_eb7c47ff-8048-441a-b153-522643657d03',
#    'product_id': 'pd_82762c24-7362-4c6d-a95c-01da3be29db0'}],
#  'products': [{'@xmlns': 'http://www.experian.com/ARFResponse',
#    'id': 'pd_82762c24-7362-4c6d-a95c-01da3be29db0',
#    'credit_profile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea'}],
#  'credit_profiles': [{'id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'header_id': 'hd_530c0a97-f26c-4d67-b153-3b11af4b1cea',
#    'inquiry_id': 'iq_e15be34d-446d-4998-b652-b8e98fcedd46'}],
#  'headers': [{'ReportDate': '10032017',
#    'ReportTime': '140607',
#    'Preamble': 'TWA1',
#    'ARFVersion': '07',
#    'id': 'hd_530c0a97-f26c-4d67-b153-3b11af4b1cea'}],
#  'risk_models': [{'Score': '0808',
#    'ScoreFactorCodeOne': '10',
#    'ScoreFactorCodeTwo': '09',
#    'ScoreFactorCodeThree': '05',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_3f81f6bf-6b10-47f4-b21c-06bd3242fec8',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'ModelIndicator_code': 'F ',
#    'Evaluation_code': 'P'},
#   {'Score': '0807',
#    'ScoreFactorCodeOne': '30',
#    'ScoreFactorCodeTwo': '05',
#    'ScoreFactorCodeThree': '11',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_17da3e39-4320-4f1e-a642-7f3da2160e71',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'ModelIndicator_code': 'AA',
#    'Evaluation_code': 'P'}],
#  'consumer_identities': [{'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_7a8676e3-94f3-49e5-9f67-a224ba45a787',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea'},
#   {'Name': {'Type': {'@code': 'N'},
#     'Surname': 'SCALICI',
#     'First': 'AS',
#     'Middle': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_0e5ca0cd-0121-438d-a996-59c277725087',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea'},
#   {'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM', 'Gen': 'JR'},
#    'YOB': None,
#    'id': 'ci_260f4c36-42b7-4b0b-901c-1699835bc99c',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea'},
#   {'Name': {'Type': {'@code': 'A'},
#     'Surname': 'ANTHONY',
#     'First': 'WILLIAM',
#     'Middle': 'R'},
#    'YOB': None,
#    'id': 'ci_9f9a2e62-5a73-4726-b9d1-9a90181964ff',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea'}],
#  'addr_infos': [{'FirstReportedDate': '10272003',
#    'LastUpdatedDate': '12202015',
#    'TimesReported': '00',
#    'LastReportingSubcode': '7370142',
#    'StreetPrefix': '7324',
#    'StreetName': '84TH STREET',
#    'StreetSuffix': 'CT SW',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984986380',
#    'CensusGeoCode': None,
#    'id': 'ai_8a249318-d504-4814-b0d2-28e656b033e2',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'Origination_code': '2',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '01012011',
#    'LastUpdatedDate': '01012011',
#    'TimesReported': '00',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3260 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_180a3b79-fc80-4969-91ea-4568b16cd4b5',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '05282006',
#    'LastUpdatedDate': '11022010',
#    'TimesReported': '12',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3216 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_794d9a61-3eae-405d-b469-1dc26e2a8954',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '}],
#  'employ_infos': [{'FirstReportedDate': '04082011',
#    'LastUpdatedDate': '04082011',
#    'Name': 'GM RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_da29547c-22e3-455b-a51f-79af941f6917',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'Origination_code': '2'},
#   {'FirstReportedDate': '12282009',
#    'LastUpdatedDate': '06112010',
#    'Name': 'RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_7fe91e47-c26a-4527-96e1-90ec73229d55',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'Origination_code': '2'}],
#  'trade_lines': [{'OpenDate': '06011981',
#    'StatusDate': '05012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '05192017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '15',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01032016',
#    'Subcode': '1401790',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_a9928133-23dd-4d24-97bb-344683a6c870',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_97e361ad-12a9-4cb2-a4e9-fd4ad50a9ca2',
#    'SpecialComment_code': '28',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03182012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1213727',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_1d148def-1b24-47f2-9aaa-78d7adea391f',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_a65fc9db-ee1d-4dfc-8348-b1a648468244',
#    'SpecialComment_code': '31',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '06102006',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '07232017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '96',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0---------CCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '07212015',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_29e7dc38-0c64-45df-8d8e-5b5ff8b9c492',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_23256fd4-5a61-4921-8cc5-b601812847bb',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '04282012',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '03',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01122010',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_43c9b5f2-ae33-4e33-bd06-8d9f778843f3',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_1e5b8723-2b57-4e0b-b1d8-4e9f3bb4f1b3',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC'},
#   {'OpenDate': '03012002',
#    'StatusDate': '04012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '0'},
#    'BalanceDate': '04012009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '86',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00--------0-----------00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12102006',
#    'Subcode': '1439507',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_b5819f40-3f54-4e57-a3dd-238f9f19a422',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_88525fe9-f6f1-4fb9-bb53-f900f0f5302f',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'NZ'},
#   {'OpenDate': '03012007',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03282009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '26',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0----------0',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_3a095ad7-7d56-479d-959a-bc2af7933a27',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_d8760f7a-7d80-46d3-9c23-e6502583f694',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '04072017',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08032017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '04',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00C',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_38513b97-e9b0-45eb-9901-89414d36765b',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_4242611f-c729-4a47-9c7e-d473b31478d6',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09012016',
#    'StatusDate': '06012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '06282017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '6037453215420',
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '06262017',
#    'Subcode': '1945962',
#    'SubscriberDisplayName': 'VERIZON NEW ENGLAND IN',
#    'id': 'tl_6e329b36-c9db-426e-bafa-3e21cf24dfbd',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_7f579b2d-51da-48f2-be97-3f21c9d5e3d3',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '31',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'UT'},
#   {'OpenDate': '08122015',
#    'StatusDate': '05012016',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '05282016',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '15621485',
#    'MonthsHistory': '10',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_7bc0891d-38f7-41df-8fe8-c969c832032c',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_2895f198-6478-4d3b-a812-e8015af620a2',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': 'UNK',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '02182007',
#    'StatusDate': '11012015',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '11282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000CCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_04978fb6-5346-46f2-aef1-b130442a2ec7',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_682647c7-6853-4ee8-8277-fd6b90d6ba7c',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '05011984',
#    'StatusDate': '10012015',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '10082015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_0c85fa37-d7ca-4532-9d18-bdcbde662348',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_12995af0-a300-4907-8972-eef482466896',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '12142012',
#    'StatusDate': '08012015',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '08282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '13750088',
#    'MonthsHistory': '33',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_261e6bbf-0892-4106-8a0d-21fd83c07d56',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_2f743643-59d5-49e0-abc0-22d6f15ad27c',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': '180',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '10202007',
#    'StatusDate': '11012012',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '11102012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '68',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_31020ed2-6e25-4dfc-8122-5ffce0f28a7a',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_26bf5ca5-0874-4bf1-8f94-c9ffbdff2840',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '10202007',
#    'StatusDate': '10012011',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '10282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1220390',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_2b6d0da0-58e0-4015-96ba-700e5e9717d9',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_d93f1be4-dbc6-40e6-9edf-91579ce9345f',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01012007',
#    'StatusDate': '07012011',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '07282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000CCCCCC',
#    'Subcode': '1290016',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_09682ab4-37d0-45f0-98e1-fc0eb0fd8405',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_3051194b-1e93-4533-91cc-f38e8e94082a',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01092008',
#    'StatusDate': '06012011',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '3'},
#    'BalanceDate': '06082011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '32',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000CCCCCCCCCC',
#    'Subcode': '1290138',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_80b02b4e-42b6-42dd-8721-44c74bd3a80b',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_77b95037-9ae8-4a9b-bde2-d328e31c6a45',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01082006',
#    'StatusDate': '02012011',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '02282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '62',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B0000000000000000--------',
#    'Subcode': '6230125',
#    'SubscriberDisplayName': 'BAC/FLEET-BKCARD',
#    'id': 'tl_4c924d30-d43a-453b-895f-c210a4a5a92f',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_86bfaecf-3e17-4d16-b3ec-4bbc137a28cc',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09242005',
#    'StatusDate': '11012010',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '3'},
#    'BalanceDate': '11282010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '60',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1260958',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_098c2bd2-07a7-4215-9e43-ce5ca6b0b86a',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_edb57935-65ba-4a13-b1fa-2555b62cf506',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09102007',
#    'StatusDate': '03012010',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03072010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '30',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000000CCCCCCC',
#    'Subcode': '3245600',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_8454ba09-b35b-4640-9a52-e2fdb98ca863',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_7fd5088c-ad18-4991-a99c-674d983a33e4',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_aba97316-b195-4206-abb3-d258d39c8956',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_48d76247-6b67-470f-a61f-841b66cdd949',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_b3807ac7-8337-498b-ada7-d62d908cf0b4',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_a8c99170-62e7-45a1-8ced-d6683d9fdcd3',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '04222005',
#    'StatusDate': '06012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '06282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '1201520',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_669270c3-f861-47e9-b904-c16489ed924f',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_399f198c-4110-471b-b3cc-fd39e93af023',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01072008',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03012009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '14',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCC',
#    'Subcode': '1202270',
#    'SubscriberDisplayName': 'WF/WB',
#    'id': 'tl_aff966b5-85c1-46c9-9f26-0fd825571e08',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_6770f56f-5e83-4944-9801-77c922c8ff15',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '02282004',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '02282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '61',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC00000000CCCCC',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_2e5976ae-ff59-41f8-bae1-fd8e7aa8e888',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_9ab7ed76-a659-4200-a170-447d02b8e0a0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '02151994',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '02222009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B---------------C--------',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_024cc26a-f451-4f0a-8784-e1c8c65ff3c7',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_459830ac-1952-4c0c-bfc2-f81de79a5f6e',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09072013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '08232017',
#    'BalanceAmount': '00000025',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C0CCCCCCCCC000CCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000010',
#    'LastPaymentDate': '06082017',
#    'Subcode': '3178962',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_2f4f1b3b-4ecd-4877-9081-71ebda0382ed',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_db193c77-661b-4314-a8b7-6f7f31e75110',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'ZR'},
#   {'OpenDate': '09011979',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08202017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '75',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000CCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '05092017',
#    'Subcode': '1335510',
#    'SubscriberDisplayName': 'SYNCB/EXXON MOBIL',
#    'id': 'tl_5fdf7588-2282-471b-bf62-ddb10ac4af15',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_888403fe-8590-4995-9d21-4572db388e96',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC'},
#   {'OpenDate': '06182013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08162017',
#    'BalanceAmount': '00000160',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '51',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0C',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07272017',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_f51c158f-6dc7-4d76-8a0e-a958339828bf',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_2b4b6634-9a7d-492c-893c-c11586ad9ca8',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'DV'},
#   {'OpenDate': '04272007',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '3'},
#    'BalanceDate': '08152017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000000000CCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12282015',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_9b9ace82-fc65-4dae-9dac-b99b327804c7',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_7be3fcec-b3dd-4fdf-a61c-66e35b262de7',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'DV'},
#   {'OpenDate': '09012010',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08142017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '84',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000C000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '08282016',
#    'Subcode': '1349040',
#    'SubscriberDisplayName': 'FILENES',
#    'id': 'tl_513fca15-e2c8-41ec-8b3a-1e1ebf29f189',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_020a9321-9157-4755-bccc-2066488d6c3e',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'ZR'},
#   {'OpenDate': '04011998',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08092017',
#    'BalanceAmount': '00001354',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '97',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07242017',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_441f578f-67e1-4995-bf6b-1d81fb57a5cd',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_d1986cc6-a650-4b99-ad51-f714974bb632',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'BC'},
#   {'OpenDate': '06011983',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000052',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_8f8e92a9-03fc-4396-809f-d960ae3ae302',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_2ac64b86-5b8d-4e5e-ae8a-6d5d715a6f01',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000599',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_d4dba46f-78c6-447d-86d1-e25b6cec8d20',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_6fb1bd30-3a3a-4172-961d-4bac25f414cf',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00001960',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_ed126d9c-3aef-4738-b9d3-41e82828b3de',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_309c89d5-ae2b-4cf6-8733-7d1cf5c94a29',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '08182016',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '0000000000CC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '09192016',
#    'Subcode': '2613430',
#    'SubscriberDisplayName': 'SYNCB/BROOK BROS',
#    'id': 'tl_75308afd-1e69-4ad0-ba54-b307cb32df0e',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_f1409315-7d65-4fd5-93a0-f12a30cb0d9f',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'CG'},
#   {'OpenDate': '08122015',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '07282017',
#    'BalanceAmount': '00004607',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '24',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0',
#    'MonthlyPaymentAmount': 'UNKNOWN',
#    'LastPaymentDate': '07102017',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_837f60d8-3608-44f3-b3d4-4e740b2fe937',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#    'enhanced_pm_data_id': 'ep_7bebf9c9-58a3-4ca7-ba3a-7e4ebe1a07a5',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BB'}],
#  'inquiries': [{'Date': '08182016',
#    'Amount': 'UNKNOWN',
#    'Subcode': '1640007',
#    'SubscriberDisplayName': 'SYNCB/BROOKS BROS',
#    'id': 'iq_e15be34d-446d-4998-b652-b8e98fcedd46',
#    'Type_code': '31',
#    'Terms_code': 'UNK',
#    'KOB_code': 'FF'}],
#  'info_msgs': [{'MessageNumber': '92',
#    'MessageText': '0092 REQUESTED PRODUCT OPTION NOT ALLOWED',
#    'id': 'im_f91de84e-d4f0-4622-941e-3443c509a9cd',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea'},
#   {'MessageNumber': '84',
#    'MessageText': '0084 SSN MATCHES',
#    'id': 'im_d46057bb-8bc2-4a0f-ab70-73f9f262bc9b',
#    'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea'}],
#  'enhanced_pm_data': [{'InitialPaymentLevelDate': '05012017',
#    'id': 'ep_97e361ad-12a9-4cb2-a4e9-fd4ad50a9ca2',
#    'AccountCondition_code': '05',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '51'},
#   {'InitialPaymentLevelDate': '03012012',
#    'id': 'ep_a65fc9db-ee1d-4dfc-8348-b1a648468244',
#    'AccountCondition_code': '05',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '40'},
#   {'InitialPaymentLevelDate': '07012017',
#    'id': 'ep_23256fd4-5a61-4921-8cc5-b601812847bb',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012012',
#    'id': 'ep_1e5b8723-2b57-4e0b-b1d8-4e9f3bb4f1b3',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '18'},
#   {'InitialPaymentLevelDate': '04012009',
#    'id': 'ep_88525fe9-f6f1-4fb9-bb53-f900f0f5302f',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012009',
#    'id': 'ep_d8760f7a-7d80-46d3-9c23-e6502583f694',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_4242611f-c729-4a47-9c7e-d473b31478d6',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '06012017',
#    'id': 'ep_7f579b2d-51da-48f2-be97-3f21c9d5e3d3',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '92',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '05012016',
#    'id': 'ep_2895f198-6478-4d3b-a812-e8015af620a2',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '6D',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '11012015',
#    'id': 'ep_682647c7-6853-4ee8-8277-fd6b90d6ba7c',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '89',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '10012015',
#    'id': 'ep_12995af0-a300-4907-8972-eef482466896',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '08012015',
#    'id': 'ep_2f743643-59d5-49e0-abc0-22d6f15ad27c',
#    'AccountCondition_code': 'A2',
# ...
#    'id': 'ep_edb57935-65ba-4a13-b1fa-2555b62cf506',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012010',
#    'id': 'ep_7fd5088c-ad18-4991-a99c-674d983a33e4',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '12012009',
#    'id': 'ep_48d76247-6b67-470f-a61f-841b66cdd949',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '12012009',
#    'id': 'ep_a8c99170-62e7-45a1-8ced-d6683d9fdcd3',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '06012009',
#    'id': 'ep_399f198c-4110-471b-b3cc-fd39e93af023',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '18'},
#   {'InitialPaymentLevelDate': '03012009',
#    'id': 'ep_6770f56f-5e83-4944-9801-77c922c8ff15',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '02012009',
#    'id': 'ep_9ab7ed76-a659-4200-a170-447d02b8e0a0',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '02012009',
#    'id': 'ep_459830ac-1952-4c0c-bfc2-f81de79a5f6e',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_db193c77-661b-4314-a8b7-6f7f31e75110',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_888403fe-8590-4995-9d21-4572db388e96',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_2b4b6634-9a7d-492c-893c-c11586ad9ca8',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_7be3fcec-b3dd-4fdf-a61c-66e35b262de7',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_020a9321-9157-4755-bccc-2066488d6c3e',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_d1986cc6-a650-4b99-ad51-f714974bb632',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_2ac64b86-5b8d-4e5e-ae8a-6d5d715a6f01',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_6fb1bd30-3a3a-4172-961d-4bac25f414cf',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_309c89d5-ae2b-4cf6-8733-7d1cf5c94a29',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_f1409315-7d65-4fd5-93a0-f12a30cb0d9f',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '07012017',
#    'id': 'ep_7bebf9c9-58a3-4ca7-ba3a-7e4ebe1a07a5',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '89',
#    'SpecialComment_code': '  '}],
#  'tradeline_amounts': [{'Value': '00000350',
#    'id': 'am_f7776d57-8aaf-4bd7-b4e8-bb8243d0b949',
#    'TradeLine_id': 'tl_a9928133-23dd-4d24-97bb-344683a6c870',
#    'Qualifier_code': 'L'},
#   {'Value': '00000056',
#    'id': 'am_619abac4-2e8d-4168-a6f7-ade0ed2e9279',
#    'TradeLine_id': 'tl_a9928133-23dd-4d24-97bb-344683a6c870',
#    'Qualifier_code': 'H'},
#   {'Value': '00011500',
#    'id': 'am_5e0ed715-217f-42b4-a56b-26a512102c49',
#    'TradeLine_id': 'tl_1d148def-1b24-47f2-9aaa-78d7adea391f',
#    'Qualifier_code': 'L'},
#   {'Value': '00011440',
#    'id': 'am_44c1eddc-c465-4530-8774-17e5ccf25d8d',
#    'TradeLine_id': 'tl_1d148def-1b24-47f2-9aaa-78d7adea391f',
#    'Qualifier_code': 'H'},
#   {'Value': '00012900',
#    'id': 'am_d4e81135-2fc5-4341-a835-d20eb18c78b1',
#    'TradeLine_id': 'tl_29e7dc38-0c64-45df-8d8e-5b5ff8b9c492',
#    'Qualifier_code': 'L'},
#   {'Value': '00008979',
#    'id': 'am_a1d69e07-ea8d-4a66-a490-dc4ab9126a61',
#    'TradeLine_id': 'tl_29e7dc38-0c64-45df-8d8e-5b5ff8b9c492',
#    'Qualifier_code': 'H'},
#   {'Value': 'UNKNOWN',
#    'id': 'am_f0d6228f-1c3b-4cea-b628-d32baeb40636',
#    'TradeLine_id': 'tl_43c9b5f2-ae33-4e33-bd06-8d9f778843f3',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_791bb5a4-36f5-4cf7-9c8e-e42b0b9ea18e',
#    'TradeLine_id': 'tl_43c9b5f2-ae33-4e33-bd06-8d9f778843f3',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_040c0052-2366-4691-95bc-98735f5beb50',
#    'TradeLine_id': 'tl_b5819f40-3f54-4e57-a3dd-238f9f19a422',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_6090dc92-9943-4251-96a0-44b8896c5b75',
#    'TradeLine_id': 'tl_b5819f40-3f54-4e57-a3dd-238f9f19a422',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_766be9e2-2ab8-405c-984b-a91fc1a2f65d',
#    'TradeLine_id': 'tl_3a095ad7-7d56-479d-959a-bc2af7933a27',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_ac6d51f1-94dc-431c-be28-095c10020802',
#    'TradeLine_id': 'tl_3a095ad7-7d56-479d-959a-bc2af7933a27',
#    'Qualifier_code': ' '},
#   {'Value': '00010000',
#    'id': 'am_e20519e8-8f56-4a04-92bd-8b5e22ee0b9f',
#    'TradeLine_id': 'tl_38513b97-e9b0-45eb-9901-89414d36765b',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_8a853201-132c-49dd-a418-d09bbed3fd95',
#    'TradeLine_id': 'tl_38513b97-e9b0-45eb-9901-89414d36765b',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_0738db0d-d357-46a6-aefd-b747c38acb77',
#    'TradeLine_id': 'tl_6e329b36-c9db-426e-bafa-3e21cf24dfbd',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_93292971-dbe4-4817-9c4c-7006c2ad2f9f',
#    'TradeLine_id': 'tl_6e329b36-c9db-426e-bafa-3e21cf24dfbd',
#    'Qualifier_code': ' '},
#   {'Value': '00040000',
#    'id': 'am_f5c1c2af-f366-4351-a64d-08c18cf1748a',
#    'TradeLine_id': 'tl_7bc0891d-38f7-41df-8fe8-c969c832032c',
#    'Qualifier_code': 'O'},
#   {'Value': None,
#    'id': 'am_5866a1ec-ea0d-4193-911c-4d4c13d562bb',
#    'TradeLine_id': 'tl_7bc0891d-38f7-41df-8fe8-c969c832032c',
#    'Qualifier_code': ' '},
#   {'Value': '00080000',
#    'id': 'am_c3df44b3-565f-4d58-b36c-1ac66bd9fd71',
#    'TradeLine_id': 'tl_04978fb6-5346-46f2-aef1-b130442a2ec7',
#    'Qualifier_code': 'L'},
#   {'Value': '00159087',
#    'id': 'am_1659b05b-47fe-4908-9a45-279e239230df',
#    'TradeLine_id': 'tl_04978fb6-5346-46f2-aef1-b130442a2ec7',
#    'Qualifier_code': 'H'},
#   {'Value': '00000223',
#    'id': 'am_9abfa2b5-b02e-45b0-93e5-eb9c3b37b42b',
#    'TradeLine_id': 'tl_0c85fa37-d7ca-4532-9d18-bdcbde662348',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_0009a4b9-bb83-47f0-8355-81867d8f5a66',
#    'TradeLine_id': 'tl_0c85fa37-d7ca-4532-9d18-bdcbde662348',
#    'Qualifier_code': ' '},
#   {'Value': '00150000',
#    'id': 'am_687d2452-01a1-4981-ac00-1135ed66499f',
#    'TradeLine_id': 'tl_261e6bbf-0892-4106-8a0d-21fd83c07d56',
#    'Qualifier_code': 'O'},
#   {'Value': None,
#    'id': 'am_5da49f64-afc2-4bc3-b5f7-8b90757b31f1',
#    'TradeLine_id': 'tl_261e6bbf-0892-4106-8a0d-21fd83c07d56',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_d6ce71d0-aa15-4fb8-8e85-d56e7d7322b4',
#    'TradeLine_id': 'tl_31020ed2-6e25-4dfc-8122-5ffce0f28a7a',
#    'Qualifier_code': 'L'},
#   {'Value': '00000082',
#    'id': 'am_0163b247-5a43-437c-b171-d0c5baea5bb3',
#    'TradeLine_id': 'tl_31020ed2-6e25-4dfc-8122-5ffce0f28a7a',
#    'Qualifier_code': 'H'},
#   {'Value': '00007000',
#    'id': 'am_faff8b5f-8ef3-4ac6-b042-3abd1caa2e15',
#    'TradeLine_id': 'tl_2b6d0da0-58e0-4015-96ba-700e5e9717d9',
#    'Qualifier_code': 'L'},
#   {'Value': '00007000',
#    'id': 'am_93b28ff5-cd27-4967-8404-a2b0ecc0fa22',
#    'TradeLine_id': 'tl_2b6d0da0-58e0-4015-96ba-700e5e9717d9',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_2020ac75-40fb-4d6c-89c7-367fd76463a1',
#    'TradeLine_id': 'tl_09682ab4-37d0-45f0-98e1-fc0eb0fd8405',
#    'Qualifier_code': 'L'},
#   {'Value': '00009434',
#    'id': 'am_15e9d035-d88e-45e1-b892-8a1b026d2723',
#    'TradeLine_id': 'tl_09682ab4-37d0-45f0-98e1-fc0eb0fd8405',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_466ec03c-6181-4c0b-80e2-fab928fcfb77',
#    'TradeLine_id': 'tl_80b02b4e-42b6-42dd-8721-44c74bd3a80b',
#    'Qualifier_code': 'L'},
#   {'Value': '00008982',
#    'id': 'am_1f015fcc-f5b2-48f5-b21c-62478dcad907',
#    'TradeLine_id': 'tl_80b02b4e-42b6-42dd-8721-44c74bd3a80b',
#    'Qualifier_code': 'H'},
#   {'Value': '00000700',
#    'id': 'am_8a5ee055-895f-4b5d-b5c6-340e6cded164',
#    'TradeLine_id': 'tl_4c924d30-d43a-453b-895f-c210a4a5a92f',
#    'Qualifier_code': 'L'},
#   {'Value': '00000283',
#    'id': 'am_3c68d057-e6f2-4b27-8682-592c470e8c1c',
#    'TradeLine_id': 'tl_4c924d30-d43a-453b-895f-c210a4a5a92f',
#    'Qualifier_code': 'H'},
#   {'Value': 'UNKNOWN',
#    'id': 'am_91884462-3c17-4a97-845a-ee86305b59d8',
#    'TradeLine_id': 'tl_098c2bd2-07a7-4215-9e43-ce5ca6b0b86a',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_70dfdbae-6c02-468d-85e8-ae77afd47a01',
#    'TradeLine_id': 'tl_098c2bd2-07a7-4215-9e43-ce5ca6b0b86a',
#    'Qualifier_code': ' '},
#   {'Value': '00004072',
#    'id': 'am_5634d3de-3018-4070-9e25-741695ba04f5',
#    'TradeLine_id': 'tl_8454ba09-b35b-4640-9a52-e2fdb98ca863',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_767c079e-43c4-43b5-881c-488fa8bd932e',
#    'TradeLine_id': 'tl_8454ba09-b35b-4640-9a52-e2fdb98ca863',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_a1a6ae62-adef-4527-b4ee-d87503cde218',
#    'TradeLine_id': 'tl_aba97316-b195-4206-abb3-d258d39c8956',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_c5d1d93c-d88e-4d71-8d0a-79663237983f',
#    'TradeLine_id': 'tl_aba97316-b195-4206-abb3-d258d39c8956',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_cd5e4175-9477-4a61-9f9b-914b487a8774',
#    'TradeLine_id': 'tl_b3807ac7-8337-498b-ada7-d62d908cf0b4',
#    'Qualifier_code': 'L'},
#   {'Value': '00003813',
#    'id': 'am_26b8b36c-6f42-4a7d-863b-6251fa4c0edf',
#    'TradeLine_id': 'tl_b3807ac7-8337-498b-ada7-d62d908cf0b4',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_c889a621-78df-4f38-ae66-ef9bd63179d0',
#    'TradeLine_id': 'tl_669270c3-f861-47e9-b904-c16489ed924f',
#    'Qualifier_code': 'L'},
#   {'Value': '00008679',
#    'id': 'am_6a522fee-a237-43a0-ac6d-f2055674da1f',
#    'TradeLine_id': 'tl_669270c3-f861-47e9-b904-c16489ed924f',
#    'Qualifier_code': 'H'},
#   {'Value': '00000500',
#    'id': 'am_8dd4ef4a-a97d-48e7-b5fa-874adc38d8bc',
#    'TradeLine_id': 'tl_aff966b5-85c1-46c9-9f26-0fd825571e08',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_209036ac-cf70-48c6-94db-1aa3e1723ef5',
#    'TradeLine_id': 'tl_aff966b5-85c1-46c9-9f26-0fd825571e08',
#    'Qualifier_code': ' '},
#   {'Value': '00012000',
#    'id': 'am_0a76bd95-c1f6-47db-95aa-4910aa9e74a2',
#    'TradeLine_id': 'tl_2e5976ae-ff59-41f8-bae1-fd8e7aa8e888',
#    'Qualifier_code': 'L'},
#   {'Value': '00010020',
#    'id': 'am_4a5a32ff-aa59-4b36-b7fd-0d03579922f8',
#    'TradeLine_id': 'tl_2e5976ae-ff59-41f8-bae1-fd8e7aa8e888',
#    'Qualifier_code': 'H'},
#   {'Value': '00005000',
#    'id': 'am_d34c7915-f7e0-4a2f-b4ec-d3939f38c2c3',
#    'TradeLine_id': 'tl_024cc26a-f451-4f0a-8784-e1c8c65ff3c7',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_eb146d30-240f-4585-9c59-a0bbe53b8059',
#    'TradeLine_id': 'tl_024cc26a-f451-4f0a-8784-e1c8c65ff3c7',
#    'Qualifier_code': ' '},
#   {'Value': '00006900',
#    'id': 'am_2aaf041c-62c8-4275-b499-67cbc7d1c255',
#    'TradeLine_id': 'tl_2f4f1b3b-4ecd-4877-9081-71ebda0382ed',
#    'Qualifier_code': 'L'},
#   {'Value': '00003032',
#    'id': 'am_b5bbb3f5-26a1-4b32-b8ba-3bffa4e5350d',
#    'TradeLine_id': 'tl_2f4f1b3b-4ecd-4877-9081-71ebda0382ed',
#    'Qualifier_code': 'H'},
#   {'Value': '00001000',
#    'id': 'am_b5ea9457-c1b7-4312-93d7-df1a2719356b',
#    'TradeLine_id': 'tl_5fdf7588-2282-471b-bf62-ddb10ac4af15',
#    'Qualifier_code': 'L'},
#   {'Value': '00000285',
#    'id': 'am_57c45b96-cebd-48cc-b181-6480e79a6deb',
#    'TradeLine_id': 'tl_5fdf7588-2282-471b-bf62-ddb10ac4af15',
#    'Qualifier_code': 'H'},
#   {'Value': '00001500',
#    'id': 'am_36f01dba-6e19-4959-8b25-2832cfe53dd5',
#    'TradeLine_id': 'tl_f51c158f-6dc7-4d76-8a0e-a958339828bf',
#    'Qualifier_code': 'L'},
#   {'Value': '00000546',
#    'id': 'am_b1dfc784-651e-44b5-9a8c-7d039579235a',
#    'TradeLine_id': 'tl_f51c158f-6dc7-4d76-8a0e-a958339828bf',
#    'Qualifier_code': 'H'},
#   {'Value': '00003600',
#    'id': 'am_b256bb74-951c-4cce-b430-7428cf9870f1',
#    'TradeLine_id': 'tl_9b9ace82-fc65-4dae-9dac-b99b327804c7',
#    'Qualifier_code': 'L'},
#   {'Value': '00001184',
#    'id': 'am_60c85692-819d-4be9-8eac-c51b839908b9',
#    'TradeLine_id': 'tl_9b9ace82-fc65-4dae-9dac-b99b327804c7',
#    'Qualifier_code': 'H'},
#   {'Value': '00000723',
#    'id': 'am_165a6cec-e91b-4121-bcc0-69e8c66e2d0a',
#    'TradeLine_id': 'tl_513fca15-e2c8-41ec-8b3a-1e1ebf29f189',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_eecc09b1-0978-4a87-a69b-d109f7863c87',
#    'TradeLine_id': 'tl_513fca15-e2c8-41ec-8b3a-1e1ebf29f189',
#    'Qualifier_code': ' '},
#   {'Value': '00019000',
#    'id': 'am_cffe11a1-d7a9-4e43-b861-09916fdcbc8c',
#    'TradeLine_id': 'tl_441f578f-67e1-4995-bf6b-1d81fb57a5cd',
#    'Qualifier_code': 'L'},
#   {'Value': '00010513',
#    'id': 'am_b8b8f6bc-f3c3-4216-bd33-613d3f4778ef',
#    'TradeLine_id': 'tl_441f578f-67e1-4995-bf6b-1d81fb57a5cd',
#    'Qualifier_code': 'H'},
#   {'Value': '00012200',
#    'id': 'am_f8521fdc-8e53-414e-8ad7-e33de26dfce1',
#    'TradeLine_id': 'tl_8f8e92a9-03fc-4396-809f-d960ae3ae302',
#    'Qualifier_code': 'L'},
#   {'Value': '00000629',
#    'id': 'am_74d5c6c4-d873-4c8c-809d-26e30ce67ff7',
#    'TradeLine_id': 'tl_8f8e92a9-03fc-4396-809f-d960ae3ae302',
#    'Qualifier_code': 'H'},
#   {'Value': '00001047',
#    'id': 'am_b9b5b40d-454a-4511-b69d-0308510b5015',
#    'TradeLine_id': 'tl_d4dba46f-78c6-447d-86d1-e25b6cec8d20',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_54a2d84d-bbd7-472d-a939-ba5fd2e42eb2',
#    'TradeLine_id': 'tl_d4dba46f-78c6-447d-86d1-e25b6cec8d20',
#    'Qualifier_code': ' '},
#   {'Value': '00007361',
#    'id': 'am_28ad1a61-cf4a-4f16-b7a5-bc7a68ae575a',
#    'TradeLine_id': 'tl_ed126d9c-3aef-4738-b9d3-41e82828b3de',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_d0a2533d-7671-45a0-a1af-4787ec731e7d',
#    'TradeLine_id': 'tl_ed126d9c-3aef-4738-b9d3-41e82828b3de',
#    'Qualifier_code': ' '},
#   {'Value': '00001500',
#    'id': 'am_6730535c-8a5e-4e58-8599-6fe4acd491eb',
#    'TradeLine_id': 'tl_75308afd-1e69-4ad0-ba54-b307cb32df0e',
#    'Qualifier_code': 'L'},
#   {'Value': '00000089',
#    'id': 'am_12fda0f4-87de-4583-81e6-187cdfcd5c8c',
#    'TradeLine_id': 'tl_75308afd-1e69-4ad0-ba54-b307cb32df0e',
#    'Qualifier_code': 'H'},
#   {'Value': '00150000',
#    'id': 'am_2d409f05-1b0d-4e4d-8dc9-330252f41165',
#    'TradeLine_id': 'tl_837f60d8-3608-44f3-b3d4-4e740b2fe937',
#    'Qualifier_code': 'L'},
#   {'Value': '00022118',
#    'id': 'am_49ce1d8e-7afe-4441-8c6d-a1d4048e7588',
#    'TradeLine_id': 'tl_837f60d8-3608-44f3-b3d4-4e740b2fe937',
#    'Qualifier_code': 'H'}]}

# %% [markdown]
# Parse XML data string and build XML_Detail table objects

# %%
RESULT_OBJ_DICT['addr_infos']
# Out:
# [{'FirstReportedDate': '10272003',
#   'LastUpdatedDate': '12202015',
#   'TimesReported': '00',
#   'LastReportingSubcode': '7370142',
#   'StreetPrefix': '7324',
#   'StreetName': '84TH STREET',
#   'StreetSuffix': 'CT SW',
#   'City': 'TACOMA',
#   'State': 'WA',
#   'Zip': '984986380',
#   'CensusGeoCode': None,
#   'id': 'ai_8a249318-d504-4814-b0d2-28e656b033e2',
#   'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#   'Origination_code': '2',
#   'DwellingType_code': 'S',
#   'HomeOwnership_code': ' '},
#  {'FirstReportedDate': '01012011',
#   'LastUpdatedDate': '01012011',
#   'TimesReported': '00',
#   'LastReportingSubcode': None,
#   'StreetPrefix': '3260 S',
#   'StreetName': 'TACOMA',
#   'StreetSuffix': 'WAY',
#   'City': 'TACOMA',
#   'State': 'WA',
#   'Zip': '984094725',
#   'CensusGeoCode': None,
#   'id': 'ai_180a3b79-fc80-4969-91ea-4568b16cd4b5',
#   'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#   'Origination_code': '1',
#   'DwellingType_code': 'S',
#   'HomeOwnership_code': ' '},
#  {'FirstReportedDate': '05282006',
#   'LastUpdatedDate': '11022010',
#   'TimesReported': '12',
#   'LastReportingSubcode': None,
#   'StreetPrefix': '3216 S',
#   'StreetName': 'TACOMA',
#   'StreetSuffix': 'WAY',
#   'City': 'TACOMA',
#   'State': 'WA',
#   'Zip': '984094725',
#   'CensusGeoCode': None,
#   'id': 'ai_794d9a61-3eae-405d-b469-1dc26e2a8954',
#   'CreditProfile_id': 'cp_83188663-1c2f-41ae-8fed-2e46b31ecaea',
#   'Origination_code': '1',
#   'DwellingType_code': 'S',
#   'HomeOwnership_code': ' '}]
