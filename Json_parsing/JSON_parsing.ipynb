# %%
import json
import pprint
import uuid
import xmltodict

RESULT_TABLE_NAMES = ['prequal_results', 'xml_details', 'products', 'credit_profiles', 'headers', 'risk_models', 'consumer_identities', 'addr_infos', 'employ_infos', 'trade_lines', 'inquiries']
with open("./data/prequalresult.json", 'r') as f:
    json_file = json.load(f)
json_file
# Out:
# [{'model': 'common.prequalresult',
#   'pk': 1,
#   'fields': {'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant'}}]

# %% [markdown]
# Building PrequalResult table objects

# %%
# initialize result object lists
RESULT_OBJ_DICT = dict((key, []) for key in RESULT_TABLE_NAMES)

prequal_results = json_file
for prequal_result in prequal_results:
    prequal_result.update(prequal_result.pop('fields'))
    xml_detail_id = "xd_{}".format(uuid.uuid4())
    prequal_result['xml_detail_id'] = xml_detail_id
    RESULT_OBJ_DICT['prequal_results'].append(prequal_result)
    
    # initializing XML_Detail object
    xml_dict = xmltodict.parse(result['xml_data'], dict_constructor=dict)['NetConnectResponse']
    xml_dict['id'] = xml_detail_id
    RESULT_OBJ_DICT['xml_details'].append(xml_dict)
    product_id = "pd_{}".format(uuid.uuid4())
    xml_dict['product_id'] = product_id
    
    # initializing Product object
    product_obj = xml_dict.pop('Products')
    product_obj['id'] = product_id
    RESULT_OBJ_DICT['products'].append(product_obj)
    credit_profile_id = "cp_{}".format(uuid.uuid4())
    product_obj['credit_profile_id'] = credit_profile_id
    
    # initializing CreditProfile object
    credit_profile_obj = product_obj.pop('CreditProfile')
    credit_profile_obj['id'] = credit_profile_id
    RESULT_OBJ_DICT['credit_profiles'].append(credit_profile_obj)
    
    
    ## handling RiskModels in CreditProfile
    for risk_model in credit_profile_obj.pop('RiskModel'):
        risk_model['id'] = "rm_{}".format(uuid.uuid4())
        risk_model['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['risk_models'].append(risk_model)
    
    # initializing Header object in CreditProfile
    header_id = "hd_{}".format(uuid.uuid4())
    credit_profile_obj['header_id'] = header_id
    header_obj = credit_profile_obj.pop('Header')
    header_obj['id'] = header_id
    RESULT_OBJ_DICT['headers'].append(header_obj)
    
    ## handling ConsumerIdentities in CreditProfile
    for consumer_identity in credit_profile_obj.pop('ConsumerIdentity'):
        consumer_identity['id'] = "ci_{}".format(uuid.uuid4())
        consumer_identity['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['consumer_identities'].append(consumer_identity)
    
    ## handling AddressInformations in CreditProfile
    for addr_info in credit_profile_obj.pop('AddressInformation'):
        addr_info['id'] = "ai_{}".format(uuid.uuid4())
        addr_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['addr_infos'].append(addr_info)
       
    ## handling EmploymentInformations in CreditProfile
    for employ_info in credit_profile_obj.pop('EmploymentInformation'):
        employ_info['id'] = "ei_{}".format(uuid.uuid4())
        employ_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['employ_infos'].append(employ_info)
        
    ## handling TradeLines in CreditProfile
    for trade_line in credit_profile_obj.pop('TradeLine'):
        trade_line['id'] = "tl_{}".format(uuid.uuid4())
        trade_line['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['trade_lines'].append(trade_line)
    
    # initializing Inquiry object in CreditProfile
    inquiry_id = "iq_{}".format(uuid.uuid4())
    credit_profile_obj['inquiry_id'] = inquiry_id
    inquiry_obj = credit_profile_obj.pop('Inquiry')
    inquiry_obj['id'] = inquiry_id
    RESULT_OBJ_DICT['inquiries'].append(header_obj)
    
    
RESULT_OBJ_DICT
# Out:
# {'prequal_results': [{'model': 'common.prequalresult',
#    'pk': 1,
#    'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant',
#    'xml_detail_id': 'xd_3491213f-331c-4c9c-8162-3cd2fe61c852'}],
#  'xml_details': [{'@xmlns': 'http://www.experian.com/NetConnectResponse',
#    'CompletionCode': '0000',
#    'ReferenceId': 'testing 123',
#    'TransactionId': '41588980',
#    'id': 'xd_3491213f-331c-4c9c-8162-3cd2fe61c852',
#    'product_id': 'pd_7f2b49ba-7c9d-4f89-99f0-c4f62fe1a400'}],
#  'products': [{'@xmlns': 'http://www.experian.com/ARFResponse',
#    'id': 'pd_7f2b49ba-7c9d-4f89-99f0-c4f62fe1a400',
#    'credit_profile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'}],
#  'credit_profiles': [{'Inquiry': {'Date': '08182016',
#     'Amount': 'UNKNOWN',
#     'Type': {'@code': '31'},
#     'Terms': {'@code': 'UNK'},
#     'Subcode': '1640007',
#     'KOB': {'@code': 'FF'},
#     'SubscriberDisplayName': 'SYNCB/BROOKS BROS'},
#    'InformationalMessage': [{'MessageNumber': '92',
#      'MessageText': '0092 REQUESTED PRODUCT OPTION NOT ALLOWED'},
#     {'MessageNumber': '84', 'MessageText': '0084 SSN MATCHES'}],
#    'id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9',
#    'header_id': 'hd_88309a1e-d23c-4ce8-a07b-0546369f0f5e'}],
#  'headers': [{'ReportDate': '10032017',
#    'ReportTime': '140607',
#    'Preamble': 'TWA1',
#    'ARFVersion': '07',
#    'id': 'hd_88309a1e-d23c-4ce8-a07b-0546369f0f5e'}],
#  'risk_models': [{'ModelIndicator': {'@code': 'F '},
#    'Score': '0808',
#    'ScoreFactorCodeOne': '10',
#    'ScoreFactorCodeTwo': '09',
#    'ScoreFactorCodeThree': '05',
#    'ScoreFactorCodeFour': None,
#    'Evaluation': {'@code': 'P'},
#    'id': 'rm_5d77ccbd-422b-4c3d-b16a-d82c4b22845e',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'ModelIndicator': {'@code': 'AA'},
#    'Score': '0807',
#    'ScoreFactorCodeOne': '30',
#    'ScoreFactorCodeTwo': '05',
#    'ScoreFactorCodeThree': '11',
#    'ScoreFactorCodeFour': None,
#    'Evaluation': {'@code': 'P'},
#    'id': 'rm_ff5c29a7-c6c5-496c-8c0c-9cda0ac8342a',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'}],
#  'consumer_identities': [{'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_4d116a27-68a5-493f-a341-17329493e340',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'Name': {'Type': {'@code': 'N'},
#     'Surname': 'SCALICI',
#     'First': 'AS',
#     'Middle': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_7b0a5db3-9d5d-468b-bcb6-01bd0770e909',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM', 'Gen': 'JR'},
#    'YOB': None,
#    'id': 'ci_304208b7-e54f-4204-acc5-6d9bd26ae1fb',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'Name': {'Type': {'@code': 'A'},
#     'Surname': 'ANTHONY',
#     'First': 'WILLIAM',
#     'Middle': 'R'},
#    'YOB': None,
#    'id': 'ci_c3b767b6-0e50-4436-81e7-f62ca02b8e50',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'}],
#  'addr_infos': [{'FirstReportedDate': '10272003',
#    'LastUpdatedDate': '12202015',
#    'Origination': {'@code': '2'},
#    'TimesReported': '00',
#    'LastReportingSubcode': '7370142',
#    'DwellingType': {'@code': 'S'},
#    'HomeOwnership': {'@code': ' '},
#    'StreetPrefix': '7324',
#    'StreetName': '84TH STREET',
#    'StreetSuffix': 'CT SW',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984986380',
#    'CensusGeoCode': None,
#    'id': 'ai_184daa65-7221-4b4e-8f42-518d06a712a3',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'FirstReportedDate': '01012011',
#    'LastUpdatedDate': '01012011',
#    'Origination': {'@code': '1'},
#    'TimesReported': '00',
#    'LastReportingSubcode': None,
#    'DwellingType': {'@code': 'S'},
#    'HomeOwnership': {'@code': ' '},
#    'StreetPrefix': '3260 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_7cdaf581-e9a8-4987-ad56-770fff084dcb',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'FirstReportedDate': '05282006',
#    'LastUpdatedDate': '11022010',
#    'Origination': {'@code': '1'},
#    'TimesReported': '12',
#    'LastReportingSubcode': None,
#    'DwellingType': {'@code': 'S'},
#    'HomeOwnership': {'@code': ' '},
#    'StreetPrefix': '3216 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_728f5fa3-d1b3-4bcc-bbf3-47a76f59248b',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'}],
#  'employ_infos': [{'FirstReportedDate': '04082011',
#    'LastUpdatedDate': '04082011',
#    'Origination': {'@code': '2'},
#    'Name': 'GM RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_c7b1d251-8e20-42a9-903e-af02afe9c039',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'FirstReportedDate': '12282009',
#    'LastUpdatedDate': '06112010',
#    'Origination': {'@code': '2'},
#    'Name': 'RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_99ec418a-2a34-4eb1-aa8b-63cd16a13fdc',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'}],
#  'trade_lines': [{'SpecialComment': {'@code': '28'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '06011981',
#    'StatusDate': '05012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00000350'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00000056'}],
#    'BalanceDate': '05192017',
#    'BalanceAmount': None,
#    'Status': {'@code': '05'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '15',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '01032016',
#    'Subcode': '1401790',
#    'KOB': {'@code': 'OC'},
#    'SubscriberDisplayName': 'CBNA',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '05012017',
#     'AccountCondition': {'@code': '05'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '51'}},
#    'id': 'tl_bf93ae58-b87a-46bf-b7ae-2ec5758f76b2',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '31'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00011500'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00011440'}],
#    'BalanceDate': '03182012',
#    'BalanceAmount': None,
#    'Status': {'@code': '05'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1213727',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BK OF AMER',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '03012012',
#     'AccountCondition': {'@code': '05'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '40'}},
#    'id': 'tl_a3e6453f-ebf8-468e-b0cd-2f389f344839',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '06102006',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00012900'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00008979'}],
#    'BalanceDate': '07232017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '96',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0---------CCC',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '07212015',
#    'Subcode': '1230206',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BK OF AMER',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '07012017',
#     'AccountCondition': {'@code': 'A3'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_82238101-0f10-4cb2-99cf-bc0899b59547',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '18'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': ' '}, 'Value': 'UNKNOWN'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '04282012',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '03',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '01122010',
#    'Subcode': '1216268',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '03012012',
#     'AccountCondition': {'@code': 'A3'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '18'}},
#    'id': 'tl_ed418291-ea01-4d33-b224-f88569801511',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '03012002',
#    'StatusDate': '04012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '0'},
#    'Amount': [{'Qualifier': {'@code': ' '}, 'Value': 'UNKNOWN'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '04012009',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '86',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00--------0-----------00',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '12102006',
#    'Subcode': '1439507',
#    'KOB': {'@code': 'NZ'},
#    'SubscriberDisplayName': 'CITI',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '04012009',
#     'AccountCondition': {'@code': 'A3'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_09ba0f10-3b32-4a54-9395-5a805d5a0215',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '03012007',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': ' '}, 'Value': 'UNKNOWN'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '03282009',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '26',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0----------0',
#    'Subcode': '1216268',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '03012009',
#     'AccountCondition': {'@code': 'A3'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_9987715a-1ea9-40e5-942d-b8572db470a9',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '04072017',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00010000'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '08032017',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '04',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00C',
#    'Subcode': '3278165',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_1ef68130-bc97-493d-85fd-6a21929c1e52',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09012016',
#    'StatusDate': '06012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '31'},
#    'TermsDuration': {'@code': '001'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': ' '}, 'Value': 'UNKNOWN'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '06282017',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'I'},
#    'ConsumerComment': None,
#    'AccountNumber': '6037453215420',
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '06262017',
#    'Subcode': '1945962',
#    'KOB': {'@code': 'UT'},
#    'SubscriberDisplayName': 'VERIZON NEW ENGLAND IN',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '06012017',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '92'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_e05ccade-ff6c-449f-b520-f73cd5c5261a',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '08122015',
#    'StatusDate': '05012016',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '31'},
#    'TermsDuration': {'@code': 'UNK'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'O'}, 'Value': '00040000'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '05282016',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'I'},
#    'ConsumerComment': None,
#    'AccountNumber': '15621485',
#    'MonthsHistory': '10',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCC',
#    'Subcode': '2165670',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '05012016',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '6D'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_b4df0fba-26ef-441e-96b7-5cd1c4e6164b',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '02182007',
#    'StatusDate': '11012015',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '47'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00080000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00159087'}],
#    'BalanceDate': '11282015',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000CCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '11012015',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '89'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_c5f59ad2-a562-4093-9fad-6f46adf40edc',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '05011984',
#    'StatusDate': '10012015',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': '001'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'H'}, 'Value': '00000223'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '10082015',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'Subcode': '1229200',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'AMEX',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '10012015',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_42b9ed9b-1073-4fe5-b6bf-acbafa33d977',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '12142012',
#    'StatusDate': '08012015',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '31'},
#    'TermsDuration': {'@code': '180'},
#    'ECOA': {'@code': '2'},
#    'Amount': [{'Qualifier': {'@code': 'O'}, 'Value': '00150000'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '08282015',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'I'},
#    'ConsumerComment': None,
#    'AccountNumber': '13750088',
#    'MonthsHistory': '33',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012015',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '6D'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_53a831ab-534b-422a-a007-8e8748cc8d15',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '18'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '10202007',
#    'StatusDate': '11012012',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00007000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00000082'}],
#    'BalanceDate': '11102012',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '68',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '3278165',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '11012012',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '18'}},
#    'id': 'tl_27926f68-9080-47cf-a340-89a47e384adb',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '10202007',
#    'StatusDate': '10012011',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00007000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00007000'}],
#    'BalanceDate': '10282011',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1220390',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '10012011',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_efee3ae4-64e5-439d-9458-cf4d64e2b8cf',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '01012007',
#    'StatusDate': '07012011',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00010000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00009434'}],
#    'BalanceDate': '07282011',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000CCCCCC',
#    'Subcode': '1290016',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '07012011',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_9a1a76d0-e8c0-4190-9c2d-618c40825092',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '01092008',
#    'StatusDate': '06012011',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '3'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00010000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00008982'}],
#    'BalanceDate': '06082011',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '32',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000CCCCCCCCCC',
#    'Subcode': '1290138',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '06012011',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_ea64f047-2fe5-4784-814d-15a457e8906f',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '18'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '01082006',
#    'StatusDate': '02012011',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00000700'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00000283'}],
#    'BalanceDate': '02282011',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '62',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B0000000000000000--------',
#    'Subcode': '6230125',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BAC/FLEET-BKCARD',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '02012011',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '18'}},
#    'id': 'tl_795544af-1e07-4d39-a809-4b5d34bbc12a',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09242005',
#    'StatusDate': '11012010',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '3'},
#    'Amount': [{'Qualifier': {'@code': ' '}, 'Value': 'UNKNOWN'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '11282010',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '60',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1260958',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '11012010',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_5c0b1a76-a5ea-44b5-8e34-1d8f7a097560',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09102007',
#    'StatusDate': '03012010',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'H'}, 'Value': '00004072'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '03072010',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '30',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000000CCCCCCC',
#    'Subcode': '3245600',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '03012010',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_9cf0f796-7026-42da-a0f6-b5899b461708',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00007000'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '12012009',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_204bc8e1-a5bc-4407-a8da-133ff2a0920e',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00007000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00003813'}],
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '12012009',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_2f9a1858-3066-4216-b8e5-454c7b915e93',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '18'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '04222005',
#    'StatusDate': '06012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00010000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00008679'}],
#    'BalanceDate': '06282009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '1201520',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '06012009',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '18'}},
#    'id': 'tl_3a8c1e34-a109-4f9e-bc61-78c3386efcd6',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '01072008',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00000500'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '03012009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '14',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCC',
#    'Subcode': '1202270',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'WF/WB',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '03012009',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_36bb36b7-41e6-4545-b9ae-a80239f12a1a',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '02282004',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00012000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00010020'}],
#    'BalanceDate': '02282009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '61',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC00000000CCCCC',
#    'Subcode': '1270583',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CHASE NA',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '02012009',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '19'}},
#    'id': 'tl_747d537f-c23c-4b2c-a834-181dcbccc257',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '02151994',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00005000'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '02222009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B---------------C--------',
#    'Subcode': '1270583',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CHASE NA',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '02012009',
#     'AccountCondition': {'@code': 'A2'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_5f76e393-fb14-41bd-b975-944b5504e824',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '09072013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00006900'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00003032'}],
#    'BalanceDate': '08232017',
#    'BalanceAmount': '00000025',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C0CCCCCCCCC000CCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000010',
#    'MonthlyPaymentType': {'@code': 'S'},
#    'LastPaymentDate': '06082017',
#    'Subcode': '3178962',
#    'KOB': {'@code': 'ZR'},
#    'SubscriberDisplayName': 'CBNA',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '07'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_13f6f94b-6515-48a4-ac47-c9b19cd41405',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '09011979',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00001000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00000285'}],
#    'BalanceDate': '08202017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '75',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000CCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '05092017',
#    'Subcode': '1335510',
#    'KOB': {'@code': 'OC'},
#    'SubscriberDisplayName': 'SYNCB/EXXON MOBIL',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '07'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_d68f8969-cdd7-47d7-868a-79ac8a8257c9',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '06182013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00001500'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00000546'}],
#    'BalanceDate': '08162017',
#    'BalanceAmount': '00000160',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '51',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0C',
#    'MonthlyPaymentAmount': '00000015',
#    'MonthlyPaymentType': {'@code': 'S'},
#    'LastPaymentDate': '07272017',
#    'Subcode': '3308810',
#    'KOB': {'@code': 'DV'},
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '07'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_4c3d7694-2c99-4bdd-a615-958b43faa118',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '04272007',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '3'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00003600'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00001184'}],
#    'BalanceDate': '08152017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000000000CCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '12282015',
#    'Subcode': '3308810',
#    'KOB': {'@code': 'DV'},
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '07'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_339a8282-beb7-45d0-8d5b-fb8b846dd009',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '09012010',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'H'}, 'Value': '00000723'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '08142017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '84',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000C000000000000',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '08282016',
#    'Subcode': '1349040',
#    'KOB': {'@code': 'ZR'},
#    'SubscriberDisplayName': 'FILENES',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '07'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_7d42cf74-3ab1-479f-b81a-a77d00113f5f',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '04011998',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00019000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00010513'}],
#    'BalanceDate': '08092017',
#    'BalanceAmount': '00001354',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '97',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000015',
#    'MonthlyPaymentType': {'@code': 'S'},
#    'LastPaymentDate': '07242017',
#    'Subcode': '1230206',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BK OF AMER',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_8b38a1c4-456b-466b-a111-408428706066',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '06011983',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00012200'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00000629'}],
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000052',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'AMEX',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_89d8c001-5576-46fc-bc11-a65cc9665a4f',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': '001'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'H'}, 'Value': '00001047'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000599',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'AMEX',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_b97a2a5a-3d2c-47fe-8bb9-fcda3f690189',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'H'}, 'Value': '00007361'},
#     {'Qualifier': {'@code': ' '}, 'Value': None}],
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00001960',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'AMEX',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '18'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_e88265f1-f97b-4bc8-936d-e5c34ae7525e',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '08182016',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00001500'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00000089'}],
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '0000000000CC',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '09192016',
#    'Subcode': '2613430',
#    'KOB': {'@code': 'CG'},
#    'SubscriberDisplayName': 'SYNCB/BROOK BROS',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '08012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '07'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_30e153db-4087-4899-8333-24c04b8a43b3',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '08122015',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '47'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'Amount': [{'Qualifier': {'@code': 'L'}, 'Value': '00150000'},
#     {'Qualifier': {'@code': 'H'}, 'Value': '00022118'}],
#    'BalanceDate': '07282017',
#    'BalanceAmount': '00004607',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '24',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0',
#    'MonthlyPaymentAmount': 'UNKNOWN',
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '07102017',
#    'Subcode': '2165670',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'EnhancedPaymentData': {'InitialPaymentLevelDate': '07012017',
#     'AccountCondition': {'@code': 'A1'},
#     'PaymentStatus': {'@code': '11'},
#     'AccountType': {'@code': '89'},
#     'SpecialComment': {'@code': '  '}},
#    'id': 'tl_15369d7c-0b15-452b-bebc-da8eba4083e7',
#    'CreditProfile_id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9'}]}

# %% [markdown]
# Parse XML data string and build XML_Detail table objects

# %%
RESULT_OBJ_DICT['credit_profiles']
# Out:
# [{'Inquiry': {'Date': '08182016',
#    'Amount': 'UNKNOWN',
#    'Type': {'@code': '31'},
#    'Terms': {'@code': 'UNK'},
#    'Subcode': '1640007',
#    'KOB': {'@code': 'FF'},
#    'SubscriberDisplayName': 'SYNCB/BROOKS BROS'},
#   'InformationalMessage': [{'MessageNumber': '92',
#     'MessageText': '0092 REQUESTED PRODUCT OPTION NOT ALLOWED'},
#    {'MessageNumber': '84', 'MessageText': '0084 SSN MATCHES'}],
#   'id': 'cp_e6fe92ff-ab6f-4264-878d-4c33800e09b9',
#   'header_id': 'hd_88309a1e-d23c-4ce8-a07b-0546369f0f5e'}]
