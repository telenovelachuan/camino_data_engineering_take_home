# %%
import json
import pprint
import uuid
import xmltodict

RESULT_TABLE_NAMES = ['prequal_results', 'xml_details', 'products', 'credit_profiles', 'headers', 'risk_models', 'consumer_identities', 'addr_infos', 'employ_infos', 'trade_lines', 'inquiries', 'info_msgs', 'enhanced_pm_data', 'tradeline_amounts']
with open("./data/prequalresult.json", 'r') as f:
    json_file = json.load(f)
json_file
# Out:
# [{'model': 'common.prequalresult',
#   'pk': 1,
#   'fields': {'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant'}}]

# %% [markdown]
# Building PrequalResult table objects

# %%
# initialize result object lists
RESULT_OBJ_DICT = dict((key, []) for key in RESULT_TABLE_NAMES)

prequal_results = json_file
for prequal_result in prequal_results:
    prequal_result.update(prequal_result.pop('fields'))
    xml_detail_id = "xd_{}".format(uuid.uuid4())
    prequal_result['xml_detail_id'] = xml_detail_id
    RESULT_OBJ_DICT['prequal_results'].append(prequal_result)
    
    # initializing XML_Detail object
    xml_dict = xmltodict.parse(result['xml_data'], dict_constructor=dict)['NetConnectResponse']
    xml_dict['id'] = xml_detail_id
    RESULT_OBJ_DICT['xml_details'].append(xml_dict)
    product_id = "pd_{}".format(uuid.uuid4())
    xml_dict['product_id'] = product_id
    
    # initializing Product object
    product_obj = xml_dict.pop('Products')
    product_obj['id'] = product_id
    RESULT_OBJ_DICT['products'].append(product_obj)
    credit_profile_id = "cp_{}".format(uuid.uuid4())
    product_obj['credit_profile_id'] = credit_profile_id
    
    # initializing CreditProfile object
    credit_profile_obj = product_obj.pop('CreditProfile')
    credit_profile_obj['id'] = credit_profile_id
    RESULT_OBJ_DICT['credit_profiles'].append(credit_profile_obj)
    
    
    ## handling RiskModels in CreditProfile
    for risk_model in credit_profile_obj.pop('RiskModel'):
        risk_model['id'] = "rm_{}".format(uuid.uuid4())
        risk_model['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['risk_models'].append(risk_model)
    
    # initializing Header object in CreditProfile
    header_id = "hd_{}".format(uuid.uuid4())
    credit_profile_obj['header_id'] = header_id
    header_obj = credit_profile_obj.pop('Header')
    header_obj['id'] = header_id
    RESULT_OBJ_DICT['headers'].append(header_obj)
    
    ## handling ConsumerIdentities in CreditProfile
    for consumer_identity in credit_profile_obj.pop('ConsumerIdentity'):
        consumer_identity['id'] = "ci_{}".format(uuid.uuid4())
        consumer_identity['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['consumer_identities'].append(consumer_identity)
    
    ## handling AddressInformations in CreditProfile
    for addr_info in credit_profile_obj.pop('AddressInformation'):
        addr_info['id'] = "ai_{}".format(uuid.uuid4())
        addr_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['addr_infos'].append(addr_info)
       
    ## handling EmploymentInformations in CreditProfile
    for employ_info in credit_profile_obj.pop('EmploymentInformation'):
        employ_info['id'] = "ei_{}".format(uuid.uuid4())
        employ_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['employ_infos'].append(employ_info)
        
    ## handling TradeLines in CreditProfile
    for trade_line in credit_profile_obj.pop('TradeLine'):
        trade_line['id'] = "tl_{}".format(uuid.uuid4())
        trade_line['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['trade_lines'].append(trade_line)
        
        # initializing EnhancedPaymentData object in TradeLine
        enhanced_pm_data_id = "ep_{}".format(uuid.uuid4())
        trade_line['enhanced_pm_data_id'] = enhanced_pm_data_id
        enhanced_pm_data_obj = trade_line.pop('EnhancedPaymentData')
        enhanced_pm_data_obj['id'] = enhanced_pm_data_id
        RESULT_OBJ_DICT['enhanced_pm_data'].append(enhanced_pm_data_obj)
        
        ## handling Amount object in TradeLine
        for amt_obj in trade_line.pop('Amount'):
            amt_obj['id'] = "am_{}".format(uuid.uuid4())
            amt_obj['TradeLine_id'] = trade_line['id']
            RESULT_OBJ_DICT['tradeline_amounts'].append(amt_obj)
    
    # initializing Inquiry object in CreditProfile
    inquiry_id = "iq_{}".format(uuid.uuid4())
    credit_profile_obj['inquiry_id'] = inquiry_id
    inquiry_obj = credit_profile_obj.pop('Inquiry')
    inquiry_obj['id'] = inquiry_id
    RESULT_OBJ_DICT['inquiries'].append(inquiry_obj)
    
    ## handling InformationalMessages in CreditProfile
    for info_msg in credit_profile_obj.pop('InformationalMessage'):
        info_msg['id'] = "im_{}".format(uuid.uuid4())
        info_msg['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['info_msgs'].append(info_msg)
    
    
RESULT_OBJ_DICT
# Out:
# {'prequal_results': [{'model': 'common.prequalresult',
#    'pk': 1,
#    'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant',
#    'xml_detail_id': 'xd_6130672d-85a2-4b9e-81f6-6d1d5bc4d773'}],
#  'xml_details': [{'@xmlns': 'http://www.experian.com/NetConnectResponse',
#    'CompletionCode': '0000',
#    'ReferenceId': 'testing 123',
#    'TransactionId': '41588980',
#    'id': 'xd_6130672d-85a2-4b9e-81f6-6d1d5bc4d773',
#    'product_id': 'pd_6cbc7469-c344-4ee8-864c-a8476908ce8b'}],
#  'products': [{'@xmlns': 'http://www.experian.com/ARFResponse',
#    'id': 'pd_6cbc7469-c344-4ee8-864c-a8476908ce8b',
#    'credit_profile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'}],
#  'credit_profiles': [{'id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'header_id': 'hd_f1f617d0-caf8-4e68-956f-c21ff05f1659',
#    'inquiry_id': 'iq_b01f1728-59f9-4aee-ae6b-b43609cd3607'}],
#  'headers': [{'ReportDate': '10032017',
#    'ReportTime': '140607',
#    'Preamble': 'TWA1',
#    'ARFVersion': '07',
#    'id': 'hd_f1f617d0-caf8-4e68-956f-c21ff05f1659'}],
#  'risk_models': [{'ModelIndicator': {'@code': 'F '},
#    'Score': '0808',
#    'ScoreFactorCodeOne': '10',
#    'ScoreFactorCodeTwo': '09',
#    'ScoreFactorCodeThree': '05',
#    'ScoreFactorCodeFour': None,
#    'Evaluation': {'@code': 'P'},
#    'id': 'rm_70a86183-b2f6-47b3-b020-c0d11a14bf40',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'},
#   {'ModelIndicator': {'@code': 'AA'},
#    'Score': '0807',
#    'ScoreFactorCodeOne': '30',
#    'ScoreFactorCodeTwo': '05',
#    'ScoreFactorCodeThree': '11',
#    'ScoreFactorCodeFour': None,
#    'Evaluation': {'@code': 'P'},
#    'id': 'rm_19f05b0e-ff4b-40f8-abae-824aee160dab',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'}],
#  'consumer_identities': [{'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_b7984b62-c5dd-4878-bb43-b5e46b7e500c',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'},
#   {'Name': {'Type': {'@code': 'N'},
#     'Surname': 'SCALICI',
#     'First': 'AS',
#     'Middle': 'WILLIAM'},
#    'YOB': None,
#    'id': 'ci_322a269a-e60c-4202-a525-1f6e785304b0',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'},
#   {'Name': {'Surname': 'SCALICI', 'First': 'WILLIAM', 'Gen': 'JR'},
#    'YOB': None,
#    'id': 'ci_b0c0d95b-439d-4813-a888-6f89d43c65de',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'},
#   {'Name': {'Type': {'@code': 'A'},
#     'Surname': 'ANTHONY',
#     'First': 'WILLIAM',
#     'Middle': 'R'},
#    'YOB': None,
#    'id': 'ci_512b119c-a1a8-416d-8ee0-5462f0a4f657',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'}],
#  'addr_infos': [{'FirstReportedDate': '10272003',
#    'LastUpdatedDate': '12202015',
#    'Origination': {'@code': '2'},
#    'TimesReported': '00',
#    'LastReportingSubcode': '7370142',
#    'DwellingType': {'@code': 'S'},
#    'HomeOwnership': {'@code': ' '},
#    'StreetPrefix': '7324',
#    'StreetName': '84TH STREET',
#    'StreetSuffix': 'CT SW',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984986380',
#    'CensusGeoCode': None,
#    'id': 'ai_f67fd5d8-1e62-48d8-80c6-ab0d769c1612',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'},
#   {'FirstReportedDate': '01012011',
#    'LastUpdatedDate': '01012011',
#    'Origination': {'@code': '1'},
#    'TimesReported': '00',
#    'LastReportingSubcode': None,
#    'DwellingType': {'@code': 'S'},
#    'HomeOwnership': {'@code': ' '},
#    'StreetPrefix': '3260 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_d0ff3812-6c7b-4197-b304-72fba38d8000',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'},
#   {'FirstReportedDate': '05282006',
#    'LastUpdatedDate': '11022010',
#    'Origination': {'@code': '1'},
#    'TimesReported': '12',
#    'LastReportingSubcode': None,
#    'DwellingType': {'@code': 'S'},
#    'HomeOwnership': {'@code': ' '},
#    'StreetPrefix': '3216 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_2bb33068-273f-41ec-bbed-3700562f36db',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'}],
#  'employ_infos': [{'FirstReportedDate': '04082011',
#    'LastUpdatedDate': '04082011',
#    'Origination': {'@code': '2'},
#    'Name': 'GM RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_5e105cae-7ec8-4510-8124-b51830444ff6',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'},
#   {'FirstReportedDate': '12282009',
#    'LastUpdatedDate': '06112010',
#    'Origination': {'@code': '2'},
#    'Name': 'RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_54fc9950-efad-4109-a717-a076a83f8a61',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'}],
#  'trade_lines': [{'SpecialComment': {'@code': '28'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '06011981',
#    'StatusDate': '05012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '05192017',
#    'BalanceAmount': None,
#    'Status': {'@code': '05'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '15',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '01032016',
#    'Subcode': '1401790',
#    'KOB': {'@code': 'OC'},
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_04682736-ca7d-49b6-9199-0d4ac3f03b2d',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_d93af22b-6e3d-4f0d-89e1-95f3a55b5cd5'},
#   {'SpecialComment': {'@code': '31'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03182012',
#    'BalanceAmount': None,
#    'Status': {'@code': '05'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1213727',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_fbddedcd-55fc-44ad-b55e-a2605f221311',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_08391d18-1334-40ec-8a26-0f73fe61f18d'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '06102006',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '07232017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '96',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0---------CCC',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '07212015',
#    'Subcode': '1230206',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_bed432f2-c6ca-4dc7-98ef-5e9fbb2be900',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_e6e43118-0381-4af8-9425-f101e6a2859f'},
#   {'SpecialComment': {'@code': '18'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '04282012',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '03',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '01122010',
#    'Subcode': '1216268',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_3f69634f-61c3-4ec2-b6c4-7a588678f301',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_cbbd066d-bd9e-49c1-926f-342e1703ec82'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '03012002',
#    'StatusDate': '04012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '0'},
#    'BalanceDate': '04012009',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '86',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00--------0-----------00',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '12102006',
#    'Subcode': '1439507',
#    'KOB': {'@code': 'NZ'},
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_82fc9ebb-39a9-4a03-a93b-cac906c27815',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_82c46013-ba8b-4873-9405-8d119b763388'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '03012007',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03282009',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '26',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0----------0',
#    'Subcode': '1216268',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_a428a41a-2361-4515-965c-a8e84e3de446',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_9497b529-8185-4f94-8058-cdea2b6ebb24'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '04072017',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08032017',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '04',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00C',
#    'Subcode': '3278165',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_2788da89-a621-4d0a-9ffc-c81b4ec0c2df',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_e5f5e04b-11e5-4203-a2dc-32fdf6f622ec'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09012016',
#    'StatusDate': '06012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '31'},
#    'TermsDuration': {'@code': '001'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '06282017',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'I'},
#    'ConsumerComment': None,
#    'AccountNumber': '6037453215420',
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '06262017',
#    'Subcode': '1945962',
#    'KOB': {'@code': 'UT'},
#    'SubscriberDisplayName': 'VERIZON NEW ENGLAND IN',
#    'id': 'tl_4e7976e7-1b3e-4583-8dc1-e0901a43f6fa',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_06d5d10c-7c89-4ad3-b6cf-d4b017f55fcf'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '08122015',
#    'StatusDate': '05012016',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '31'},
#    'TermsDuration': {'@code': 'UNK'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '05282016',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'I'},
#    'ConsumerComment': None,
#    'AccountNumber': '15621485',
#    'MonthsHistory': '10',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCC',
#    'Subcode': '2165670',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_8a39cae2-39be-4692-a63e-56fd0d415ce9',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_48dc1832-830a-4e2d-a654-c8cdba6f1f6c'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '02182007',
#    'StatusDate': '11012015',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '47'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '11282015',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000CCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_248dbbae-0f9a-4138-93e2-a77973b41264',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_d13d3a67-69c5-417f-a1d2-4f592bed7ff9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '05011984',
#    'StatusDate': '10012015',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': '001'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '10082015',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'Subcode': '1229200',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_f98b68cf-29a5-4361-af70-c7623c37c654',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_c320b2bf-b359-4854-9ecb-2642738f122d'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '12142012',
#    'StatusDate': '08012015',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '31'},
#    'TermsDuration': {'@code': '180'},
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '08282015',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'I'},
#    'ConsumerComment': None,
#    'AccountNumber': '13750088',
#    'MonthsHistory': '33',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_7e7921ce-479f-4056-8786-4e2bf9d20a89',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_f381d34a-3751-4970-8f7e-7d8c186bd15c'},
#   {'SpecialComment': {'@code': '18'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '10202007',
#    'StatusDate': '11012012',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '11102012',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '68',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '3278165',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_5d750318-2471-4423-b0d9-d255d36ee9c2',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_84ee48ff-f954-4509-97d8-623c7b2a4004'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '10202007',
#    'StatusDate': '10012011',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '10282011',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1220390',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_c012648a-5add-4e65-bf8e-4e2062261b99',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_f0940e40-081c-40dd-9aca-f69a8969da9b'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '01012007',
#    'StatusDate': '07012011',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '07282011',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000CCCCCC',
#    'Subcode': '1290016',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_dc54844a-6174-4936-928f-70c1ac877fcf',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_08f886f1-ced3-4068-9e7f-9859a27bcb75'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '01092008',
#    'StatusDate': '06012011',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '3'},
#    'BalanceDate': '06082011',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '32',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000CCCCCCCCCC',
#    'Subcode': '1290138',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_82aca976-0820-4081-94ec-683ba5e3ef49',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_2026993e-ff9a-4986-ae86-bcb0803dfecf'},
#   {'SpecialComment': {'@code': '18'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '01082006',
#    'StatusDate': '02012011',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '02282011',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '62',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B0000000000000000--------',
#    'Subcode': '6230125',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BAC/FLEET-BKCARD',
#    'id': 'tl_89e5a29c-ac9e-4ee2-b929-fda32fe1a150',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_fe5fc6a2-08d1-4172-8f8f-e8710697637d'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09242005',
#    'StatusDate': '11012010',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '3'},
#    'BalanceDate': '11282010',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '60',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1260958',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_7165d65a-f513-43d6-b535-404aa30eb61b',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_276b968d-0c1f-482e-80ca-c15cf8eb9a93'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09102007',
#    'StatusDate': '03012010',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03072010',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '30',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000000CCCCCCC',
#    'Subcode': '3245600',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_2a249894-1ec2-4f66-80e0-8b502a090b35',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_399c0abb-7882-44f3-8219-7b9fc37d3978'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_bfe01a0c-cabf-40af-8010-8d9d933410ba',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_69fe09fc-23ce-4e86-8001-d69c55ff159a'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_3c0675fe-681e-428f-9a0f-6aa27a7e5513',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_aee27e13-d8c2-420f-9e74-aa46fdbf75f0'},
#   {'SpecialComment': {'@code': '18'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '04222005',
#    'StatusDate': '06012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '06282009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '1201520',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_5034ee64-8458-4905-bc36-4967bd424dbf',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_4fb37296-2f66-4f26-b76d-0cfa573208a9'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '01072008',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '03012009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '14',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCC',
#    'Subcode': '1202270',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'WF/WB',
#    'id': 'tl_17af31cf-1e22-4023-a976-7b07e3d9e7ca',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_882fefd3-aafb-4493-8b17-cea00f58700c'},
#   {'SpecialComment': {'@code': '19'},
#    'Evaluation': {'@code': 'N'},
#    'OpenDate': '02282004',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '02282009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '61',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC00000000CCCCC',
#    'Subcode': '1270583',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_b3a9b87b-347c-4af3-a20c-80105b545a3c',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_6d15250f-698b-4a08-aec2-aa802e29c33e'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '02151994',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '02222009',
#    'BalanceAmount': None,
#    'Status': {'@code': '12'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'C'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B---------------C--------',
#    'Subcode': '1270583',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_05c9c45f-095f-4f7d-8925-2c8e9000cf0a',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_054fe3dc-2bf0-4622-87ce-b0e874fa01e5'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '09072013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '2'},
#    'BalanceDate': '08232017',
#    'BalanceAmount': '00000025',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C0CCCCCCCCC000CCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000010',
#    'MonthlyPaymentType': {'@code': 'S'},
#    'LastPaymentDate': '06082017',
#    'Subcode': '3178962',
#    'KOB': {'@code': 'ZR'},
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_94953b3e-e2ed-4e4e-9699-7f53cebae65f',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_8cbe563a-c396-4c1f-a7eb-e5969b5496a0'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '09011979',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08202017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '75',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000CCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '05092017',
#    'Subcode': '1335510',
#    'KOB': {'@code': 'OC'},
#    'SubscriberDisplayName': 'SYNCB/EXXON MOBIL',
#    'id': 'tl_9ffe784f-0f78-4a0b-9745-48de17a311a0',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_7bf2ee5b-dd10-4ec2-8c83-925523398c89'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '06182013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08162017',
#    'BalanceAmount': '00000160',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '51',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0C',
#    'MonthlyPaymentAmount': '00000015',
#    'MonthlyPaymentType': {'@code': 'S'},
#    'LastPaymentDate': '07272017',
#    'Subcode': '3308810',
#    'KOB': {'@code': 'DV'},
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_989cb800-44ba-4501-9bdd-94633989aa0f',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_55535e7c-fc26-4022-ba6e-99612132c750'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '04272007',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '3'},
#    'BalanceDate': '08152017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000000000CCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '12282015',
#    'Subcode': '3308810',
#    'KOB': {'@code': 'DV'},
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_4de1cc4d-0e50-497d-84b3-d3c2974a2cb5',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_c58f7a70-15b8-4c08-9527-89d1a35ad905'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '09012010',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08142017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '84',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000C000000000000',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '08282016',
#    'Subcode': '1349040',
#    'KOB': {'@code': 'ZR'},
#    'SubscriberDisplayName': 'FILENES',
#    'id': 'tl_8617b55b-066c-4cd5-9e4f-bf08f198053a',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_b690f73b-9eb3-49ff-9f6e-be114a779ed8'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '04011998',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08092017',
#    'BalanceAmount': '00001354',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '97',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000015',
#    'MonthlyPaymentType': {'@code': 'S'},
#    'LastPaymentDate': '07242017',
#    'Subcode': '1230206',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_fa9fb661-67a7-4813-9947-232ca900a7db',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_72d65da8-deed-463d-b4f9-bb70db6c5732'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '06011983',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000052',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_2b27898e-7585-438c-8b66-496b8afe4326',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_a2ba97d2-218c-4984-999e-c5ea44360ecf'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': '001'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000599',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_f40b425d-98fe-4904-aa57-025943671ab7',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_e44749f1-f205-48f1-84da-25627a60056c'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '18'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00001960',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'KOB': {'@code': 'BC'},
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_6c01c68c-a1d3-464f-8427-ba4018164846',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_d2b0449a-89be-4295-a7c1-1f8164adfbc8'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '08182016',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '07'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000000',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '0000000000CC',
#    'MonthlyPaymentAmount': None,
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '09192016',
#    'Subcode': '2613430',
#    'KOB': {'@code': 'CG'},
#    'SubscriberDisplayName': 'SYNCB/BROOK BROS',
#    'id': 'tl_cf1788c3-3ca5-4e57-8c87-f98378919358',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_82c0e44a-8508-47e8-8016-26ba8492f8b8'},
#   {'SpecialComment': {'@code': '  '},
#    'Evaluation': {'@code': 'P'},
#    'OpenDate': '08122015',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'AccountType': {'@code': '47'},
#    'TermsDuration': {'@code': 'REV'},
#    'ECOA': {'@code': '1'},
#    'BalanceDate': '07282017',
#    'BalanceAmount': '00004607',
#    'Status': {'@code': '11'},
#    'AmountPastDue': None,
#    'OpenOrClosed': {'@code': 'O'},
#    'RevolvingOrInstallment': {'@code': 'R'},
#    'ConsumerComment': None,
#    'MonthsHistory': '24',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0',
#    'MonthlyPaymentAmount': 'UNKNOWN',
#    'MonthlyPaymentType': {'@code': ' '},
#    'LastPaymentDate': '07102017',
#    'Subcode': '2165670',
#    'KOB': {'@code': 'BB'},
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_46f334d7-1396-4d5f-89be-de0592c82428',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133',
#    'enhanced_pm_data_id': 'ep_842917e7-a8b7-41b3-a191-4bf5eaaf4e45'}],
#  'inquiries': [{'Date': '08182016',
#    'Amount': 'UNKNOWN',
#    'Type': {'@code': '31'},
#    'Terms': {'@code': 'UNK'},
#    'Subcode': '1640007',
#    'KOB': {'@code': 'FF'},
#    'SubscriberDisplayName': 'SYNCB/BROOKS BROS',
#    'id': 'iq_b01f1728-59f9-4aee-ae6b-b43609cd3607'}],
#  'info_msgs': [{'MessageNumber': '92',
#    'MessageText': '0092 REQUESTED PRODUCT OPTION NOT ALLOWED',
#    'id': 'im_3b3ea1d7-90f1-4ea6-afa7-661c4ec598c3',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'},
#   {'MessageNumber': '84',
#    'MessageText': '0084 SSN MATCHES',
#    'id': 'im_1f2e5989-59e3-4225-a4a7-1db0e8a55451',
#    'CreditProfile_id': 'cp_0603588d-ea95-4ca0-b9e4-9cd7dd16a133'}],
#  'enhanced_pm_data': [{'InitialPaymentLevelDate': '05012017',
#    'AccountCondition': {'@code': '05'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '51'},
#    'id': 'ep_d93af22b-6e3d-4f0d-89e1-95f3a55b5cd5'},
#   {'InitialPaymentLevelDate': '03012012',
#    'AccountCondition': {'@code': '05'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '40'},
#    'id': 'ep_08391d18-1334-40ec-8a26-0f73fe61f18d'},
#   {'InitialPaymentLevelDate': '07012017',
#    'AccountCondition': {'@code': 'A3'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_e6e43118-0381-4af8-9425-f101e6a2859f'},
#   {'InitialPaymentLevelDate': '03012012',
#    'AccountCondition': {'@code': 'A3'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '18'},
#    'id': 'ep_cbbd066d-bd9e-49c1-926f-342e1703ec82'},
#   {'InitialPaymentLevelDate': '04012009',
#    'AccountCondition': {'@code': 'A3'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_82c46013-ba8b-4873-9405-8d119b763388'},
#   {'InitialPaymentLevelDate': '03012009',
#    'AccountCondition': {'@code': 'A3'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
# ...
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_aee27e13-d8c2-420f-9e74-aa46fdbf75f0'},
#   {'InitialPaymentLevelDate': '06012009',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '18'},
#    'id': 'ep_4fb37296-2f66-4f26-b76d-0cfa573208a9'},
#   {'InitialPaymentLevelDate': '03012009',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_882fefd3-aafb-4493-8b17-cea00f58700c'},
#   {'InitialPaymentLevelDate': '02012009',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '19'},
#    'id': 'ep_6d15250f-698b-4a08-aec2-aa802e29c33e'},
#   {'InitialPaymentLevelDate': '02012009',
#    'AccountCondition': {'@code': 'A2'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_054fe3dc-2bf0-4622-87ce-b0e874fa01e5'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_8cbe563a-c396-4c1f-a7eb-e5969b5496a0'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_7bf2ee5b-dd10-4ec2-8c83-925523398c89'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_55535e7c-fc26-4022-ba6e-99612132c750'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_c58f7a70-15b8-4c08-9527-89d1a35ad905'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_b690f73b-9eb3-49ff-9f6e-be114a779ed8'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_72d65da8-deed-463d-b4f9-bb70db6c5732'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_a2ba97d2-218c-4984-999e-c5ea44360ecf'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_e44749f1-f205-48f1-84da-25627a60056c'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '18'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_d2b0449a-89be-4295-a7c1-1f8164adfbc8'},
#   {'InitialPaymentLevelDate': '08012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '07'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_82c0e44a-8508-47e8-8016-26ba8492f8b8'},
#   {'InitialPaymentLevelDate': '07012017',
#    'AccountCondition': {'@code': 'A1'},
#    'PaymentStatus': {'@code': '11'},
#    'AccountType': {'@code': '89'},
#    'SpecialComment': {'@code': '  '},
#    'id': 'ep_842917e7-a8b7-41b3-a191-4bf5eaaf4e45'}],
#  'tradeline_amounts': [{'Qualifier': {'@code': 'L'},
#    'Value': '00000350',
#    'id': 'am_124d16d8-dfbd-4087-8524-166dc13ef679',
#    'TradeLine_id': 'tl_04682736-ca7d-49b6-9199-0d4ac3f03b2d'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000056',
#    'id': 'am_637c590d-e17a-4279-a161-626e0dff2ebe',
#    'TradeLine_id': 'tl_04682736-ca7d-49b6-9199-0d4ac3f03b2d'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00011500',
#    'id': 'am_f6a4bd9c-0ceb-4726-ac71-481c211371a0',
#    'TradeLine_id': 'tl_fbddedcd-55fc-44ad-b55e-a2605f221311'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00011440',
#    'id': 'am_8e9b6b5e-429e-4f8a-ab85-4c01d5a62fe4',
#    'TradeLine_id': 'tl_fbddedcd-55fc-44ad-b55e-a2605f221311'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00012900',
#    'id': 'am_2864c251-c44b-46c7-828b-9340df49f018',
#    'TradeLine_id': 'tl_bed432f2-c6ca-4dc7-98ef-5e9fbb2be900'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00008979',
#    'id': 'am_00cbf555-e8e0-4ff2-b913-050954fb0f3f',
#    'TradeLine_id': 'tl_bed432f2-c6ca-4dc7-98ef-5e9fbb2be900'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_cc6daeb9-422d-49b2-b17c-f919ba3dbdcd',
#    'TradeLine_id': 'tl_3f69634f-61c3-4ec2-b6c4-7a588678f301'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_fa7ace6e-c7b7-4e07-9d64-4b7c3bdce725',
#    'TradeLine_id': 'tl_3f69634f-61c3-4ec2-b6c4-7a588678f301'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_8b120fd7-11f6-48dd-8663-a5ce0afbdadd',
#    'TradeLine_id': 'tl_82fc9ebb-39a9-4a03-a93b-cac906c27815'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_11944e78-d3d5-4983-9999-355399d9c9d7',
#    'TradeLine_id': 'tl_82fc9ebb-39a9-4a03-a93b-cac906c27815'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_169e42f6-d8a5-402e-bae5-b6062cbfbc96',
#    'TradeLine_id': 'tl_a428a41a-2361-4515-965c-a8e84e3de446'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_ba4ea015-6a49-4f6b-ab06-8ba78ea887a4',
#    'TradeLine_id': 'tl_a428a41a-2361-4515-965c-a8e84e3de446'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00010000',
#    'id': 'am_9e616b0c-95ac-4084-bc81-1c6661adff48',
#    'TradeLine_id': 'tl_2788da89-a621-4d0a-9ffc-c81b4ec0c2df'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_f9f91469-bd77-4116-bc39-d20f15a75811',
#    'TradeLine_id': 'tl_2788da89-a621-4d0a-9ffc-c81b4ec0c2df'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_b5d5883c-39e0-4a73-8bde-2e852e2cd2a2',
#    'TradeLine_id': 'tl_4e7976e7-1b3e-4583-8dc1-e0901a43f6fa'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_0e7402eb-1c1b-4d69-9391-3f18e43dea1f',
#    'TradeLine_id': 'tl_4e7976e7-1b3e-4583-8dc1-e0901a43f6fa'},
#   {'Qualifier': {'@code': 'O'},
#    'Value': '00040000',
#    'id': 'am_3fd26377-9c8f-49a7-b36f-65c9315967d9',
#    'TradeLine_id': 'tl_8a39cae2-39be-4692-a63e-56fd0d415ce9'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_b44cab96-7cac-4a9e-aa02-7e5d808b11e1',
#    'TradeLine_id': 'tl_8a39cae2-39be-4692-a63e-56fd0d415ce9'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00080000',
#    'id': 'am_f39c9aa5-824e-4254-8337-5b6aea3cc3c3',
#    'TradeLine_id': 'tl_248dbbae-0f9a-4138-93e2-a77973b41264'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00159087',
#    'id': 'am_31919c73-1d6a-42ae-9ca1-2851c53e8fe0',
#    'TradeLine_id': 'tl_248dbbae-0f9a-4138-93e2-a77973b41264'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000223',
#    'id': 'am_d5b64eca-9c99-4e0c-94c2-f16008bdb508',
#    'TradeLine_id': 'tl_f98b68cf-29a5-4361-af70-c7623c37c654'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_aae6eed8-d564-4d5d-ab25-a0fc82234b5d',
#    'TradeLine_id': 'tl_f98b68cf-29a5-4361-af70-c7623c37c654'},
#   {'Qualifier': {'@code': 'O'},
#    'Value': '00150000',
#    'id': 'am_83bf88ba-5e13-4eb3-b401-be39270ecc71',
#    'TradeLine_id': 'tl_7e7921ce-479f-4056-8786-4e2bf9d20a89'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_cc58d16d-3e28-400b-8d9b-1175a0992ee5',
#    'TradeLine_id': 'tl_7e7921ce-479f-4056-8786-4e2bf9d20a89'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00007000',
#    'id': 'am_e88c8c20-fae4-4ba8-8a1f-ec3f21c22cc4',
#    'TradeLine_id': 'tl_5d750318-2471-4423-b0d9-d255d36ee9c2'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000082',
#    'id': 'am_06bfc87c-7f2e-43ca-adea-71aaaf3b7e72',
#    'TradeLine_id': 'tl_5d750318-2471-4423-b0d9-d255d36ee9c2'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00007000',
#    'id': 'am_0759dbf7-2768-46b5-9a7e-c36025c358f2',
#    'TradeLine_id': 'tl_c012648a-5add-4e65-bf8e-4e2062261b99'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00007000',
#    'id': 'am_61c186b2-7f36-4be9-9798-c60e04f77d8f',
#    'TradeLine_id': 'tl_c012648a-5add-4e65-bf8e-4e2062261b99'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00010000',
#    'id': 'am_a7dfb876-e366-4860-8f40-cf02fb1810fa',
#    'TradeLine_id': 'tl_dc54844a-6174-4936-928f-70c1ac877fcf'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00009434',
#    'id': 'am_0e9326f0-7a8e-4641-9d9f-275799bc768c',
#    'TradeLine_id': 'tl_dc54844a-6174-4936-928f-70c1ac877fcf'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00010000',
#    'id': 'am_b7b9b1b7-7329-4fcc-a8f3-e45e842b4321',
#    'TradeLine_id': 'tl_82aca976-0820-4081-94ec-683ba5e3ef49'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00008982',
#    'id': 'am_e25b638b-c750-4dda-ad08-7f90bb3094bc',
#    'TradeLine_id': 'tl_82aca976-0820-4081-94ec-683ba5e3ef49'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00000700',
#    'id': 'am_a94043fd-6fa8-4503-ae82-c2c7c9e63715',
#    'TradeLine_id': 'tl_89e5a29c-ac9e-4ee2-b929-fda32fe1a150'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000283',
#    'id': 'am_dc386a5b-67c9-4043-a497-35f8d87dd18a',
#    'TradeLine_id': 'tl_89e5a29c-ac9e-4ee2-b929-fda32fe1a150'},
#   {'Qualifier': {'@code': ' '},
#    'Value': 'UNKNOWN',
#    'id': 'am_b7171680-fe75-438a-99dd-dfc874a28a02',
#    'TradeLine_id': 'tl_7165d65a-f513-43d6-b535-404aa30eb61b'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_2863c1a1-96a1-4b6a-91bc-14ae3a035f3f',
#    'TradeLine_id': 'tl_7165d65a-f513-43d6-b535-404aa30eb61b'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00004072',
#    'id': 'am_8513d07d-6f69-4241-8f7c-8cf637fb3df5',
#    'TradeLine_id': 'tl_2a249894-1ec2-4f66-80e0-8b502a090b35'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_d5017761-0058-4b03-a0ab-ef8f56a2a3fb',
#    'TradeLine_id': 'tl_2a249894-1ec2-4f66-80e0-8b502a090b35'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00007000',
#    'id': 'am_846435ab-63f9-4045-8c73-456c8c98f795',
#    'TradeLine_id': 'tl_bfe01a0c-cabf-40af-8010-8d9d933410ba'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_5120ef2b-7785-447d-aeea-df8c6ef64459',
#    'TradeLine_id': 'tl_bfe01a0c-cabf-40af-8010-8d9d933410ba'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00007000',
#    'id': 'am_eadb0b5b-e07d-4705-99b9-1c87bbd0660f',
#    'TradeLine_id': 'tl_3c0675fe-681e-428f-9a0f-6aa27a7e5513'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00003813',
#    'id': 'am_2a95cc2e-f93d-4071-8b91-0ecc60434930',
#    'TradeLine_id': 'tl_3c0675fe-681e-428f-9a0f-6aa27a7e5513'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00010000',
#    'id': 'am_1b7351e5-19cb-405b-a61d-4818b8310592',
#    'TradeLine_id': 'tl_5034ee64-8458-4905-bc36-4967bd424dbf'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00008679',
#    'id': 'am_39031fd0-619e-4457-97c4-349de28166cd',
#    'TradeLine_id': 'tl_5034ee64-8458-4905-bc36-4967bd424dbf'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00000500',
#    'id': 'am_e17521e6-2114-4432-9391-3ece10333790',
#    'TradeLine_id': 'tl_17af31cf-1e22-4023-a976-7b07e3d9e7ca'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_caf45a1e-0750-4732-b9df-c1142d371a75',
#    'TradeLine_id': 'tl_17af31cf-1e22-4023-a976-7b07e3d9e7ca'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00012000',
#    'id': 'am_8b379855-d36c-442b-b17b-fc1984d90594',
#    'TradeLine_id': 'tl_b3a9b87b-347c-4af3-a20c-80105b545a3c'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00010020',
#    'id': 'am_72505943-8805-4b6c-b62a-223ff1a5d9f5',
#    'TradeLine_id': 'tl_b3a9b87b-347c-4af3-a20c-80105b545a3c'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00005000',
#    'id': 'am_0a657475-1a46-4d90-acb3-6e4293f1cae2',
#    'TradeLine_id': 'tl_05c9c45f-095f-4f7d-8925-2c8e9000cf0a'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_9b562b54-3cd8-420c-8d27-e2485b9a0fb4',
#    'TradeLine_id': 'tl_05c9c45f-095f-4f7d-8925-2c8e9000cf0a'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00006900',
#    'id': 'am_11ef191d-2d0f-4824-8f7b-280edc6853be',
#    'TradeLine_id': 'tl_94953b3e-e2ed-4e4e-9699-7f53cebae65f'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00003032',
#    'id': 'am_68549aed-0dd6-467a-b5fa-4c6054c02ae5',
#    'TradeLine_id': 'tl_94953b3e-e2ed-4e4e-9699-7f53cebae65f'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00001000',
#    'id': 'am_b952b559-f9ff-4d9f-a7b3-b9b0dc860d55',
#    'TradeLine_id': 'tl_9ffe784f-0f78-4a0b-9745-48de17a311a0'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000285',
#    'id': 'am_bc5f3036-cc27-4e89-9eeb-f270a7d1222a',
#    'TradeLine_id': 'tl_9ffe784f-0f78-4a0b-9745-48de17a311a0'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00001500',
#    'id': 'am_3156eb55-764f-4371-a751-e13d49ccc028',
#    'TradeLine_id': 'tl_989cb800-44ba-4501-9bdd-94633989aa0f'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000546',
#    'id': 'am_26051ca2-4400-4e3a-9562-f2a3a25e6214',
#    'TradeLine_id': 'tl_989cb800-44ba-4501-9bdd-94633989aa0f'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00003600',
#    'id': 'am_a30dc9cb-cdcf-4903-a6ea-0cfab3e58b50',
#    'TradeLine_id': 'tl_4de1cc4d-0e50-497d-84b3-d3c2974a2cb5'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00001184',
#    'id': 'am_8891f2fb-067c-463e-aba9-d88f1c0cbbce',
#    'TradeLine_id': 'tl_4de1cc4d-0e50-497d-84b3-d3c2974a2cb5'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000723',
#    'id': 'am_ee9c2cbc-c270-4900-980c-bdd30678c0de',
#    'TradeLine_id': 'tl_8617b55b-066c-4cd5-9e4f-bf08f198053a'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_92e20bff-4125-40f4-a0ab-28876880f0f9',
#    'TradeLine_id': 'tl_8617b55b-066c-4cd5-9e4f-bf08f198053a'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00019000',
#    'id': 'am_40a077b2-d8dd-4de1-b165-182b77279a88',
#    'TradeLine_id': 'tl_fa9fb661-67a7-4813-9947-232ca900a7db'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00010513',
#    'id': 'am_c04a74bc-819a-4552-a06d-2fc4fb6d6ba7',
#    'TradeLine_id': 'tl_fa9fb661-67a7-4813-9947-232ca900a7db'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00012200',
#    'id': 'am_7c6fb9b6-563f-4a8b-8f98-face40c5b741',
#    'TradeLine_id': 'tl_2b27898e-7585-438c-8b66-496b8afe4326'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000629',
#    'id': 'am_1c6e6a55-28be-4ac4-891b-651abb67fb1f',
#    'TradeLine_id': 'tl_2b27898e-7585-438c-8b66-496b8afe4326'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00001047',
#    'id': 'am_8d0dfe57-dd30-4975-b014-4b5ef30e628b',
#    'TradeLine_id': 'tl_f40b425d-98fe-4904-aa57-025943671ab7'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_4302cd6a-891d-447b-b2fd-3383f3ddec36',
#    'TradeLine_id': 'tl_f40b425d-98fe-4904-aa57-025943671ab7'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00007361',
#    'id': 'am_6c00bf4d-83de-4d15-a965-b7c4c9ceac88',
#    'TradeLine_id': 'tl_6c01c68c-a1d3-464f-8427-ba4018164846'},
#   {'Qualifier': {'@code': ' '},
#    'Value': None,
#    'id': 'am_92792154-4f8d-4c4b-928d-e55ecf0d2717',
#    'TradeLine_id': 'tl_6c01c68c-a1d3-464f-8427-ba4018164846'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00001500',
#    'id': 'am_f9bfe316-e34d-4661-ba24-f5784c86f0bc',
#    'TradeLine_id': 'tl_cf1788c3-3ca5-4e57-8c87-f98378919358'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00000089',
#    'id': 'am_c4493d91-7076-4321-8b8a-69b3484a0c89',
#    'TradeLine_id': 'tl_cf1788c3-3ca5-4e57-8c87-f98378919358'},
#   {'Qualifier': {'@code': 'L'},
#    'Value': '00150000',
#    'id': 'am_87131b44-ce20-42f4-96ca-e4b5d2e56551',
#    'TradeLine_id': 'tl_46f334d7-1396-4d5f-89be-de0592c82428'},
#   {'Qualifier': {'@code': 'H'},
#    'Value': '00022118',
#    'id': 'am_2cc90b9b-356a-44a0-84c2-c3a1f259deca',
#    'TradeLine_id': 'tl_46f334d7-1396-4d5f-89be-de0592c82428'}]}

# %% [markdown]
# Parse XML data string and build XML_Detail table objects

# %%
RESULT_OBJ_DICT['tradeline_amounts']
# Out:
# [{'Qualifier': {'@code': 'L'},
#   'Value': '00000350',
#   'id': 'am_124d16d8-dfbd-4087-8524-166dc13ef679',
#   'TradeLine_id': 'tl_04682736-ca7d-49b6-9199-0d4ac3f03b2d'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00000056',
#   'id': 'am_637c590d-e17a-4279-a161-626e0dff2ebe',
#   'TradeLine_id': 'tl_04682736-ca7d-49b6-9199-0d4ac3f03b2d'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00011500',
#   'id': 'am_f6a4bd9c-0ceb-4726-ac71-481c211371a0',
#   'TradeLine_id': 'tl_fbddedcd-55fc-44ad-b55e-a2605f221311'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00011440',
#   'id': 'am_8e9b6b5e-429e-4f8a-ab85-4c01d5a62fe4',
#   'TradeLine_id': 'tl_fbddedcd-55fc-44ad-b55e-a2605f221311'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00012900',
#   'id': 'am_2864c251-c44b-46c7-828b-9340df49f018',
#   'TradeLine_id': 'tl_bed432f2-c6ca-4dc7-98ef-5e9fbb2be900'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00008979',
#   'id': 'am_00cbf555-e8e0-4ff2-b913-050954fb0f3f',
#   'TradeLine_id': 'tl_bed432f2-c6ca-4dc7-98ef-5e9fbb2be900'},
#  {'Qualifier': {'@code': ' '},
#   'Value': 'UNKNOWN',
#   'id': 'am_cc6daeb9-422d-49b2-b17c-f919ba3dbdcd',
#   'TradeLine_id': 'tl_3f69634f-61c3-4ec2-b6c4-7a588678f301'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_fa7ace6e-c7b7-4e07-9d64-4b7c3bdce725',
#   'TradeLine_id': 'tl_3f69634f-61c3-4ec2-b6c4-7a588678f301'},
#  {'Qualifier': {'@code': ' '},
#   'Value': 'UNKNOWN',
#   'id': 'am_8b120fd7-11f6-48dd-8663-a5ce0afbdadd',
#   'TradeLine_id': 'tl_82fc9ebb-39a9-4a03-a93b-cac906c27815'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_11944e78-d3d5-4983-9999-355399d9c9d7',
#   'TradeLine_id': 'tl_82fc9ebb-39a9-4a03-a93b-cac906c27815'},
#  {'Qualifier': {'@code': ' '},
#   'Value': 'UNKNOWN',
#   'id': 'am_169e42f6-d8a5-402e-bae5-b6062cbfbc96',
#   'TradeLine_id': 'tl_a428a41a-2361-4515-965c-a8e84e3de446'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_ba4ea015-6a49-4f6b-ab06-8ba78ea887a4',
#   'TradeLine_id': 'tl_a428a41a-2361-4515-965c-a8e84e3de446'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00010000',
#   'id': 'am_9e616b0c-95ac-4084-bc81-1c6661adff48',
#   'TradeLine_id': 'tl_2788da89-a621-4d0a-9ffc-c81b4ec0c2df'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_f9f91469-bd77-4116-bc39-d20f15a75811',
#   'TradeLine_id': 'tl_2788da89-a621-4d0a-9ffc-c81b4ec0c2df'},
#  {'Qualifier': {'@code': ' '},
#   'Value': 'UNKNOWN',
#   'id': 'am_b5d5883c-39e0-4a73-8bde-2e852e2cd2a2',
#   'TradeLine_id': 'tl_4e7976e7-1b3e-4583-8dc1-e0901a43f6fa'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_0e7402eb-1c1b-4d69-9391-3f18e43dea1f',
#   'TradeLine_id': 'tl_4e7976e7-1b3e-4583-8dc1-e0901a43f6fa'},
#  {'Qualifier': {'@code': 'O'},
#   'Value': '00040000',
#   'id': 'am_3fd26377-9c8f-49a7-b36f-65c9315967d9',
#   'TradeLine_id': 'tl_8a39cae2-39be-4692-a63e-56fd0d415ce9'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_b44cab96-7cac-4a9e-aa02-7e5d808b11e1',
#   'TradeLine_id': 'tl_8a39cae2-39be-4692-a63e-56fd0d415ce9'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00080000',
#   'id': 'am_f39c9aa5-824e-4254-8337-5b6aea3cc3c3',
#   'TradeLine_id': 'tl_248dbbae-0f9a-4138-93e2-a77973b41264'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00159087',
#   'id': 'am_31919c73-1d6a-42ae-9ca1-2851c53e8fe0',
#   'TradeLine_id': 'tl_248dbbae-0f9a-4138-93e2-a77973b41264'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00000223',
#   'id': 'am_d5b64eca-9c99-4e0c-94c2-f16008bdb508',
#   'TradeLine_id': 'tl_f98b68cf-29a5-4361-af70-c7623c37c654'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_aae6eed8-d564-4d5d-ab25-a0fc82234b5d',
#   'TradeLine_id': 'tl_f98b68cf-29a5-4361-af70-c7623c37c654'},
#  {'Qualifier': {'@code': 'O'},
#   'Value': '00150000',
#   'id': 'am_83bf88ba-5e13-4eb3-b401-be39270ecc71',
#   'TradeLine_id': 'tl_7e7921ce-479f-4056-8786-4e2bf9d20a89'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_cc58d16d-3e28-400b-8d9b-1175a0992ee5',
#   'TradeLine_id': 'tl_7e7921ce-479f-4056-8786-4e2bf9d20a89'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00007000',
#   'id': 'am_e88c8c20-fae4-4ba8-8a1f-ec3f21c22cc4',
#   'TradeLine_id': 'tl_5d750318-2471-4423-b0d9-d255d36ee9c2'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00000082',
#   'id': 'am_06bfc87c-7f2e-43ca-adea-71aaaf3b7e72',
#   'TradeLine_id': 'tl_5d750318-2471-4423-b0d9-d255d36ee9c2'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00007000',
#   'id': 'am_0759dbf7-2768-46b5-9a7e-c36025c358f2',
#   'TradeLine_id': 'tl_c012648a-5add-4e65-bf8e-4e2062261b99'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00007000',
#   'id': 'am_61c186b2-7f36-4be9-9798-c60e04f77d8f',
#   'TradeLine_id': 'tl_c012648a-5add-4e65-bf8e-4e2062261b99'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00010000',
#   'id': 'am_a7dfb876-e366-4860-8f40-cf02fb1810fa',
#   'TradeLine_id': 'tl_dc54844a-6174-4936-928f-70c1ac877fcf'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00009434',
#   'id': 'am_0e9326f0-7a8e-4641-9d9f-275799bc768c',
#   'TradeLine_id': 'tl_dc54844a-6174-4936-928f-70c1ac877fcf'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00010000',
#   'id': 'am_b7b9b1b7-7329-4fcc-a8f3-e45e842b4321',
#   'TradeLine_id': 'tl_82aca976-0820-4081-94ec-683ba5e3ef49'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00008982',
#   'id': 'am_e25b638b-c750-4dda-ad08-7f90bb3094bc',
#   'TradeLine_id': 'tl_82aca976-0820-4081-94ec-683ba5e3ef49'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00000700',
#   'id': 'am_a94043fd-6fa8-4503-ae82-c2c7c9e63715',
#   'TradeLine_id': 'tl_89e5a29c-ac9e-4ee2-b929-fda32fe1a150'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00000283',
#   'id': 'am_dc386a5b-67c9-4043-a497-35f8d87dd18a',
#   'TradeLine_id': 'tl_89e5a29c-ac9e-4ee2-b929-fda32fe1a150'},
#  {'Qualifier': {'@code': ' '},
#   'Value': 'UNKNOWN',
#   'id': 'am_b7171680-fe75-438a-99dd-dfc874a28a02',
#   'TradeLine_id': 'tl_7165d65a-f513-43d6-b535-404aa30eb61b'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_2863c1a1-96a1-4b6a-91bc-14ae3a035f3f',
#   'TradeLine_id': 'tl_7165d65a-f513-43d6-b535-404aa30eb61b'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00004072',
#   'id': 'am_8513d07d-6f69-4241-8f7c-8cf637fb3df5',
#   'TradeLine_id': 'tl_2a249894-1ec2-4f66-80e0-8b502a090b35'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_d5017761-0058-4b03-a0ab-ef8f56a2a3fb',
#   'TradeLine_id': 'tl_2a249894-1ec2-4f66-80e0-8b502a090b35'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00007000',
#   'id': 'am_846435ab-63f9-4045-8c73-456c8c98f795',
#   'TradeLine_id': 'tl_bfe01a0c-cabf-40af-8010-8d9d933410ba'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_5120ef2b-7785-447d-aeea-df8c6ef64459',
#   'TradeLine_id': 'tl_bfe01a0c-cabf-40af-8010-8d9d933410ba'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00007000',
#   'id': 'am_eadb0b5b-e07d-4705-99b9-1c87bbd0660f',
#   'TradeLine_id': 'tl_3c0675fe-681e-428f-9a0f-6aa27a7e5513'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00003813',
#   'id': 'am_2a95cc2e-f93d-4071-8b91-0ecc60434930',
#   'TradeLine_id': 'tl_3c0675fe-681e-428f-9a0f-6aa27a7e5513'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00010000',
#   'id': 'am_1b7351e5-19cb-405b-a61d-4818b8310592',
#   'TradeLine_id': 'tl_5034ee64-8458-4905-bc36-4967bd424dbf'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00008679',
#   'id': 'am_39031fd0-619e-4457-97c4-349de28166cd',
#   'TradeLine_id': 'tl_5034ee64-8458-4905-bc36-4967bd424dbf'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00000500',
#   'id': 'am_e17521e6-2114-4432-9391-3ece10333790',
#   'TradeLine_id': 'tl_17af31cf-1e22-4023-a976-7b07e3d9e7ca'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_caf45a1e-0750-4732-b9df-c1142d371a75',
#   'TradeLine_id': 'tl_17af31cf-1e22-4023-a976-7b07e3d9e7ca'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00012000',
#   'id': 'am_8b379855-d36c-442b-b17b-fc1984d90594',
#   'TradeLine_id': 'tl_b3a9b87b-347c-4af3-a20c-80105b545a3c'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00010020',
#   'id': 'am_72505943-8805-4b6c-b62a-223ff1a5d9f5',
#   'TradeLine_id': 'tl_b3a9b87b-347c-4af3-a20c-80105b545a3c'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00005000',
#   'id': 'am_0a657475-1a46-4d90-acb3-6e4293f1cae2',
#   'TradeLine_id': 'tl_05c9c45f-095f-4f7d-8925-2c8e9000cf0a'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_9b562b54-3cd8-420c-8d27-e2485b9a0fb4',
#   'TradeLine_id': 'tl_05c9c45f-095f-4f7d-8925-2c8e9000cf0a'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00006900',
#   'id': 'am_11ef191d-2d0f-4824-8f7b-280edc6853be',
#   'TradeLine_id': 'tl_94953b3e-e2ed-4e4e-9699-7f53cebae65f'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00003032',
#   'id': 'am_68549aed-0dd6-467a-b5fa-4c6054c02ae5',
#   'TradeLine_id': 'tl_94953b3e-e2ed-4e4e-9699-7f53cebae65f'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00001000',
#   'id': 'am_b952b559-f9ff-4d9f-a7b3-b9b0dc860d55',
#   'TradeLine_id': 'tl_9ffe784f-0f78-4a0b-9745-48de17a311a0'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00000285',
#   'id': 'am_bc5f3036-cc27-4e89-9eeb-f270a7d1222a',
#   'TradeLine_id': 'tl_9ffe784f-0f78-4a0b-9745-48de17a311a0'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00001500',
#   'id': 'am_3156eb55-764f-4371-a751-e13d49ccc028',
#   'TradeLine_id': 'tl_989cb800-44ba-4501-9bdd-94633989aa0f'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00000546',
#   'id': 'am_26051ca2-4400-4e3a-9562-f2a3a25e6214',
#   'TradeLine_id': 'tl_989cb800-44ba-4501-9bdd-94633989aa0f'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00003600',
#   'id': 'am_a30dc9cb-cdcf-4903-a6ea-0cfab3e58b50',
#   'TradeLine_id': 'tl_4de1cc4d-0e50-497d-84b3-d3c2974a2cb5'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00001184',
#   'id': 'am_8891f2fb-067c-463e-aba9-d88f1c0cbbce',
#   'TradeLine_id': 'tl_4de1cc4d-0e50-497d-84b3-d3c2974a2cb5'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00000723',
#   'id': 'am_ee9c2cbc-c270-4900-980c-bdd30678c0de',
#   'TradeLine_id': 'tl_8617b55b-066c-4cd5-9e4f-bf08f198053a'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_92e20bff-4125-40f4-a0ab-28876880f0f9',
#   'TradeLine_id': 'tl_8617b55b-066c-4cd5-9e4f-bf08f198053a'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00019000',
#   'id': 'am_40a077b2-d8dd-4de1-b165-182b77279a88',
#   'TradeLine_id': 'tl_fa9fb661-67a7-4813-9947-232ca900a7db'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00010513',
#   'id': 'am_c04a74bc-819a-4552-a06d-2fc4fb6d6ba7',
#   'TradeLine_id': 'tl_fa9fb661-67a7-4813-9947-232ca900a7db'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00012200',
#   'id': 'am_7c6fb9b6-563f-4a8b-8f98-face40c5b741',
#   'TradeLine_id': 'tl_2b27898e-7585-438c-8b66-496b8afe4326'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00000629',
#   'id': 'am_1c6e6a55-28be-4ac4-891b-651abb67fb1f',
#   'TradeLine_id': 'tl_2b27898e-7585-438c-8b66-496b8afe4326'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00001047',
#   'id': 'am_8d0dfe57-dd30-4975-b014-4b5ef30e628b',
#   'TradeLine_id': 'tl_f40b425d-98fe-4904-aa57-025943671ab7'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_4302cd6a-891d-447b-b2fd-3383f3ddec36',
#   'TradeLine_id': 'tl_f40b425d-98fe-4904-aa57-025943671ab7'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00007361',
#   'id': 'am_6c00bf4d-83de-4d15-a965-b7c4c9ceac88',
#   'TradeLine_id': 'tl_6c01c68c-a1d3-464f-8427-ba4018164846'},
#  {'Qualifier': {'@code': ' '},
#   'Value': None,
#   'id': 'am_92792154-4f8d-4c4b-928d-e55ecf0d2717',
#   'TradeLine_id': 'tl_6c01c68c-a1d3-464f-8427-ba4018164846'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00001500',
#   'id': 'am_f9bfe316-e34d-4661-ba24-f5784c86f0bc',
#   'TradeLine_id': 'tl_cf1788c3-3ca5-4e57-8c87-f98378919358'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00000089',
#   'id': 'am_c4493d91-7076-4321-8b8a-69b3484a0c89',
#   'TradeLine_id': 'tl_cf1788c3-3ca5-4e57-8c87-f98378919358'},
#  {'Qualifier': {'@code': 'L'},
#   'Value': '00150000',
#   'id': 'am_87131b44-ce20-42f4-96ca-e4b5d2e56551',
#   'TradeLine_id': 'tl_46f334d7-1396-4d5f-89be-de0592c82428'},
#  {'Qualifier': {'@code': 'H'},
#   'Value': '00022118',
#   'id': 'am_2cc90b9b-356a-44a0-84c2-c3a1f259deca',
#   'TradeLine_id': 'tl_46f334d7-1396-4d5f-89be-de0592c82428'}]
