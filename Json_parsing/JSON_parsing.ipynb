# %%
import json
import pprint
import uuid
import xmltodict
import pandas as pd

pd.set_option('display.max_rows', 10)
RESULT_TABLE_NAMES = ['prequal_results', 'xml_details', 'products', 'credit_profiles', 'headers', 'risk_models', 'consumer_identities', 'addr_infos', 'employ_infos', 'trade_lines', 'inquiries', 'info_msgs', 'enhanced_pm_data', 'tradeline_amounts']
with open("./data/prequalresult.json", 'r') as f:
    json_file = json.load(f)
json_file
# Out:
# [{'model': 'common.prequalresult',
#   'pk': 1,
#   'fields': {'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant'}}]

# %% [markdown]
# Parse XML data string and build the internal objects into the designed tables

# %%
# initialize result object lists
RESULT_OBJ_DICT = dict((key, []) for key in RESULT_TABLE_NAMES)
ATTR_CODE_DICT = {
    'risk_models': ['ModelIndicator', 'Evaluation'],
    'addr_infos': ['Origination', 'DwellingType', 'HomeOwnership'],
    'employ_infos': ['Origination'],
    'trade_lines': ['SpecialComment', 'Evaluation', 'AccountType', 'TermsDuration', 'Status', 'ECOA', 'OpenOrClosed', 'RevolvingOrInstallment', 'MonthlyPaymentType', 'KOB'],
    'tradeline_amounts': ['Qualifier'],
    'enhanced_pm_data': ['AccountCondition', 'PaymentStatus', 'AccountType', 'SpecialComment'],
    'inquiries': ['Type', 'Terms', 'KOB'],
}

prequal_results = json_file
for prequal_result in prequal_results:
    prequal_result.update(prequal_result.pop('fields'))
    xml_detail_id = "xd_{}".format(uuid.uuid4())
    prequal_result['xml_detail_id'] = xml_detail_id
    RESULT_OBJ_DICT['prequal_results'].append(prequal_result)
    
    # initializing XML_Detail object
    xml_dict = xmltodict.parse(result['xml_data'], dict_constructor=dict)['NetConnectResponse']
    xml_dict['id'] = xml_detail_id
    RESULT_OBJ_DICT['xml_details'].append(xml_dict)
    product_id = "pd_{}".format(uuid.uuid4())
    xml_dict['product_id'] = product_id
    
    # initializing Product object
    product_obj = xml_dict.pop('Products')
    product_obj['id'] = product_id
    RESULT_OBJ_DICT['products'].append(product_obj)
    credit_profile_id = "cp_{}".format(uuid.uuid4())
    product_obj['credit_profile_id'] = credit_profile_id
    
    # initializing CreditProfile object
    credit_profile_obj = product_obj.pop('CreditProfile')
    credit_profile_obj['id'] = credit_profile_id
    RESULT_OBJ_DICT['credit_profiles'].append(credit_profile_obj)
    
    
    ## handling RiskModels in CreditProfile
    for risk_model in credit_profile_obj.pop('RiskModel'):
        risk_model['id'] = "rm_{}".format(uuid.uuid4())
        risk_model['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['risk_models'].append(risk_model)
    
    # initializing Header object in CreditProfile
    header_id = "hd_{}".format(uuid.uuid4())
    credit_profile_obj['header_id'] = header_id
    header_obj = credit_profile_obj.pop('Header')
    header_obj['id'] = header_id
    RESULT_OBJ_DICT['headers'].append(header_obj)
    
    ## handling ConsumerIdentities in CreditProfile
    name_attrs = ['Surname', 'First', 'Middle', 'Gen']
    for consumer_identity in credit_profile_obj.pop('ConsumerIdentity'):
        consumer_identity['id'] = "ci_{}".format(uuid.uuid4())
        for name_attr in name_attrs:
            if name_attr in consumer_identity['Name']:
                attr_v = consumer_identity['Name'][name_attr]
            else:
                attr_v = ''
            consumer_identity[name_attr] = attr_v
        consumer_identity['YOB'] = consumer_identity['YOB']
        if 'Type' in consumer_identity['Name']:
            name_type_code = consumer_identity['Name']['Type']['@code']
        else:
            name_type_code = ''
        consumer_identity['NameType_code'] = name_type_code
        del consumer_identity['Name']
        consumer_identity['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['consumer_identities'].append(consumer_identity)
    
    ## handling AddressInformations in CreditProfile
    for addr_info in credit_profile_obj.pop('AddressInformation'):
        addr_info['id'] = "ai_{}".format(uuid.uuid4())
        addr_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['addr_infos'].append(addr_info)
       
    ## handling EmploymentInformations in CreditProfile
    for employ_info in credit_profile_obj.pop('EmploymentInformation'):
        employ_info['id'] = "ei_{}".format(uuid.uuid4())
        employ_info['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['employ_infos'].append(employ_info)
        
    ## handling TradeLines in CreditProfile
    code_attrs = ['SpecialComment', 'Evaluation', 'AccountType', 'TermsDuration', 'Status', 'OpenOrClosed', 'RevolvingOrInstallment', 'MonthlyPaymentType', 'KOB']
    for trade_line in credit_profile_obj.pop('TradeLine'):
        trade_line['id'] = "tl_{}".format(uuid.uuid4())
        trade_line['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['trade_lines'].append(trade_line)
        
        # initializing EnhancedPaymentData object in TradeLine
        enhanced_pm_data_id = "ep_{}".format(uuid.uuid4())
        trade_line['enhanced_pm_data_id'] = enhanced_pm_data_id
        enhanced_pm_data_obj = trade_line.pop('EnhancedPaymentData')
        enhanced_pm_data_obj['id'] = enhanced_pm_data_id
        RESULT_OBJ_DICT['enhanced_pm_data'].append(enhanced_pm_data_obj)
        
        ## handling Amount object in TradeLine
        for amt_obj in trade_line.pop('Amount'):
            amt_obj['id'] = "am_{}".format(uuid.uuid4())
            amt_obj['TradeLine_id'] = trade_line['id']
            RESULT_OBJ_DICT['tradeline_amounts'].append(amt_obj)
    
    # initializing Inquiry object in CreditProfile
    inquiry_id = "iq_{}".format(uuid.uuid4())
    credit_profile_obj['inquiry_id'] = inquiry_id
    inquiry_obj = credit_profile_obj.pop('Inquiry')
    inquiry_obj['id'] = inquiry_id
    RESULT_OBJ_DICT['inquiries'].append(inquiry_obj)
    
    ## handling InformationalMessages in CreditProfile
    for info_msg in credit_profile_obj.pop('InformationalMessage'):
        info_msg['id'] = "im_{}".format(uuid.uuid4())
        info_msg['CreditProfile_id'] = credit_profile_id
        RESULT_OBJ_DICT['info_msgs'].append(info_msg)
    
# converting sub-attrs into underscore attrs
for attr, code_attr_list in ATTR_CODE_DICT.items():
    attr_obj_list = RESULT_OBJ_DICT[attr]
    for attr_obj in attr_obj_list:
        for attr in code_attr_list:
            if attr in attr_obj:
                code = attr_obj[attr]['@code']
            else:
                code = ''
            attr_obj["{}_code".format(attr)] = code
            attr_obj.pop(attr, None)
    
RESULT_OBJ_DICT
# Out:
# {'prequal_results': [{'model': 'common.prequalresult',
#    'pk': 1,
#    'loanapp_id': 194,
#    'result': True,
#    'error_reason': 'no reasons',
#    'detail_results': None,
#    'fico_v2': '695',
#    'report_type': 'CreditProfile',
#    'username': 'cho',
#    'created_at': '2016-08-04T00:29:03.067Z',
#    'xml_data': '<?xml version="1.0" standalone="no"?><NetConnectResponse xmlns="http://www.experian.com/NetConnectResponse"><CompletionCode>0000</CompletionCode><ReferenceId>testing 123</ReferenceId><TransactionId>41588980</TransactionId><Products xmlns="http://www.experian.com/ARFResponse"><CreditProfile><Header><ReportDate>10032017</ReportDate><ReportTime>140607</ReportTime><Preamble>TWA1</Preamble><ARFVersion>07</ARFVersion></Header><RiskModel><ModelIndicator code="F "/><Score>0808</Score><ScoreFactorCodeOne>10</ScoreFactorCodeOne><ScoreFactorCodeTwo>09</ScoreFactorCodeTwo><ScoreFactorCodeThree>05</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><RiskModel><ModelIndicator code="AA"/><Score>0807</Score><ScoreFactorCodeOne>30</ScoreFactorCodeOne><ScoreFactorCodeTwo>05</ScoreFactorCodeTwo><ScoreFactorCodeThree>11</ScoreFactorCodeThree><ScoreFactorCodeFour>  </ScoreFactorCodeFour><Evaluation code="P"/></RiskModel><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="N"/><Surname>SCALICI</Surname><First>AS</First><Middle>WILLIAM</Middle></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Surname>SCALICI</Surname><First>WILLIAM</First><Gen>JR</Gen></Name><YOB>    </YOB></ConsumerIdentity><ConsumerIdentity><Name><Type code="A"/><Surname>ANTHONY</Surname><First>WILLIAM</First><Middle>R</Middle></Name><YOB>    </YOB></ConsumerIdentity><AddressInformation><FirstReportedDate>10272003</FirstReportedDate><LastUpdatedDate>12202015</LastUpdatedDate><Origination code="2"/><TimesReported>00</TimesReported><LastReportingSubcode>7370142</LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>7324</StreetPrefix><StreetName>84TH STREET</StreetName><StreetSuffix>CT SW</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984986380</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>01012011</FirstReportedDate><LastUpdatedDate>01012011</LastUpdatedDate><Origination code="1"/><TimesReported>00</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3260 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><AddressInformation><FirstReportedDate>05282006</FirstReportedDate><LastUpdatedDate>11022010</LastUpdatedDate><Origination code="1"/><TimesReported>12</TimesReported><LastReportingSubcode>       </LastReportingSubcode><DwellingType code="S"/><HomeOwnership code=" "/><StreetPrefix>3216 S</StreetPrefix><StreetName>TACOMA</StreetName><StreetSuffix>WAY</StreetSuffix><City>TACOMA</City><State>WA</State><Zip>984094725</Zip><CensusGeoCode>       </CensusGeoCode></AddressInformation><EmploymentInformation><FirstReportedDate>04082011</FirstReportedDate><LastUpdatedDate>04082011</LastUpdatedDate><Origination code="2"/><Name>GM RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><EmploymentInformation><FirstReportedDate>12282009</FirstReportedDate><LastUpdatedDate>06112010</LastUpdatedDate><Origination code="2"/><Name>RETIRED</Name><AddressFirstLine> </AddressFirstLine><AddressSecondLine> </AddressSecondLine><AddressExtraLine> </AddressExtraLine><Zip>          </Zip></EmploymentInformation><TradeLine><SpecialComment code="28"/><Evaluation code="N"/><OpenDate>06011981</OpenDate><StatusDate>05012017</StatusDate><MaxDelinquencyDate>        </MaxDelinquencyDate><AccountType code="18"/><TermsDuration code="REV"/><ECOA code="1"/><Amount><Qualifier code="L"/><Value>00000350</Value></Amount><Amount><Qualifier code="H"/><Value>00000056</Value></Amount><BalanceDate>05192017</BalanceDate><BalanceAmo ...
#    'personal_total_monthly_payments': None,
#    'personal_credit_card_total_limits': None,
#    'personal_credit_card_total_balances': None,
#    'business_credit_card_total_limits': None,
#    'business_credit_card_total_balances': None,
#    'business_total_mortgage_monthly_payments': None,
#    'business_total_monthly_debt_payments': None,
#    'bkdate': None,
#    'fico_v3': None,
#    'total_mortgage_monthly_payments': None,
#    'version': 'CF Microloan',
#    'role': 'applicant',
#    'xml_detail_id': 'xd_33d31da3-3f55-4238-a9cb-c090f13cc2e5'}],
#  'xml_details': [{'@xmlns': 'http://www.experian.com/NetConnectResponse',
#    'CompletionCode': '0000',
#    'ReferenceId': 'testing 123',
#    'TransactionId': '41588980',
#    'id': 'xd_33d31da3-3f55-4238-a9cb-c090f13cc2e5',
#    'product_id': 'pd_81025c35-8e16-462a-b457-17b838fe21b8'}],
#  'products': [{'@xmlns': 'http://www.experian.com/ARFResponse',
#    'id': 'pd_81025c35-8e16-462a-b457-17b838fe21b8',
#    'credit_profile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'}],
#  'credit_profiles': [{'id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'header_id': 'hd_a6a390f7-11f7-40ab-844c-298ce0e4039a',
#    'inquiry_id': 'iq_288adcc1-a898-45fd-9b5d-91c918d963d6'}],
#  'headers': [{'ReportDate': '10032017',
#    'ReportTime': '140607',
#    'Preamble': 'TWA1',
#    'ARFVersion': '07',
#    'id': 'hd_a6a390f7-11f7-40ab-844c-298ce0e4039a'}],
#  'risk_models': [{'Score': '0808',
#    'ScoreFactorCodeOne': '10',
#    'ScoreFactorCodeTwo': '09',
#    'ScoreFactorCodeThree': '05',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_e6cfea6e-ca63-4b2b-a514-cdc40086d057',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'ModelIndicator_code': 'F ',
#    'Evaluation_code': 'P'},
#   {'Score': '0807',
#    'ScoreFactorCodeOne': '30',
#    'ScoreFactorCodeTwo': '05',
#    'ScoreFactorCodeThree': '11',
#    'ScoreFactorCodeFour': None,
#    'id': 'rm_e887dcb0-a4d8-472e-be82-c3aeacd015f8',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'ModelIndicator_code': 'AA',
#    'Evaluation_code': 'P'}],
#  'consumer_identities': [{'YOB': None,
#    'id': 'ci_96c6683f-47f4-43bc-958b-339dd5755b2a',
#    'Surname': 'SCALICI',
#    'First': 'WILLIAM',
#    'Middle': '',
#    'Gen': '',
#    'NameType_code': '',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'},
#   {'YOB': None,
#    'id': 'ci_16874b77-f28a-49d2-85f6-0fead5f8fb97',
#    'Surname': 'SCALICI',
#    'First': 'AS',
#    'Middle': 'WILLIAM',
#    'Gen': '',
#    'NameType_code': 'N',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'},
#   {'YOB': None,
#    'id': 'ci_6336a8b5-f7f0-4f00-ad2e-6f7c82415042',
#    'Surname': 'SCALICI',
#    'First': 'WILLIAM',
#    'Middle': '',
#    'Gen': 'JR',
#    'NameType_code': '',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'},
#   {'YOB': None,
#    'id': 'ci_7d44be99-91b4-4516-bc60-c65b6ba34fb0',
#    'Surname': 'ANTHONY',
#    'First': 'WILLIAM',
#    'Middle': 'R',
#    'Gen': '',
#    'NameType_code': 'A',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'}],
#  'addr_infos': [{'FirstReportedDate': '10272003',
#    'LastUpdatedDate': '12202015',
#    'TimesReported': '00',
#    'LastReportingSubcode': '7370142',
#    'StreetPrefix': '7324',
#    'StreetName': '84TH STREET',
#    'StreetSuffix': 'CT SW',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984986380',
#    'CensusGeoCode': None,
#    'id': 'ai_b31f5b14-1fc3-486b-8781-9dcc9fe96bb0',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'Origination_code': '2',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '01012011',
#    'LastUpdatedDate': '01012011',
#    'TimesReported': '00',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3260 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_aac7988d-95e2-425a-ab7f-d91fef025f88',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '},
#   {'FirstReportedDate': '05282006',
#    'LastUpdatedDate': '11022010',
#    'TimesReported': '12',
#    'LastReportingSubcode': None,
#    'StreetPrefix': '3216 S',
#    'StreetName': 'TACOMA',
#    'StreetSuffix': 'WAY',
#    'City': 'TACOMA',
#    'State': 'WA',
#    'Zip': '984094725',
#    'CensusGeoCode': None,
#    'id': 'ai_ab82d74c-74d1-42f4-80e0-2784e9d51c23',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'Origination_code': '1',
#    'DwellingType_code': 'S',
#    'HomeOwnership_code': ' '}],
#  'employ_infos': [{'FirstReportedDate': '04082011',
#    'LastUpdatedDate': '04082011',
#    'Name': 'GM RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_6c59e6ea-e02f-4df3-a944-c74c9883ebdf',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'Origination_code': '2'},
#   {'FirstReportedDate': '12282009',
#    'LastUpdatedDate': '06112010',
#    'Name': 'RETIRED',
#    'AddressFirstLine': None,
#    'AddressSecondLine': None,
#    'AddressExtraLine': None,
#    'Zip': None,
#    'id': 'ei_d63a1bf8-36fe-4605-9bfa-8a8b777ea155',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'Origination_code': '2'}],
#  'trade_lines': [{'OpenDate': '06011981',
#    'StatusDate': '05012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '05192017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '15',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01032016',
#    'Subcode': '1401790',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_e99abe94-fb64-4f72-8b3e-ffe50f9151cc',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_be81da4a-f067-4fe0-9af8-f90de047374a',
#    'SpecialComment_code': '28',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03182012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1213727',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_7edd5a5b-35d8-4d80-b1b1-516ee5ad7a83',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_270687c8-893a-4639-9d91-c76296a54e96',
#    'SpecialComment_code': '31',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '05',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '06102006',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '07232017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '96',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0---------CCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '07212015',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_304db81f-57c1-499e-bc9b-d21c2f1ce9f2',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_7966909c-b9e6-4212-9cc6-aec4d1948471',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC'},
#   {'OpenDate': '08282007',
#    'StatusDate': '03012012',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '04282012',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '03',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '01122010',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_388c50ef-fa08-4570-8b2b-53703c078658',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_e4d9adbf-61b9-4183-bc78-ab8a53413d97',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BC'},
#   {'OpenDate': '03012002',
#    'StatusDate': '04012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '04012009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '86',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00--------0-----------00',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12102006',
#    'Subcode': '1439507',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_6c06c7bc-30ae-4968-8112-95895298a3be',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_c3c7268d-6147-40a3-a31a-9091637e1938',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '0',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'NZ'},
#   {'OpenDate': '03012007',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03282009',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '26',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B-0---------0----------0',
#    'Subcode': '1216268',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_560ce8d6-64f5-4fac-88b3-9f3978790fe5',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_011b0c0d-6f88-47bc-98a7-d63c2437d00b',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '04072017',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08032017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '04',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00C',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_38cccc58-77e7-4d43-803c-daf57c01503e',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_08909036-da3f-445f-9354-5add2f601ac0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09012016',
#    'StatusDate': '06012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '06282017',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '6037453215420',
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '06262017',
#    'Subcode': '1945962',
#    'SubscriberDisplayName': 'VERIZON NEW ENGLAND IN',
#    'id': 'tl_e6a7994e-4212-4d1f-ae1d-0c77398befab',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_2c77e30c-fcad-4908-a817-b47ac51bde50',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '31',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'UT'},
#   {'OpenDate': '08122015',
#    'StatusDate': '05012016',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '05282016',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '15621485',
#    'MonthsHistory': '10',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_ac3736af-cae2-4c48-a566-1d9bd337e506',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_b93cec78-db16-41a8-9195-8283acaf46c0',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': 'UNK',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '02182007',
#    'StatusDate': '11012015',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '11282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000CCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_ea59113c-d435-4c30-a344-f3da4e52eea9',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_d4664c75-3dd8-4a84-8cea-b17db387697c',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '05011984',
#    'StatusDate': '10012015',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '10082015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_086dca5f-abf3-4a45-a1b2-5b5a6c0b329a',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_ae7c993e-8d48-40e0-8464-45f558bd3ecc',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '12142012',
#    'StatusDate': '08012015',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08282015',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'AccountNumber': '13750088',
#    'MonthsHistory': '33',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_fc0e0bc4-af71-4ef4-a252-ab8a3a955993',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_84bbc8df-819f-4003-bd05-4f0f759a3dde',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '31',
#    'TermsDuration_code': '180',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'I',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '10202007',
#    'StatusDate': '11012012',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '11102012',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '68',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_4bb6fdaf-da34-4953-b4c4-3d60a5ac3e04',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_59bca1bc-0675-4ea5-b3ff-8f8da26ae783',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '10202007',
#    'StatusDate': '10012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '10282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1220390',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_c1cd1b66-6cb1-4f5a-92ca-1ce5e87fb21c',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_8e38d2fc-ab48-4565-99d3-9931834440c3',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01012007',
#    'StatusDate': '07012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '07282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '56',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000CCCCCC',
#    'Subcode': '1290016',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_e51b5060-3384-4666-930b-e7f9376e120f',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_17a26a42-58e4-4280-bd89-4bfb7ab8ba19',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01092008',
#    'StatusDate': '06012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '06082011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '32',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000CCCCCCCCCC',
#    'Subcode': '1290138',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_ab3a4ad4-d792-4a3c-870b-4f5a28b825c8',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_4d93cfa2-ab93-4a28-abcd-ff278d470c94',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '3',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01082006',
#    'StatusDate': '02012011',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '02282011',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '62',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B0000000000000000--------',
#    'Subcode': '6230125',
#    'SubscriberDisplayName': 'BAC/FLEET-BKCARD',
#    'id': 'tl_17f12c67-cdc4-4ae0-9ae9-a5f725554875',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_cb21fb4b-3555-43e8-a3cf-3265290ff12f',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09242005',
#    'StatusDate': '11012010',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '11282010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '60',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B000000000000000000000000',
#    'Subcode': '1260958',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_bb25d97f-9914-4d3f-98f4-22ee5069ea67',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_8bb9c517-432c-454f-8302-7d7426a7e9e6',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '3',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09102007',
#    'StatusDate': '03012010',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03072010',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '30',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B00000000000000000CCCCCCC',
#    'Subcode': '3245600',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_aa796aef-900b-4cf7-9759-1fb45a962def',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_3228221c-f42f-4cf1-a1e3-dbf597afe64e',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_f6f140b2-817b-4ffb-b9e7-934df118c51a',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_6dd3e0c9-1a06-4a38-9fe5-4e018b5de802',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09262007',
#    'StatusDate': '12012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '12282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '3278165',
#    'SubscriberDisplayName': 'CITI',
#    'id': 'tl_c2e52f63-4953-4b6b-9429-acd160031b40',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_32c68ac8-6221-414d-9796-a954f02ca760',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '04222005',
#    'StatusDate': '06012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '06282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '25',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCCCCCCCCCCCCC',
#    'Subcode': '1201520',
#    'SubscriberDisplayName': 'BANK CREDIT CARD',
#    'id': 'tl_8b5a7386-1c44-42e0-ba13-3184314d31be',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_a68f5610-aa8a-4eb4-a199-63e920010c54',
#    'SpecialComment_code': '18',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '01072008',
#    'StatusDate': '03012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '03012009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '14',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCCCC',
#    'Subcode': '1202270',
#    'SubscriberDisplayName': 'WF/WB',
#    'id': 'tl_2f969070-5e2d-4dd6-9d12-a3e19f5936b8',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_4e536a31-83fc-4fb8-8a42-96f9bc99c88e',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BB'},
#   {'OpenDate': '02282004',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '02282009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '61',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'BCCCCCCCCCCC00000000CCCCC',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_beeea4b7-ee93-4a75-a553-7b23f8632f01',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_52917525-02fd-41c1-9781-173853ccfcf0',
#    'SpecialComment_code': '19',
#    'Evaluation_code': 'N',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '02151994',
#    'StatusDate': '02012009',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '02222009',
#    'BalanceAmount': None,
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'B---------------C--------',
#    'Subcode': '1270583',
#    'SubscriberDisplayName': 'CHASE NA',
#    'id': 'tl_e9ac86b8-552f-481e-8ad2-a6d4530b35c3',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_390ac941-71fe-4191-aac0-eaf1252198c9',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '12',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'C',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '09072013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08232017',
#    'BalanceAmount': '00000025',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '49',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C0CCCCCCCCC000CCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000010',
#    'LastPaymentDate': '06082017',
#    'Subcode': '3178962',
#    'SubscriberDisplayName': 'CBNA',
#    'id': 'tl_ca9831e0-e1b7-4c11-ab27-2cd2cea626ab',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_793dadff-58b6-40bd-8129-cd40cb699697',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '2',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'ZR'},
#   {'OpenDate': '09011979',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08202017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '75',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000CCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '05092017',
#    'Subcode': '1335510',
#    'SubscriberDisplayName': 'SYNCB/EXXON MOBIL',
#    'id': 'tl_79743047-2624-49e5-a215-bd6650b7c601',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_c227c59a-64e1-42ac-b13f-e1648f075c9f',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'OC'},
#   {'OpenDate': '06182013',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08162017',
#    'BalanceAmount': '00000160',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '51',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0C',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07272017',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_0d756ec2-ed56-4c0b-8b39-b506af5ceb06',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_3a721bfb-b9d0-4bce-a818-e2e0f7f21f0f',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'DV'},
#   {'OpenDate': '04272007',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08152017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '99',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000000000CCCCCCC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '12282015',
#    'Subcode': '3308810',
#    'SubscriberDisplayName': 'SYNCB/SAMS CLUB',
#    'id': 'tl_41637bbe-3470-46c1-8fcf-f719ea52599c',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_74edf147-401f-4292-8a52-df7d884f14d2',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '3',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'DV'},
#   {'OpenDate': '09012010',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08142017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '84',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '000000000000C000000000000',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '08282016',
#    'Subcode': '1349040',
#    'SubscriberDisplayName': 'FILENES',
#    'id': 'tl_23e90d28-92b3-4329-9c06-8ab7afce4142',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_0ed96132-6f17-4dde-ba51-82e8db662111',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'ZR'},
#   {'OpenDate': '04011998',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08092017',
#    'BalanceAmount': '00001354',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '97',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCCCC',
#    'MonthlyPaymentAmount': '00000015',
#    'LastPaymentDate': '07242017',
#    'Subcode': '1230206',
#    'SubscriberDisplayName': 'BK OF AMER',
#    'id': 'tl_6cf42c49-1c3e-4029-8386-45f420773b49',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_0dd80f3a-73cb-4800-b8ed-92073f8e5e09',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': 'S',
#    'KOB_code': 'BC'},
#   {'OpenDate': '06011983',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000052',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_0ae7eded-3185-443b-9e66-4bd9cb1c727c',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_611dfdcb-78ea-41bf-9941-f8e15612172b',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000599',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_78913199-f05d-447e-b7ee-9e01727875ae',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_942dd53b-6b51-400b-80e7-f3d8b19cfdf5',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': '001',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '05011984',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00001960',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '01',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'C',
#    'Subcode': '1229200',
#    'SubscriberDisplayName': 'AMEX',
#    'id': 'tl_a8158f99-8a96-4eff-aa3b-fa6f7ee51e3e',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_e669400c-83b0-457a-82e8-da8f9a730fa9',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '18',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': '',
#    'KOB_code': 'BC'},
#   {'OpenDate': '08182016',
#    'StatusDate': '08012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '08072017',
#    'BalanceAmount': '00000000',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '12',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': '0000000000CC',
#    'MonthlyPaymentAmount': None,
#    'LastPaymentDate': '09192016',
#    'Subcode': '2613430',
#    'SubscriberDisplayName': 'SYNCB/BROOK BROS',
#    'id': 'tl_182e25bc-d3d0-4c7f-bf9e-e7324caaaa68',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_5958777f-1fec-4661-b16e-c17b1d4d6576',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '07',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'CG'},
#   {'OpenDate': '08122015',
#    'StatusDate': '07012017',
#    'MaxDelinquencyDate': None,
#    'BalanceDate': '07282017',
#    'BalanceAmount': '00004607',
#    'AmountPastDue': None,
#    'ConsumerComment': None,
#    'MonthsHistory': '24',
#    'DelinquenciesOver30Days': '00',
#    'DelinquenciesOver60Days': '00',
#    'DelinquenciesOver90Days': '00',
#    'DerogCounter': '00',
#    'PaymentProfile': 'CCCCCCCCCCCCCCCCCCCCCCC0',
#    'MonthlyPaymentAmount': 'UNKNOWN',
#    'LastPaymentDate': '07102017',
#    'Subcode': '2165670',
#    'SubscriberDisplayName': 'CITIZENS BANK',
#    'id': 'tl_eb1ddcd2-9181-4ce7-bf44-51e7ac994038',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976',
#    'enhanced_pm_data_id': 'ep_b5957d23-2cc4-458b-9999-c778f38e6f43',
#    'SpecialComment_code': '  ',
#    'Evaluation_code': 'P',
#    'AccountType_code': '47',
#    'TermsDuration_code': 'REV',
#    'Status_code': '11',
#    'ECOA_code': '1',
#    'OpenOrClosed_code': 'O',
#    'RevolvingOrInstallment_code': 'R',
#    'MonthlyPaymentType_code': ' ',
#    'KOB_code': 'BB'}],
#  'inquiries': [{'Date': '08182016',
#    'Amount': 'UNKNOWN',
#    'Subcode': '1640007',
#    'SubscriberDisplayName': 'SYNCB/BROOKS BROS',
#    'id': 'iq_288adcc1-a898-45fd-9b5d-91c918d963d6',
#    'Type_code': '31',
#    'Terms_code': 'UNK',
#    'KOB_code': 'FF'}],
#  'info_msgs': [{'MessageNumber': '92',
#    'MessageText': '0092 REQUESTED PRODUCT OPTION NOT ALLOWED',
#    'id': 'im_7b5a9f0d-ba02-487e-9887-5d829cc9a5b3',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'},
#   {'MessageNumber': '84',
#    'MessageText': '0084 SSN MATCHES',
#    'id': 'im_624f38eb-1e24-4076-ab0b-9a5217880475',
#    'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'}],
#  'enhanced_pm_data': [{'InitialPaymentLevelDate': '05012017',
#    'id': 'ep_be81da4a-f067-4fe0-9af8-f90de047374a',
#    'AccountCondition_code': '05',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '51'},
#   {'InitialPaymentLevelDate': '03012012',
#    'id': 'ep_270687c8-893a-4639-9d91-c76296a54e96',
#    'AccountCondition_code': '05',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '40'},
#   {'InitialPaymentLevelDate': '07012017',
#    'id': 'ep_7966909c-b9e6-4212-9cc6-aec4d1948471',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012012',
#    'id': 'ep_e4d9adbf-61b9-4183-bc78-ab8a53413d97',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '18'},
#   {'InitialPaymentLevelDate': '04012009',
#    'id': 'ep_c3c7268d-6147-40a3-a31a-9091637e1938',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012009',
#    'id': 'ep_011b0c0d-6f88-47bc-98a7-d63c2437d00b',
#    'AccountCondition_code': 'A3',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_08909036-da3f-445f-9354-5add2f601ac0',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '06012017',
#    'id': 'ep_2c77e30c-fcad-4908-a817-b47ac51bde50',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '92',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '05012016',
#    'id': 'ep_b93cec78-db16-41a8-9195-8283acaf46c0',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '6D',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '11012015',
#    'id': 'ep_d4664c75-3dd8-4a84-8cea-b17db387697c',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '89',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '10012015',
#    'id': 'ep_ae7c993e-8d48-40e0-8464-45f558bd3ecc',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '08012015',
#    'id': 'ep_84bbc8df-819f-4003-bd05-4f0f759a3dde',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '6D',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '11012012',
# ...
#    'id': 'ep_8bb9c517-432c-454f-8302-7d7426a7e9e6',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '03012010',
#    'id': 'ep_3228221c-f42f-4cf1-a1e3-dbf597afe64e',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '12012009',
#    'id': 'ep_6dd3e0c9-1a06-4a38-9fe5-4e018b5de802',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '12012009',
#    'id': 'ep_32c68ac8-6221-414d-9796-a954f02ca760',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '06012009',
#    'id': 'ep_a68f5610-aa8a-4eb4-a199-63e920010c54',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '18'},
#   {'InitialPaymentLevelDate': '03012009',
#    'id': 'ep_4e536a31-83fc-4fb8-8a42-96f9bc99c88e',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '02012009',
#    'id': 'ep_52917525-02fd-41c1-9781-173853ccfcf0',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '19'},
#   {'InitialPaymentLevelDate': '02012009',
#    'id': 'ep_390ac941-71fe-4191-aac0-eaf1252198c9',
#    'AccountCondition_code': 'A2',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_793dadff-58b6-40bd-8129-cd40cb699697',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_c227c59a-64e1-42ac-b13f-e1648f075c9f',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_3a721bfb-b9d0-4bce-a818-e2e0f7f21f0f',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_74edf147-401f-4292-8a52-df7d884f14d2',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_0ed96132-6f17-4dde-ba51-82e8db662111',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_0dd80f3a-73cb-4800-b8ed-92073f8e5e09',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_611dfdcb-78ea-41bf-9941-f8e15612172b',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_942dd53b-6b51-400b-80e7-f3d8b19cfdf5',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_e669400c-83b0-457a-82e8-da8f9a730fa9',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '18',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '08012017',
#    'id': 'ep_5958777f-1fec-4661-b16e-c17b1d4d6576',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '07',
#    'SpecialComment_code': '  '},
#   {'InitialPaymentLevelDate': '07012017',
#    'id': 'ep_b5957d23-2cc4-458b-9999-c778f38e6f43',
#    'AccountCondition_code': 'A1',
#    'PaymentStatus_code': '11',
#    'AccountType_code': '89',
#    'SpecialComment_code': '  '}],
#  'tradeline_amounts': [{'Value': '00000350',
#    'id': 'am_21f9148e-baa0-499a-b57f-db97d0532fa4',
#    'TradeLine_id': 'tl_e99abe94-fb64-4f72-8b3e-ffe50f9151cc',
#    'Qualifier_code': 'L'},
#   {'Value': '00000056',
#    'id': 'am_3f0738cb-0a0e-4347-abcd-6c1eebea1b60',
#    'TradeLine_id': 'tl_e99abe94-fb64-4f72-8b3e-ffe50f9151cc',
#    'Qualifier_code': 'H'},
#   {'Value': '00011500',
#    'id': 'am_4218d53f-8f47-4f13-bcce-a70280c59c40',
#    'TradeLine_id': 'tl_7edd5a5b-35d8-4d80-b1b1-516ee5ad7a83',
#    'Qualifier_code': 'L'},
#   {'Value': '00011440',
#    'id': 'am_74dced83-e3ad-400d-8eba-a18bf51d5247',
#    'TradeLine_id': 'tl_7edd5a5b-35d8-4d80-b1b1-516ee5ad7a83',
#    'Qualifier_code': 'H'},
#   {'Value': '00012900',
#    'id': 'am_4c662ef6-e429-4cf4-a5ef-f2f7eb45119a',
#    'TradeLine_id': 'tl_304db81f-57c1-499e-bc9b-d21c2f1ce9f2',
#    'Qualifier_code': 'L'},
#   {'Value': '00008979',
#    'id': 'am_4cd636c2-3751-4c72-97d0-6a73e8fae7d2',
#    'TradeLine_id': 'tl_304db81f-57c1-499e-bc9b-d21c2f1ce9f2',
#    'Qualifier_code': 'H'},
#   {'Value': 'UNKNOWN',
#    'id': 'am_996df2f7-b98e-40a6-8618-2506c6b41d51',
#    'TradeLine_id': 'tl_388c50ef-fa08-4570-8b2b-53703c078658',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_da0d7fbf-22ca-46b3-bcfb-e9aae0cbee8f',
#    'TradeLine_id': 'tl_388c50ef-fa08-4570-8b2b-53703c078658',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_24d7c229-f286-4370-9c30-f4d1b7c787dd',
#    'TradeLine_id': 'tl_6c06c7bc-30ae-4968-8112-95895298a3be',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_f249f1f0-0f79-4e2a-b0c1-b0429a29d910',
#    'TradeLine_id': 'tl_6c06c7bc-30ae-4968-8112-95895298a3be',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_ab61fb04-1710-4b0d-9a26-7232e07f8815',
#    'TradeLine_id': 'tl_560ce8d6-64f5-4fac-88b3-9f3978790fe5',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_862f640d-000e-4658-850e-8625f3299e29',
#    'TradeLine_id': 'tl_560ce8d6-64f5-4fac-88b3-9f3978790fe5',
#    'Qualifier_code': ' '},
#   {'Value': '00010000',
#    'id': 'am_a79c2fc6-3590-4e9a-8099-cadd49a29354',
#    'TradeLine_id': 'tl_38cccc58-77e7-4d43-803c-daf57c01503e',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_e9382a16-3051-4510-825a-3c9a1bc5e814',
#    'TradeLine_id': 'tl_38cccc58-77e7-4d43-803c-daf57c01503e',
#    'Qualifier_code': ' '},
#   {'Value': 'UNKNOWN',
#    'id': 'am_079c7ce5-e0f7-443b-b954-9d7efe1d4944',
#    'TradeLine_id': 'tl_e6a7994e-4212-4d1f-ae1d-0c77398befab',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_7be6bca6-ad2b-482c-b8e3-23cd5d0c9b78',
#    'TradeLine_id': 'tl_e6a7994e-4212-4d1f-ae1d-0c77398befab',
#    'Qualifier_code': ' '},
#   {'Value': '00040000',
#    'id': 'am_17c683d2-1dca-4666-afd5-5125226c7858',
#    'TradeLine_id': 'tl_ac3736af-cae2-4c48-a566-1d9bd337e506',
#    'Qualifier_code': 'O'},
#   {'Value': None,
#    'id': 'am_2114b01c-008a-44e6-9875-41f3d5b858de',
#    'TradeLine_id': 'tl_ac3736af-cae2-4c48-a566-1d9bd337e506',
#    'Qualifier_code': ' '},
#   {'Value': '00080000',
#    'id': 'am_345f0fc2-a807-4e6b-b7fc-4562f475434b',
#    'TradeLine_id': 'tl_ea59113c-d435-4c30-a344-f3da4e52eea9',
#    'Qualifier_code': 'L'},
#   {'Value': '00159087',
#    'id': 'am_b5d7eb17-fcd9-43e8-91cc-e197af99b485',
#    'TradeLine_id': 'tl_ea59113c-d435-4c30-a344-f3da4e52eea9',
#    'Qualifier_code': 'H'},
#   {'Value': '00000223',
#    'id': 'am_42bba3c2-6815-403c-a34f-d208e3f73510',
#    'TradeLine_id': 'tl_086dca5f-abf3-4a45-a1b2-5b5a6c0b329a',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_df3b8a13-89de-4b57-ba29-674311cfe88b',
#    'TradeLine_id': 'tl_086dca5f-abf3-4a45-a1b2-5b5a6c0b329a',
#    'Qualifier_code': ' '},
#   {'Value': '00150000',
#    'id': 'am_0232e561-12b9-4c25-ba71-16d361c213b9',
#    'TradeLine_id': 'tl_fc0e0bc4-af71-4ef4-a252-ab8a3a955993',
#    'Qualifier_code': 'O'},
#   {'Value': None,
#    'id': 'am_4fa06e1f-a7d7-4c58-bf9d-6419d51e5ecb',
#    'TradeLine_id': 'tl_fc0e0bc4-af71-4ef4-a252-ab8a3a955993',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_a04a59c9-de41-4f7c-a2eb-3469d77ad643',
#    'TradeLine_id': 'tl_4bb6fdaf-da34-4953-b4c4-3d60a5ac3e04',
#    'Qualifier_code': 'L'},
#   {'Value': '00000082',
#    'id': 'am_3b49bda4-3ff7-45aa-bddb-29ef1aec8d92',
#    'TradeLine_id': 'tl_4bb6fdaf-da34-4953-b4c4-3d60a5ac3e04',
#    'Qualifier_code': 'H'},
#   {'Value': '00007000',
#    'id': 'am_a1616ffb-5b2e-4d22-b450-b2f9efb743fd',
#    'TradeLine_id': 'tl_c1cd1b66-6cb1-4f5a-92ca-1ce5e87fb21c',
#    'Qualifier_code': 'L'},
#   {'Value': '00007000',
#    'id': 'am_79d22e45-8689-4a78-ad7d-68fca776f3fb',
#    'TradeLine_id': 'tl_c1cd1b66-6cb1-4f5a-92ca-1ce5e87fb21c',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_2d0b743f-73ec-4287-896a-f55cc7bcb266',
#    'TradeLine_id': 'tl_e51b5060-3384-4666-930b-e7f9376e120f',
#    'Qualifier_code': 'L'},
#   {'Value': '00009434',
#    'id': 'am_81a92986-fac8-4946-8f32-43575f89abdb',
#    'TradeLine_id': 'tl_e51b5060-3384-4666-930b-e7f9376e120f',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_05da379e-3213-4b9f-baf7-768b3bede347',
#    'TradeLine_id': 'tl_ab3a4ad4-d792-4a3c-870b-4f5a28b825c8',
#    'Qualifier_code': 'L'},
#   {'Value': '00008982',
#    'id': 'am_ac3d56b8-7aa4-424b-b7b2-2d165b121c64',
#    'TradeLine_id': 'tl_ab3a4ad4-d792-4a3c-870b-4f5a28b825c8',
#    'Qualifier_code': 'H'},
#   {'Value': '00000700',
#    'id': 'am_a3c4694c-7d39-46c5-a520-62d1160012fd',
#    'TradeLine_id': 'tl_17f12c67-cdc4-4ae0-9ae9-a5f725554875',
#    'Qualifier_code': 'L'},
#   {'Value': '00000283',
#    'id': 'am_31415639-1334-4d38-b1bc-c97748570892',
#    'TradeLine_id': 'tl_17f12c67-cdc4-4ae0-9ae9-a5f725554875',
#    'Qualifier_code': 'H'},
#   {'Value': 'UNKNOWN',
#    'id': 'am_1df45ff7-b7dc-4e22-97e2-4650d832bf50',
#    'TradeLine_id': 'tl_bb25d97f-9914-4d3f-98f4-22ee5069ea67',
#    'Qualifier_code': ' '},
#   {'Value': None,
#    'id': 'am_9e1eed84-9051-4a40-a477-ae76c8896bd6',
#    'TradeLine_id': 'tl_bb25d97f-9914-4d3f-98f4-22ee5069ea67',
#    'Qualifier_code': ' '},
#   {'Value': '00004072',
#    'id': 'am_13e2ed85-884b-4b0a-9c96-0a41164f575c',
#    'TradeLine_id': 'tl_aa796aef-900b-4cf7-9759-1fb45a962def',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_9b4d6f9d-9740-4027-812e-63ed594c703a',
#    'TradeLine_id': 'tl_aa796aef-900b-4cf7-9759-1fb45a962def',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_eeba0551-507e-44b6-83b8-90c94db23546',
#    'TradeLine_id': 'tl_f6f140b2-817b-4ffb-b9e7-934df118c51a',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_d9c5e93d-a299-4aaf-b1a4-78fad6ade1bc',
#    'TradeLine_id': 'tl_f6f140b2-817b-4ffb-b9e7-934df118c51a',
#    'Qualifier_code': ' '},
#   {'Value': '00007000',
#    'id': 'am_caf0b081-d52c-4026-be3b-7416f57b2041',
#    'TradeLine_id': 'tl_c2e52f63-4953-4b6b-9429-acd160031b40',
#    'Qualifier_code': 'L'},
#   {'Value': '00003813',
#    'id': 'am_a63c5d3a-8ccb-487b-b6c4-ab5883f90614',
#    'TradeLine_id': 'tl_c2e52f63-4953-4b6b-9429-acd160031b40',
#    'Qualifier_code': 'H'},
#   {'Value': '00010000',
#    'id': 'am_ec175514-5998-4739-9dd0-c871577f6dca',
#    'TradeLine_id': 'tl_8b5a7386-1c44-42e0-ba13-3184314d31be',
#    'Qualifier_code': 'L'},
#   {'Value': '00008679',
#    'id': 'am_7bb42a50-819c-44f1-9e17-475f6772da61',
#    'TradeLine_id': 'tl_8b5a7386-1c44-42e0-ba13-3184314d31be',
#    'Qualifier_code': 'H'},
#   {'Value': '00000500',
#    'id': 'am_05e88b20-a373-4c43-a214-0dde1a508b68',
#    'TradeLine_id': 'tl_2f969070-5e2d-4dd6-9d12-a3e19f5936b8',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_6623c079-c7bd-4396-a277-db579526ec85',
#    'TradeLine_id': 'tl_2f969070-5e2d-4dd6-9d12-a3e19f5936b8',
#    'Qualifier_code': ' '},
#   {'Value': '00012000',
#    'id': 'am_294f114c-8d47-433c-80c3-193669fb878e',
#    'TradeLine_id': 'tl_beeea4b7-ee93-4a75-a553-7b23f8632f01',
#    'Qualifier_code': 'L'},
#   {'Value': '00010020',
#    'id': 'am_31d8d59f-b13b-4d00-b11c-0ba84cbe9d60',
#    'TradeLine_id': 'tl_beeea4b7-ee93-4a75-a553-7b23f8632f01',
#    'Qualifier_code': 'H'},
#   {'Value': '00005000',
#    'id': 'am_80537e0e-cd95-4b55-b683-2935fa20dedc',
#    'TradeLine_id': 'tl_e9ac86b8-552f-481e-8ad2-a6d4530b35c3',
#    'Qualifier_code': 'L'},
#   {'Value': None,
#    'id': 'am_e8faf6f2-06b7-49b7-b1fe-60b19dd7a158',
#    'TradeLine_id': 'tl_e9ac86b8-552f-481e-8ad2-a6d4530b35c3',
#    'Qualifier_code': ' '},
#   {'Value': '00006900',
#    'id': 'am_48eb94b5-4eae-44a6-ac1d-d81485515cc1',
#    'TradeLine_id': 'tl_ca9831e0-e1b7-4c11-ab27-2cd2cea626ab',
#    'Qualifier_code': 'L'},
#   {'Value': '00003032',
#    'id': 'am_68f9535f-d4a9-4d95-b8d4-66fdecf27ce1',
#    'TradeLine_id': 'tl_ca9831e0-e1b7-4c11-ab27-2cd2cea626ab',
#    'Qualifier_code': 'H'},
#   {'Value': '00001000',
#    'id': 'am_ec6c00a9-da24-4241-8788-265313ad3b8b',
#    'TradeLine_id': 'tl_79743047-2624-49e5-a215-bd6650b7c601',
#    'Qualifier_code': 'L'},
#   {'Value': '00000285',
#    'id': 'am_333a22f3-edf2-467e-85d4-55222263950e',
#    'TradeLine_id': 'tl_79743047-2624-49e5-a215-bd6650b7c601',
#    'Qualifier_code': 'H'},
#   {'Value': '00001500',
#    'id': 'am_31ffd3ad-60aa-4480-8bfa-c03beb99a707',
#    'TradeLine_id': 'tl_0d756ec2-ed56-4c0b-8b39-b506af5ceb06',
#    'Qualifier_code': 'L'},
#   {'Value': '00000546',
#    'id': 'am_0be35486-6d1d-4270-ba71-4d8a99ffcebe',
#    'TradeLine_id': 'tl_0d756ec2-ed56-4c0b-8b39-b506af5ceb06',
#    'Qualifier_code': 'H'},
#   {'Value': '00003600',
#    'id': 'am_f15b9ec1-e299-465f-9058-fe6a55596f8c',
#    'TradeLine_id': 'tl_41637bbe-3470-46c1-8fcf-f719ea52599c',
#    'Qualifier_code': 'L'},
#   {'Value': '00001184',
#    'id': 'am_7eae1b57-c897-43d6-ab37-a28eea195129',
#    'TradeLine_id': 'tl_41637bbe-3470-46c1-8fcf-f719ea52599c',
#    'Qualifier_code': 'H'},
#   {'Value': '00000723',
#    'id': 'am_b744bffd-a9c7-46cd-9d46-f75db512b734',
#    'TradeLine_id': 'tl_23e90d28-92b3-4329-9c06-8ab7afce4142',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_b2d87543-f3b3-424e-8185-5c37a5f9942c',
#    'TradeLine_id': 'tl_23e90d28-92b3-4329-9c06-8ab7afce4142',
#    'Qualifier_code': ' '},
#   {'Value': '00019000',
#    'id': 'am_f6f39e1f-9b0d-43b8-a307-6ccdfb3e26d3',
#    'TradeLine_id': 'tl_6cf42c49-1c3e-4029-8386-45f420773b49',
#    'Qualifier_code': 'L'},
#   {'Value': '00010513',
#    'id': 'am_3581a30f-ab40-418e-b0f3-1310406621c9',
#    'TradeLine_id': 'tl_6cf42c49-1c3e-4029-8386-45f420773b49',
#    'Qualifier_code': 'H'},
#   {'Value': '00012200',
#    'id': 'am_b9facca0-4d64-4b09-af92-0f3d97298ddf',
#    'TradeLine_id': 'tl_0ae7eded-3185-443b-9e66-4bd9cb1c727c',
#    'Qualifier_code': 'L'},
#   {'Value': '00000629',
#    'id': 'am_6b26906e-d4f3-4a68-9fe2-f7f35514efee',
#    'TradeLine_id': 'tl_0ae7eded-3185-443b-9e66-4bd9cb1c727c',
#    'Qualifier_code': 'H'},
#   {'Value': '00001047',
#    'id': 'am_69547451-9d3e-4fa6-96e8-dd33fba32ab5',
#    'TradeLine_id': 'tl_78913199-f05d-447e-b7ee-9e01727875ae',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_2a5fcc7d-c221-4be6-8ddd-c56514ca07b7',
#    'TradeLine_id': 'tl_78913199-f05d-447e-b7ee-9e01727875ae',
#    'Qualifier_code': ' '},
#   {'Value': '00007361',
#    'id': 'am_4492c98d-8f30-4b96-b357-7df38c235a00',
#    'TradeLine_id': 'tl_a8158f99-8a96-4eff-aa3b-fa6f7ee51e3e',
#    'Qualifier_code': 'H'},
#   {'Value': None,
#    'id': 'am_445b16b3-843e-4673-a87f-ce94aa72a96f',
#    'TradeLine_id': 'tl_a8158f99-8a96-4eff-aa3b-fa6f7ee51e3e',
#    'Qualifier_code': ' '},
#   {'Value': '00001500',
#    'id': 'am_0c40e446-f4fb-4af6-9869-ad0f42c2864b',
#    'TradeLine_id': 'tl_182e25bc-d3d0-4c7f-bf9e-e7324caaaa68',
#    'Qualifier_code': 'L'},
#   {'Value': '00000089',
#    'id': 'am_93b53107-b8d0-4de5-82db-9ada7d78e6f8',
#    'TradeLine_id': 'tl_182e25bc-d3d0-4c7f-bf9e-e7324caaaa68',
#    'Qualifier_code': 'H'},
#   {'Value': '00150000',
#    'id': 'am_2b0550a5-0f1d-476c-8df7-d0501576b506',
#    'TradeLine_id': 'tl_eb1ddcd2-9181-4ce7-bf44-51e7ac994038',
#    'Qualifier_code': 'L'},
#   {'Value': '00022118',
#    'id': 'am_342f29f3-46c1-4177-b931-6dd66350d457',
#    'TradeLine_id': 'tl_eb1ddcd2-9181-4ce7-bf44-51e7ac994038',
#    'Qualifier_code': 'H'}]}

# %% [markdown]
# Take a preview of table PrequalResult

# %%
pd.DataFrame(RESULT_OBJ_DICT['prequal_results'])
# Out:
#                   model  pk  loanapp_id  result error_reason detail_results  \
# 0  common.prequalresult   1         194    True   no reasons           None
#
#   fico_v2    report_type username                created_at  ...  \
# 0     695  CreditProfile      cho  2016-08-04T00:29:03.067Z  ...
#
#   business_credit_card_total_limits business_credit_card_total_balances  \
# 0                              None                                None
#
#   business_total_mortgage_monthly_payments  \
# 0                                     None
#
#   business_total_monthly_debt_payments bkdate fico_v3  \
# 0                                 None   None    None
#
#   total_mortgage_monthly_payments       version       role  \
# 0                            None  CF Microloan  applicant
#
#                              xml_detail_id
# 0  xd_eb7c47ff-8048-441a-b153-522643657d03
#
# [1 rows x 24 columns]

# %% [markdown]
# Take a preview of table Product

# %%
pd.DataFrame(RESULT_OBJ_DICT['products'])
# Out:
#                                 @xmlns  \
# 0  http://www.experian.com/ARFResponse
#
#                                         id  \
# 0  pd_82762c24-7362-4c6d-a95c-01da3be29db0
#
#                          credit_profile_id
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea

# %% [markdown]
# Take a preview of table CreditProfile

# %%
pd.DataFrame(RESULT_OBJ_DICT['credit_profiles'])
# Out:
#                                         id  \
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea
#
#                                  header_id  \
# 0  hd_530c0a97-f26c-4d67-b153-3b11af4b1cea
#
#                                 inquiry_id
# 0  iq_e15be34d-446d-4998-b652-b8e98fcedd46

# %% [markdown]
# Take a preview of table Header

# %%
pd.DataFrame(RESULT_OBJ_DICT['headers'])
# Out:
#   ReportDate ReportTime Preamble ARFVersion  \
# 0   10032017     140607     TWA1         07
#
#                                         id
# 0  hd_530c0a97-f26c-4d67-b153-3b11af4b1cea

# %% [markdown]
# Take a preview of table RiskModel

# %%
pd.DataFrame(RESULT_OBJ_DICT['risk_models'])
# Out:
#   Score ScoreFactorCodeOne ScoreFactorCodeTwo ScoreFactorCodeThree  \
# 0  0808                 10                 09                   05
# 1  0807                 30                 05                   11
#
#   ScoreFactorCodeFour                                       id  \
# 0                None  rm_3f81f6bf-6b10-47f4-b21c-06bd3242fec8
# 1                None  rm_17da3e39-4320-4f1e-a642-7f3da2160e71
#
#                           CreditProfile_id ModelIndicator_code Evaluation_code
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                  F                P
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                  AA               P

# %% [markdown]
# Take a preview of table ConsumerIdentity

# %%
RESULT_OBJ_DICT['consumer_identities']
# Out:
# [{'YOB': None,
#   'id': 'ci_96c6683f-47f4-43bc-958b-339dd5755b2a',
#   'Surname': 'SCALICI',
#   'First': 'WILLIAM',
#   'Middle': '',
#   'Gen': '',
#   'NameType_code': '',
#   'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'},
#  {'YOB': None,
#   'id': 'ci_16874b77-f28a-49d2-85f6-0fead5f8fb97',
#   'Surname': 'SCALICI',
#   'First': 'AS',
#   'Middle': 'WILLIAM',
#   'Gen': '',
#   'NameType_code': 'N',
#   'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'},
#  {'YOB': None,
#   'id': 'ci_6336a8b5-f7f0-4f00-ad2e-6f7c82415042',
#   'Surname': 'SCALICI',
#   'First': 'WILLIAM',
#   'Middle': '',
#   'Gen': 'JR',
#   'NameType_code': '',
#   'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'},
#  {'YOB': None,
#   'id': 'ci_7d44be99-91b4-4516-bc60-c65b6ba34fb0',
#   'Surname': 'ANTHONY',
#   'First': 'WILLIAM',
#   'Middle': 'R',
#   'Gen': '',
#   'NameType_code': 'A',
#   'CreditProfile_id': 'cp_77c81901-e783-4adb-a5b5-f9b3a54cc976'}]

# %%
pd.DataFrame(RESULT_OBJ_DICT['consumer_identities'])
# Out:
#                                                 Name   YOB  \
# 0         {'Surname': 'SCALICI', 'First': 'WILLIAM'}  None
# 1  {'Type': {'@code': 'N'}, 'Surname': 'SCALICI',...  None
# 2  {'Surname': 'SCALICI', 'First': 'WILLIAM', 'Ge...  None
# 3  {'Type': {'@code': 'A'}, 'Surname': 'ANTHONY',...  None
#
#                                         id   Middle NameType_code  \
# 0  ci_a47c6f9c-bd0a-4123-85ad-ead4ecc95d8e
# 1  ci_de5fc6e7-f534-45f0-8069-7c5b74daeebe  WILLIAM             N
# 2  ci_e7e1780e-12a9-4851-a30b-d82db451f64f
# 3  ci_741e218a-8406-4a41-b2f6-e7f44ffd5453        R             A
#
#                           CreditProfile_id
# 0  cp_294b2457-e1a0-4f52-8cda-bdc7119e745b
# 1  cp_294b2457-e1a0-4f52-8cda-bdc7119e745b
# 2  cp_294b2457-e1a0-4f52-8cda-bdc7119e745b
# 3  cp_294b2457-e1a0-4f52-8cda-bdc7119e745b

# %% [markdown]
# Take a preview of table AddressInfo

# %%
pd.DataFrame(RESULT_OBJ_DICT['addr_infos'])
# Out:
#   FirstReportedDate LastUpdatedDate TimesReported LastReportingSubcode  \
# 0          10272003        12202015            00              7370142
# 1          01012011        01012011            00                 None
# 2          05282006        11022010            12                 None
#
#   StreetPrefix   StreetName StreetSuffix    City State        Zip  \
# 0         7324  84TH STREET        CT SW  TACOMA    WA  984986380
# 1       3260 S       TACOMA          WAY  TACOMA    WA  984094725
# 2       3216 S       TACOMA          WAY  TACOMA    WA  984094725
#
#   CensusGeoCode                                       id  \
# 0          None  ai_8a249318-d504-4814-b0d2-28e656b033e2
# 1          None  ai_180a3b79-fc80-4969-91ea-4568b16cd4b5
# 2          None  ai_794d9a61-3eae-405d-b469-1dc26e2a8954
#
#                           CreditProfile_id Origination_code DwellingType_code  \
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                2                 S
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                1                 S
# 2  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                1                 S
#
#   HomeOwnership_code
# 0
# 1
# 2

# %% [markdown]
# Take a preview of table EmploymentInfo

# %%
pd.DataFrame(RESULT_OBJ_DICT['employ_infos'])
# Out:
#   FirstReportedDate LastUpdatedDate        Name AddressFirstLine  \
# 0          04082011        04082011  GM RETIRED             None
# 1          12282009        06112010     RETIRED             None
#
#   AddressSecondLine AddressExtraLine   Zip  \
# 0              None             None  None
# 1              None             None  None
#
#                                         id  \
# 0  ei_da29547c-22e3-455b-a51f-79af941f6917
# 1  ei_7fe91e47-c26a-4527-96e1-90ec73229d55
#
#                           CreditProfile_id Origination_code
# 0  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                2
# 1  cp_83188663-1c2f-41ae-8fed-2e46b31ecaea                2

# %% [markdown]
# Take a preview of table TradeLine

# %%
pd.DataFrame(RESULT_OBJ_DICT['trade_lines'])
# Out:
#     OpenDate StatusDate MaxDelinquencyDate BalanceDate BalanceAmount  \
# 0   06011981   05012017               None    05192017          None
# 1   08282007   03012012               None    03182012          None
# 2   06102006   07012017               None    07232017      00000000
# 3   08282007   03012012               None    04282012      00000000
# 4   03012002   04012009               None    04012009      00000000
# ..       ...        ...                ...         ...           ...
# 31  06011983   08012017               None    08072017      00000052
# 32  05011984   08012017               None    08072017      00000599
# 33  05011984   08012017               None    08072017      00001960
# 34  08182016   08012017               None    08072017      00000000
# 35  08122015   07012017               None    07282017      00004607
#
#    AmountPastDue ConsumerComment MonthsHistory DelinquenciesOver30Days  \
# 0           None            None            15                      00
# 1           None            None            56                      00
# 2           None            None            96                      00
# 3           None            None            03                      00
# 4           None            None            86                      00
# ..           ...             ...           ...                     ...
# 31          None            None            01                      00
# 32          None            None            01                      00
# 33          None            None            01                      00
# 34          None            None            12                      00
# 35          None            None            24                      00
#
#    DelinquenciesOver60Days  ... Evaluation_code AccountType_code  \
# 0                       00  ...               N               18
# 1                       00  ...               N               18
# 2                       00  ...               N               18
# 3                       00  ...               N               18
# 4                       00  ...               N               18
# ..                     ...  ...             ...              ...
# 31                      00  ...               P               18
# 32                      00  ...               P               18
# 33                      00  ...               P               18
# 34                      00  ...               P               07
# 35                      00  ...               P               47
#
#    TermsDuration_code Status_code ECOA_code OpenOrClosed_code  \
# 0                 REV          05         1                 C
# 1                 REV          05         1                 C
# 2                 REV          11         2                 C
# 3                 REV          11         1                 C
# 4                 REV          11         0                 C
# ..                ...         ...       ...               ...
# 31                REV          11         1                 O
# 32                001          11         1                 O
# 33                REV          11         1                 O
# 34                REV          11         1                 O
# 35                REV          11         1                 O
#
#    RevolvingOrInstallment_code MonthlyPaymentType_code KOB_code AccountNumber
# 0                            R                               OC           NaN
# 1                            R                               BC           NaN
# 2                            R                               BC           NaN
# 3                            R                               BC           NaN
# 4                            R                               NZ           NaN
# ..                         ...                     ...      ...           ...
# 31                           R                               BC           NaN
# 32                           R                               BC           NaN
# 33                           R                               BC           NaN
# 34                           R                               CG           NaN
# 35                           R                               BB           NaN
#
# [36 rows x 31 columns]

# %% [markdown]
# Take a preview of table Inquiry

# %%
pd.DataFrame(RESULT_OBJ_DICT['inquiries'])
# Out:
#        Date   Amount  Subcode SubscriberDisplayName  \
# 0  08182016  UNKNOWN  1640007     SYNCB/BROOKS BROS
#
#                                         id Type_code Terms_code KOB_code
# 0  iq_3fc54910-a551-4314-85d9-51c8d0d5cfec        31        UNK       FF

# %% [markdown]
# Take a preview of table InformationMessage

# %%
pd.DataFrame(RESULT_OBJ_DICT['info_msgs'])
# Out:
#   MessageNumber                                MessageText  \
# 0            92  0092 REQUESTED PRODUCT OPTION NOT ALLOWED
# 1            84                           0084 SSN MATCHES
#
#                                         id  \
# 0  im_28268464-7836-441b-a0d0-18f3205ef32c
# 1  im_ebdda4fd-48a0-41fc-93db-5e2749d0ba4f
#
#                           CreditProfile_id
# 0  cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6
# 1  cp_0160ed5d-ab9c-42b1-8f2a-7b438e70b0a6

# %%
Take a preview of table EnhancedPaymentData

# %%
pd.DataFrame(RESULT_OBJ_DICT['enhanced_pm_data'])
# Out:
#    InitialPaymentLevelDate                                       id  \
# 0                 05012017  ep_3c421ba6-2346-428c-8d27-68fe80c0d68c
# 1                 03012012  ep_568ec0f9-f267-4dc6-9a1a-a900a502f03b
# 2                 07012017  ep_047b1fda-32da-4a2f-9132-2b319fafbd66
# 3                 03012012  ep_1d2705f9-1a92-478d-b1d2-6a116354c0c6
# 4                 04012009  ep_67ca52d4-0e3f-4043-acb4-4e35c00b3135
# ..                     ...                                      ...
# 31                08012017  ep_0cd98c68-209d-46ed-813c-b46e6b79dc19
# 32                08012017  ep_5f1be051-aa86-49ed-ad57-a2fad69d656b
# 33                08012017  ep_65e68832-a111-4c24-9f1b-3f1cb61cbcbd
# 34                08012017  ep_6dfac92c-1023-4fc9-9852-105664319d7e
# 35                07012017  ep_5a86bd16-57bd-4126-a87f-16167ee5fecb
#
#    AccountCondition_code PaymentStatus_code AccountType_code  \
# 0                     05                 11               18
# 1                     05                 11               18
# 2                     A3                 11               18
# 3                     A3                 11               18
# 4                     A3                 11               18
# ..                   ...                ...              ...
# 31                    A1                 11               18
# 32                    A1                 11               18
# 33                    A1                 11               18
# 34                    A1                 11               07
# 35                    A1                 11               89
#
#    SpecialComment_code
# 0                   51
# 1                   40
# 2                   19
# 3                   18
# 4                   19
# ..                 ...
# 31
# 32
# 33
# 34
# 35
#
# [36 rows x 6 columns]

# %%
Take a preview of table TradeLineAmount

# %%
pd.DataFrame(RESULT_OBJ_DICT['tradeline_amounts'])
# Out:
#        Value                                       id  \
# 0   00000350  am_83f02edd-f55c-4d77-8a87-c01c6959cb5e
# 1   00000056  am_030a13e9-c47b-4937-be78-7a1e1e42ca52
# 2   00011500  am_9d329a05-5a4e-4d62-baa4-5af4378c7fa0
# 3   00011440  am_0fbe17a5-35f7-4a6e-bcb2-6263eaf49f61
# 4   00012900  am_53376d62-5f42-420f-9099-eeb21c7f0daf
# ..       ...                                      ...
# 67      None  am_4dd6e759-bea2-4030-9f2e-a76e8f319923
# 68  00001500  am_bc49cd77-e919-4876-89cb-5a65d773dc0b
# 69  00000089  am_437b4598-c470-4bdf-8420-dad6b0ffd728
# 70  00150000  am_e201de52-84d8-4e0e-92aa-43fdb07e4de7
# 71  00022118  am_c7136f6f-dc66-4f90-8ae9-f0ffeaad640e
#
#                                TradeLine_id Qualifier_code
# 0   tl_1db28f6a-e1f2-4694-afc8-f1c1660cbfe6              L
# 1   tl_1db28f6a-e1f2-4694-afc8-f1c1660cbfe6              H
# 2   tl_38ed728c-204b-499a-bcd8-db7e2f5b20a6              L
# 3   tl_38ed728c-204b-499a-bcd8-db7e2f5b20a6              H
# 4   tl_c81a6fb7-b0cb-4573-afc6-c2f18f4d218a              L
# ..                                      ...            ...
# 67  tl_a6592400-9fcd-44c5-ab51-32715778e8f8
# 68  tl_add11747-c117-42de-bdec-130a6cc899ff              L
# 69  tl_add11747-c117-42de-bdec-130a6cc899ff              H
# 70  tl_60319ada-d9ff-43c0-89b9-04470f2fb38c              L
# 71  tl_60319ada-d9ff-43c0-89b9-04470f2fb38c              H
#
# [72 rows x 4 columns]
